# %% [markdown]
# # FIT5148 - Distributed Databases and Big Data
#
# # Assignment 2 TaskB - Solution Workbook
#
# **Your details:**
# - Name: Zhiqing Shu
# - Student ID: 28217551
#
# - Name: Yicheng Zhang
# - Student ID: 27699641
#
# Let's get started!

# %% [markdown]
# **1.Based on the two data sets provided i.e. Fire data-Part 1 and Weather data-Part 1, design a suitable data model to support efficient querying of the two data sets in MongoDB. Justify your data model design.**

# %% [markdown]
# We decided to model One-to-Many Relationships between `climate` and `fire` with `Embedded Documents` based on following reasons:
#
# * 'One-to-Some': the number of the fire that broken out in a certain day is impossible to be a large number, so one climate data is associated with just few fire data. In this case, `Documents Reference` is unnecessary.
# * In our task, we just need to query rather than update, and embedding provides better performance for read operations since it reduces the work load of I/O of disk.
# * We don't need to have a sperate query to get embeded data details.
#
# However, there are some disadvantages for this model:
# * The fire cannot be accessed as stand-alone entities without aggregate.
# * The statistics for fire data and its field may take more resources.
#
# After considering the pros and cons, we believe that the `Embedded` model is a better choice for our task.

# %% [markdown]
# **2.Create a new database in MongoDB. The new database will be based on the document model you have designed in Task B1.**

# %% [markdown]
# Based on the above designing, the new database and its document model should be like the following sample:
# ```json
# {'Station': 948701,
#   'Date': '2017-04-01',
#   'AirTemperature(Celcius)': 14,
#   'RelativeHumidity': 45.7,
#   'WindSpeed(knots)': 9.2,
#   'MaxWindSpeed': 15.9,
#   'MAX': '63.9*',
#   'MIN': '50.4',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.1948,
#     'Longitude': 145.7688,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-01T04:11:30',
#     'Power': 18.7,
#     'Confidence': 73,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 50}
# ```
#
# The fire data store in a list and embedded in the climate data.

# %% [markdown]
# **3. Write a python program that will read the data from Fire data-Part1 and Climate data - Part1 and load them to the new database created in Task B2.**

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pprint import pprint
import time
import multiprocessing as mp

# %%
# connect on the default host and port
client = MongoClient () 
db = client.TaskB_db
# drop collection in case duplicate
db.Combine.drop()
collection = db.Combine

# %%
# read csv as dataframe
climate = pd.read_csv('ClimateData-Part1.csv')
fire = pd.read_csv('FireData-Part1.csv')

# %%
# remove space
climate.columns = climate.columns.str.replace('\s+', '')
climate.replace('\s+', '',regex=True,inplace=True)

# %%
# transfer dataframe to dictionaries
climatelist = climate.to_dict('records')
firelist = fire.to_dict('records')

# %%
climatelist[1]
# Out:
# {'Station': 948700,
#  'Date': '2017-01-02',
#  'AirTemperature(Celcius)': 15,
#  'RelativeHumidity': 50.7,
#  'WindSpeed(knots)': 9.2,
#  'MaxWindSpeed': 13.0,
#  'MAX': '72.0*',
#  'MIN': '58.3',
#  'Precipitation': '0.02G',
#  'fire': [],
#  '_id': ObjectId('5b17eb16b3dbfe1420cdbc36')}

# %%
# Check data
firelist[1]
# Out:
# {'Latitude': -35.541,
#  'Longitude': 143.311,
#  'Surface Temperature (kelvin)': 336.3,
#  'Datetime': '2017-12-27T00:02:15',
#  'Power': 62.0,
#  'Confidence': 82,
#  'Date': '2017-12-27',
#  'Surface Temperature (Celcius)': 63}

# %%
# join two tables
for i,val in enumerate(climatelist):
    climatelist[i]['fire'] = []
    for fire in firelist:
        if climatelist[i]['Date'] == fire['Date']:
            templist = climatelist[i]['fire']
            templist.append(fire)
            climatelist[i]['fire'] = templist

# %%
# check results
climatelist[90:100]
# Out:
# [{'Station': 948701,
#   'Date': '2017-04-01',
#   'AirTemperature(Celcius)': 14,
#   'RelativeHumidity': 45.7,
#   'WindSpeed(knots)': 9.2,
#   'MaxWindSpeed': 15.9,
#   'MAX': '63.9*',
#   'MIN': '50.4',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.1948,
#     'Longitude': 145.7688,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-01T04:11:30',
#     'Power': 18.7,
#     'Confidence': 73,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.2721,
#     'Longitude': 146.847,
#     'Surface Temperature (kelvin)': 318.9,
#     'Datetime': '2017-04-01T04:09:20',
#     'Power': 20.2,
#     'Confidence': 70,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -36.1017,
#     'Longitude': 147.6381,
#     'Surface Temperature (kelvin)': 319.2,
#     'Datetime': '2017-04-01T04:04:50',
#     'Power': 21.6,
#     'Confidence': 71,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.1256,
#     'Longitude': 145.2444,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-01T04:02:50',
#     'Power': 24.0,
#     'Confidence': 77,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.2044,
#     'Longitude': 145.7706,
#     'Surface Temperature (kelvin)': 324.7,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 19.1,
#     'Confidence': 58,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.5245,
#     'Longitude': 143.1556,
#     'Surface Temperature (kelvin)': 316.5,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 12.3,
#     'Confidence': 57,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.1002,
#     'Longitude': 147.6494,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 14.8,
#     'Confidence': 50,
#     'Date': '2017-04-01',
#     'Surface Temperature (Celcius)': 39}]},
#  {'Station': 948701,
#   'Date': '2017-04-02',
#   'AirTemperature(Celcius)': 12,
#   'RelativeHumidity': 43.4,
#   'WindSpeed(knots)': 9.3,
#   'MaxWindSpeed': 15.0,
#   'MAX': '63.3*',
#   'MIN': '45.0*',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.3872,
#     'Longitude': 145.3858,
#     'Surface Temperature (kelvin)': 314.1,
#     'Datetime': '2017-04-02T04:53:30',
#     'Power': 11.1,
#     'Confidence': 60,
#     'Date': '2017-04-02',
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.6664,
#     'Longitude': 145.2554,
#     'Surface Temperature (kelvin)': 325.7,
#     'Datetime': '2017-04-02T04:51:40',
#     'Power': 24.4,
#     'Confidence': 79,
#     'Date': '2017-04-02',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.6688,
#     'Longitude': 145.2635,
#     'Surface Temperature (kelvin)': 321.0,
#     'Datetime': '2017-04-02T04:45:10',
#     'Power': 17.7,
#     'Confidence': 73,
#     'Date': '2017-04-02',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.494,
#     'Longitude': 145.4522,
#     'Surface Temperature (kelvin)': 315.0,
#     'Datetime': '2017-04-02T04:45:10',
#     'Power': 11.3,
#     'Confidence': 63,
#     'Date': '2017-04-02',
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.324,
#     'Longitude': 146.1647,
#     'Surface Temperature (kelvin)': 319.6,
#     'Datetime': '2017-04-02T00:24:50',
#     'Power': 23.2,
#     'Confidence': 60,
#     'Date': '2017-04-02',
#     'Surface Temperature (Celcius)': 46}]},
#  {'Station': 948701,
#   'Date': '2017-04-03',
#   'AirTemperature(Celcius)': 15,
#   'RelativeHumidity': 47.7,
#   'WindSpeed(knots)': 5.9,
#   'MaxWindSpeed': 13.0,
#   'MAX': '71.1*',
#   'MIN': '43',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.1141,
#     'Longitude': 141.6787,
#     'Surface Temperature (kelvin)': 310.8,
#     'Datetime': '2017-04-03T13:20:00',
#     'Power': 20.5,
#     'Confidence': 72,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 37},
#    {'Latitude': -37.8046,
#     'Longitude': 146.0304,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-03T13:17:00',
#     'Power': 26.2,
#     'Confidence': 91,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.9068,
#     'Longitude': 145.9047,
#     'Surface Temperature (kelvin)': 313.8,
#     'Datetime': '2017-04-03T13:15:30',
#     'Power': 23.7,
#     'Confidence': 83,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1156,
#     'Longitude': 141.6664,
#     'Surface Temperature (kelvin)': 335.7,
#     'Datetime': '2017-04-03T13:15:10',
#     'Power': 52.7,
#     'Confidence': 100,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.8064,
#     'Longitude': 146.0189,
#     'Surface Temperature (kelvin)': 318.5,
#     'Datetime': '2017-04-03T13:15:10',
#     'Power': 28.3,
#     'Confidence': 96,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.0221,
#     'Longitude': 141.5517,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-03T04:00:00',
#     'Power': 20.1,
#     'Confidence': 76,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3735,
#     'Longitude': 145.886,
#     'Surface Temperature (kelvin)': 369.2,
#     'Datetime': '2017-04-03T03:59:10',
#     'Power': 124.4,
#     'Confidence': 87,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 96},
#    {'Latitude': -37.5422,
#     'Longitude': 143.2276,
#     'Surface Temperature (kelvin)': 322.3,
#     'Datetime': '2017-04-03T03:58:20',
#     'Power': 17.4,
#     'Confidence': 75,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.7465,
#     'Longitude': 143.3806,
#     'Surface Temperature (kelvin)': 345.7,
#     'Datetime': '2017-04-03T03:57:50',
#     'Power': 55.0,
#     'Confidence': 93,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -37.3094,
#     'Longitude': 146.1945,
#     'Surface Temperature (kelvin)': 333.6,
#     'Datetime': '2017-04-03T03:56:40',
#     'Power': 39.8,
#     'Confidence': 77,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 60},
#    {'Latitude': -36.7199,
#     'Longitude': 141.3946,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-03T03:56:20',
#     'Power': 26.7,
#     'Confidence': 82,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7638,
#     'Longitude': 142.1215,
#     'Surface Temperature (kelvin)': 326.0,
#     'Datetime': '2017-04-03T03:56:20',
#     'Power': 18.1,
#     'Confidence': 79,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.1534,
#     'Longitude': 141.5948,
#     'Surface Temperature (kelvin)': 337.3,
#     'Datetime': '2017-04-03T03:55:10',
#     'Power': 38.1,
#     'Confidence': 88,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.8072,
#     'Longitude': 145.9738,
#     'Surface Temperature (kelvin)': 350.8,
#     'Datetime': '2017-04-03T03:55:10',
#     'Power': 75.9,
#     'Confidence': 95,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 77},
#    {'Latitude': -37.3704,
#     'Longitude': 145.8942,
#     'Surface Temperature (kelvin)': 351.6,
#     'Datetime': '2017-04-03T03:54:00',
#     'Power': 76.4,
#     'Confidence': 96,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -37.297,
#     'Longitude': 143.5753,
#     'Surface Temperature (kelvin)': 367.0,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 108.3,
#     'Confidence': 100,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 93},
#    {'Latitude': -36.9172,
#     'Longitude': 142.0472,
#     'Surface Temperature (kelvin)': 319.1,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 11.3,
#     'Confidence': 71,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.8668,
#     'Longitude': 143.0472,
#     'Surface Temperature (kelvin)': 318.0,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 14.4,
#     'Confidence': 69,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7602,
#     'Longitude': 143.382,
#     'Surface Temperature (kelvin)': 317.5,
#     'Datetime': '2017-04-03T03:53:40',
#     'Power': 12.7,
#     'Confidence': 68,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7529,
#     'Longitude': 143.3745,
#     'Surface Temperature (kelvin)': 332.5,
#     'Datetime': '2017-04-03T03:53:30',
#     'Power': 32.5,
#     'Confidence': 85,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -37.7885,
#     'Longitude': 142.9509,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-03T03:53:30',
#     'Power': 12.4,
#     'Confidence': 66,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -34.2714,
#     'Longitude': 141.6197,
#     'Surface Temperature (kelvin)': 321.7,
#     'Datetime': '2017-04-03T03:53:00',
#     'Power': 12.2,
#     'Confidence': 74,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.1698,
#     'Longitude': 142.0536,
#     'Surface Temperature (kelvin)': 331.2,
#     'Datetime': '2017-04-03T03:52:30',
#     'Power': 26.5,
#     'Confidence': 84,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.2988,
#     'Longitude': 143.5487,
#     'Surface Temperature (kelvin)': 363.3,
#     'Datetime': '2017-04-03T03:52:30',
#     'Power': 98.0,
#     'Confidence': 100,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 90},
#    {'Latitude': -37.3716,
#     'Longitude': 145.9065,
#     'Surface Temperature (kelvin)': 389.0,
#     'Datetime': '2017-04-03T03:52:20',
#     'Power': 203.8,
#     'Confidence': 100,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 115},
#    {'Latitude': -37.8662,
#     'Longitude': 143.251,
#     'Surface Temperature (kelvin)': 319.3,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 16.0,
#     'Confidence': 71,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.4291,
#     'Longitude': 141.2426,
#     'Surface Temperature (kelvin)': 334.6,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 33.3,
#     'Confidence': 86,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.2891,
#     'Longitude': 143.5697,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 18.7,
#     'Confidence': 76,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3025,
#     'Longitude': 143.5714,
#     'Surface Temperature (kelvin)': 372.0,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 124.9,
#     'Confidence': 100,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 98},
#    {'Latitude': -37.383,
#     'Longitude': 145.9089,
#     'Surface Temperature (kelvin)': 362.4,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 104.5,
#     'Confidence': 100,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -37.7216,
#     'Longitude': 143.4272,
#     'Surface Temperature (kelvin)': 332.8,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 33.0,
#     'Confidence': 85,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -37.8717,
#     'Longitude': 143.3652,
#     'Surface Temperature (kelvin)': 322.5,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 19.2,
#     'Confidence': 75,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.8717,
#     'Longitude': 143.2566,
#     'Surface Temperature (kelvin)': 316.5,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 13.0,
#     'Confidence': 66,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3851,
#     'Longitude': 145.8878,
#     'Surface Temperature (kelvin)': 336.5,
#     'Datetime': '2017-04-03T03:51:30',
#     'Power': 46.2,
#     'Confidence': 83,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.7446,
#     'Longitude': 143.4085,
#     'Surface Temperature (kelvin)': 339.4,
#     'Datetime': '2017-04-03T03:51:30',
#     'Power': 42.8,
#     'Confidence': 89,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.7159,
#     'Longitude': 141.3991,
#     'Surface Temperature (kelvin)': 322.5,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 17.7,
#     'Confidence': 75,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -35.7626,
#     'Longitude': 142.1167,
#     'Surface Temperature (kelvin)': 336.0,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 33.2,
#     'Confidence': 87,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.8011,
#     'Longitude': 144.7343,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 12.4,
#     'Confidence': 67,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.8777,
#     'Longitude': 143.371,
#     'Surface Temperature (kelvin)': 327.5,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 26.6,
#     'Confidence': 81,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.7509,
#     'Longitude': 143.4023,
#     'Surface Temperature (kelvin)': 355.9,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 79.3,
#     'Confidence': 98,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 82},
#    {'Latitude': -36.6085,
#     'Longitude': 142.4451,
#     'Surface Temperature (kelvin)': 326.7,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 20.9,
#     'Confidence': 80,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.3802,
#     'Longitude': 145.9147,
#     'Surface Temperature (kelvin)': 376.3,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 149.0,
#     'Confidence': 100,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 103},
#    {'Latitude': -37.7974,
#     'Longitude': 145.9535,
#     'Surface Temperature (kelvin)': 370.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 131.2,
#     'Confidence': 87,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 97},
#    {'Latitude': -37.0241,
#     'Longitude': 141.5163,
#     'Surface Temperature (kelvin)': 316.9,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 13.4,
#     'Confidence': 67,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.2912,
#     'Longitude': 143.543,
#     'Surface Temperature (kelvin)': 316.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 11.1,
#     'Confidence': 66,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.313,
#     'Longitude': 146.1561,
#     'Surface Temperature (kelvin)': 319.9,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 21.6,
#     'Confidence': 52,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -38.0226,
#     'Longitude': 143.6739,
#     'Surface Temperature (kelvin)': 312.8,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 10.1,
#     'Confidence': 56,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -35.7657,
#     'Longitude': 142.0906,
#     'Surface Temperature (kelvin)': 340.1,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 40.5,
#     'Confidence': 90,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -37.9029,
#     'Longitude': 143.5946,
#     'Surface Temperature (kelvin)': 320.6,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 16.8,
#     'Confidence': 73,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.9151,
#     'Longitude': 142.0798,
#     'Surface Temperature (kelvin)': 323.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 16.6,
#     'Confidence': 77,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.9112,
#     'Longitude': 143.6025,
#     'Surface Temperature (kelvin)': 334.2,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 34.9,
#     'Confidence': 85,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.8089,
#     'Longitude': 145.9555,
#     'Surface Temperature (kelvin)': 314.8,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 18.9,
#     'Confidence': 56,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.9009,
#     'Longitude': 143.6217,
#     'Surface Temperature (kelvin)': 318.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 14.3,
#     'Confidence': 62,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.7583,
#     'Longitude': 143.41,
#     'Surface Temperature (kelvin)': 318.6,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.8,
#     'Confidence': 70,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.7836,
#     'Longitude': 142.9437,
#     'Surface Temperature (kelvin)': 318.0,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 14.5,
#     'Confidence': 69,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7236,
#     'Longitude': 143.3995,
#     'Surface Temperature (kelvin)': 359.3,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 88.0,
#     'Confidence': 99,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 86},
#    {'Latitude': -37.5402,
#     'Longitude': 143.2559,
#     'Surface Temperature (kelvin)': 323.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 18.6,
#     'Confidence': 76,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3046,
#     'Longitude': 143.5448,
#     'Surface Temperature (kelvin)': 345.3,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 53.9,
#     'Confidence': 93,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -37.0484,
#     'Longitude': 141.6245,
#     'Surface Temperature (kelvin)': 315.8,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 10.5,
#     'Confidence': 52,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -36.911,
#     'Longitude': 142.1445,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.3,
#     'Confidence': 68,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.4312,
#     'Longitude': 141.2064,
#     'Surface Temperature (kelvin)': 349.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 61.7,
#     'Confidence': 95,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -36.1702,
#     'Longitude': 142.0586,
#     'Surface Temperature (kelvin)': 333.6,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 30.8,
#     'Confidence': 86,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 60},
#    {'Latitude': -36.1722,
#     'Longitude': 142.0266,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.3,
#     'Confidence': 73,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.1556,
#     'Longitude': 141.5904,
#     'Surface Temperature (kelvin)': 338.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 40.5,
#     'Confidence': 89,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -35.7598,
#     'Longitude': 143.851,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 12.0,
#     'Confidence': 72,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -35.7609,
#     'Longitude': 143.8442,
#     'Surface Temperature (kelvin)': 328.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 23.0,
#     'Confidence': 82,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7647,
#     'Longitude': 142.0858,
#     'Surface Temperature (kelvin)': 338.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 37.5,
#     'Confidence': 89,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -34.2536,
#     'Longitude': 141.6199,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-03T01:11:00',
#     'Power': 13.8,
#     'Confidence': 67,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2674,
#     'Longitude': 141.6183,
#     'Surface Temperature (kelvin)': 324.2,
#     'Datetime': '2017-04-03T01:10:50',
#     'Power': 19.5,
#     'Confidence': 77,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.7885,
#     'Longitude': 142.1258,
#     'Surface Temperature (kelvin)': 319.5,
#     'Datetime': '2017-04-03T01:07:30',
#     'Power': 16.4,
#     'Confidence': 71,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2594,
#     'Longitude': 141.6139,
#     'Surface Temperature (kelvin)': 327.7,
#     'Datetime': '2017-04-03T01:07:20',
#     'Power': 24.6,
#     'Confidence': 81,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -34.2614,
#     'Longitude': 141.6412,
#     'Surface Temperature (kelvin)': 317.0,
#     'Datetime': '2017-04-03T01:07:00',
#     'Power': 11.0,
#     'Confidence': 57,
#     'Date': '2017-04-03',
#     'Surface Temperature (Celcius)': 43}]},
#  {'Station': 948701,
#   'Date': '2017-04-04',
#   'AirTemperature(Celcius)': 16,
#   'RelativeHumidity': 47.5,
#   'WindSpeed(knots)': 5.4,
#   'MaxWindSpeed': 12.0,
#   'MAX': '73.4*',
#   'MIN': '46.8',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -37.2162,
#     'Longitude': 146.2408,
#     'Surface Temperature (kelvin)': 311.8,
#     'Datetime': '2017-04-04T15:33:40',
#     'Power': 20.0,
#     'Confidence': 76,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.086999999999996,
#     'Longitude': 141.7227,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-04T15:31:00',
#     'Power': 27.5,
#     'Confidence': 93,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -36.0933,
#     'Longitude': 141.7154,
#     'Surface Temperature (kelvin)': 308.8,
#     'Datetime': '2017-04-04T15:30:40',
#     'Power': 19.7,
#     'Confidence': 63,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -36.0852,
#     'Longitude': 141.7112,
#     'Surface Temperature (kelvin)': 337.2,
#     'Datetime': '2017-04-04T15:30:40',
#     'Power': 55.7,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -36.3194,
#     'Longitude': 141.7531,
#     'Surface Temperature (kelvin)': 337.1,
#     'Datetime': '2017-04-04T04:41:50',
#     'Power': 34.5,
#     'Confidence': 88,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.3601,
#     'Longitude': 145.8519,
#     'Surface Temperature (kelvin)': 335.3,
#     'Datetime': '2017-04-04T04:41:10',
#     'Power': 44.8,
#     'Confidence': 82,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.1598,
#     'Longitude': 141.8841,
#     'Surface Temperature (kelvin)': 337.7,
#     'Datetime': '2017-04-04T04:41:00',
#     'Power': 35.0,
#     'Confidence': 88,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -36.6936,
#     'Longitude': 145.2788,
#     'Surface Temperature (kelvin)': 334.4,
#     'Datetime': '2017-04-04T04:41:00',
#     'Power': 35.9,
#     'Confidence': 86,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.1057,
#     'Longitude': 141.7608,
#     'Surface Temperature (kelvin)': 393.8,
#     'Datetime': '2017-04-04T04:40:00',
#     'Power': 212.5,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 120},
#    {'Latitude': -35.4033,
#     'Longitude': 143.267,
#     'Surface Temperature (kelvin)': 340.4,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 40.3,
#     'Confidence': 90,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 67},
#    {'Latitude': -36.6281,
#     'Longitude': 142.4349,
#     'Surface Temperature (kelvin)': 341.6,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 51.0,
#     'Confidence': 64,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 68},
#    {'Latitude': -36.111,
#     'Longitude': 145.124,
#     'Surface Temperature (kelvin)': 340.0,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 46.0,
#     'Confidence': 85,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.1615,
#     'Longitude': 141.8728,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 37.9,
#     'Confidence': 90,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -37.3074,
#     'Longitude': 142.9925,
#     'Surface Temperature (kelvin)': 328.1,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 31.4,
#     'Confidence': 81,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.937,
#     'Longitude': 142.1176,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 22.9,
#     'Confidence': 61,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -38.1868,
#     'Longitude': 143.0938,
#     'Surface Temperature (kelvin)': 318.9,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 22.6,
#     'Confidence': 70,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -35.2601,
#     'Longitude': 143.1931,
#     'Surface Temperature (kelvin)': 324.1,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 15.2,
#     'Confidence': 77,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.1849,
#     'Longitude': 145.9109,
#     'Surface Temperature (kelvin)': 381.0,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 155.3,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 107},
#    {'Latitude': -37.2109,
#     'Longitude': 142.7966,
#     'Surface Temperature (kelvin)': 325.5,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 27.6,
#     'Confidence': 74,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.6951,
#     'Longitude': 145.424,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-04T04:38:10',
#     'Power': 12.2,
#     'Confidence': 50,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.1376,
#     'Longitude': 145.84,
#     'Surface Temperature (kelvin)': 329.0,
#     'Datetime': '2017-04-04T04:37:30',
#     'Power': 27.2,
#     'Confidence': 76,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.6965,
#     'Longitude': 142.7116,
#     'Surface Temperature (kelvin)': 337.9,
#     'Datetime': '2017-04-04T04:37:10',
#     'Power': 40.1,
#     'Confidence': 88,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.0753,
#     'Longitude': 141.0532,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-04T04:36:40',
#     'Power': 22.1,
#     'Confidence': 79,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -37.6714,
#     'Longitude': 144.2154,
#     'Surface Temperature (kelvin)': 319.6,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 20.6,
#     'Confidence': 67,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.4465,
#     'Longitude': 143.5163,
#     'Surface Temperature (kelvin)': 324.1,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 27.7,
#     'Confidence': 70,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -38.0494,
#     'Longitude': 143.9141,
#     'Surface Temperature (kelvin)': 331.5,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 38.7,
#     'Confidence': 63,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -38.1356,
#     'Longitude': 143.7098,
#     'Surface Temperature (kelvin)': 323.6,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 28.0,
#     'Confidence': 72,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3632,
#     'Longitude': 145.8356,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 32.9,
#     'Confidence': 75,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.6078,
#     'Longitude': 141.9742,
#     'Surface Temperature (kelvin)': 336.7,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 36.9,
#     'Confidence': 88,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.3765,
#     'Longitude': 145.8221,
#     'Surface Temperature (kelvin)': 335.4,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 47.2,
#     'Confidence': 87,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.0694,
#     'Longitude': 141.5717,
#     'Surface Temperature (kelvin)': 327.3,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 19.4,
#     'Confidence': 72,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.1122,
#     'Longitude': 142.1491,
#     'Surface Temperature (kelvin)': 349.4,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 61.2,
#     'Confidence': 90,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -36.400999999999996,
#     'Longitude': 145.5113,
#     'Surface Temperature (kelvin)': 328.5,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 26.7,
#     'Confidence': 77,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -37.9048,
#     'Longitude': 145.7738,
#     'Surface Temperature (kelvin)': 322.8,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 29.8,
#     'Confidence': 76,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.3735,
#     'Longitude': 145.8384,
#     'Surface Temperature (kelvin)': 368.4,
#     'Datetime': '2017-04-04T04:35:00',
#     'Power': 125.0,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 95},
#    {'Latitude': -35.4128,
#     'Longitude': 143.2693,
#     'Surface Temperature (kelvin)': 330.8,
#     'Datetime': '2017-04-04T04:34:50',
#     'Power': 24.1,
#     'Confidence': 83,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.8848,
#     'Longitude': 142.1523,
#     'Surface Temperature (kelvin)': 324.4,
#     'Datetime': '2017-04-04T04:34:30',
#     'Power': 19.9,
#     'Confidence': 70,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -35.4255,
#     'Longitude': 143.6306,
#     'Surface Temperature (kelvin)': 338.8,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 42.8,
#     'Confidence': 89,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -36.1198,
#     'Longitude': 145.6369,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 20.6,
#     'Confidence': 79,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -38.4879,
#     'Longitude': 143.9971,
#     'Surface Temperature (kelvin)': 313.6,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 17.3,
#     'Confidence': 54,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1955,
#     'Longitude': 145.914,
#     'Surface Temperature (kelvin)': 351.3,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 63.0,
#     'Confidence': 96,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -35.4533,
#     'Longitude': 143.2029,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 40.4,
#     'Confidence': 85,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -35.4993,
#     'Longitude': 143.3105,
#     'Surface Temperature (kelvin)': 331.1,
#     'Datetime': '2017-04-04T04:34:00',
#     'Power': 23.5,
#     'Confidence': 84,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.5989,
#     'Longitude': 141.9771,
#     'Surface Temperature (kelvin)': 354.4,
#     'Datetime': '2017-04-04T04:33:50',
#     'Power': 76.1,
#     'Confidence': 92,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 81},
#    {'Latitude': -37.4485,
#     'Longitude': 143.5041,
#     'Surface Temperature (kelvin)': 328.0,
#     'Datetime': '2017-04-04T04:33:40',
#     'Power': 32.9,
#     'Confidence': 81,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.1744,
#     'Longitude': 143.9256,
#     'Surface Temperature (kelvin)': 316.8,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 15.2,
#     'Confidence': 63,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.104,
#     'Longitude': 141.77200000000002,
#     'Surface Temperature (kelvin)': 386.7,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 178.1,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 113},
#    {'Latitude': -36.4918,
#     'Longitude': 142.2465,
#     'Surface Temperature (kelvin)': 328.0,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 25.9,
#     'Confidence': 69,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6663,
#     'Longitude': 143.2603,
#     'Surface Temperature (kelvin)': 332.0,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 36.4,
#     'Confidence': 80,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -36.0189,
#     'Longitude': 145.6844,
#     'Surface Temperature (kelvin)': 322.7,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 16.8,
#     'Confidence': 75,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -35.7523,
#     'Longitude': 143.8866,
#     'Surface Temperature (kelvin)': 333.1,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 31.7,
#     'Confidence': 85,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -36.6538,
#     'Longitude': 142.7552,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-04T04:33:20',
#     'Power': 24.5,
#     'Confidence': 72,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.6299,
#     'Longitude': 142.4234,
#     'Surface Temperature (kelvin)': 345.0,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 56.3,
#     'Confidence': 66,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 71},
#    {'Latitude': -36.0994,
#     'Longitude': 143.4156,
#     'Surface Temperature (kelvin)': 335.4,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 38.8,
#     'Confidence': 82,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.8395,
#     'Longitude': 142.2188,
#     'Surface Temperature (kelvin)': 336.1,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 36.7,
#     'Confidence': 82,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.9294,
#     'Longitude': 142.7087,
#     'Surface Temperature (kelvin)': 324.6,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 21.9,
#     'Confidence': 78,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.1439,
#     'Longitude': 145.832,
#     'Surface Temperature (kelvin)': 323.5,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 19.3,
#     'Confidence': 53,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.1925,
#     'Longitude': 145.93,
#     'Surface Temperature (kelvin)': 353.0,
#     'Datetime': '2017-04-04T04:33:00',
#     'Power': 68.2,
#     'Confidence': 97,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 79},
#    {'Latitude': -37.8351,
#     'Longitude': 145.9789,
#     'Surface Temperature (kelvin)': 334.2,
#     'Datetime': '2017-04-04T04:33:00',
#     'Power': 44.9,
#     'Confidence': 86,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.095,
#     'Longitude': 141.7699,
#     'Surface Temperature (kelvin)': 356.1,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 74.0,
#     'Confidence': 98,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 82},
#    {'Latitude': -36.7848,
#     'Longitude': 141.9044,
#     'Surface Temperature (kelvin)': 334.6,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 34.6,
#     'Confidence': 85,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.6962,
#     'Longitude': 145.2642,
#     'Surface Temperature (kelvin)': 331.9,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 31.7,
#     'Confidence': 84,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.1089,
#     'Longitude': 143.0783,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 29.3,
#     'Confidence': 82,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.7009,
#     'Longitude': 141.541,
#     'Surface Temperature (kelvin)': 323.0,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 18.6,
#     'Confidence': 54,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.4604,
#     'Longitude': 142.1623,
#     'Surface Temperature (kelvin)': 321.4,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 19.6,
#     'Confidence': 70,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.343,
#     'Longitude': 142.1986,
#     'Surface Temperature (kelvin)': 396.3,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 233.4,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 123},
#    {'Latitude': -36.2906,
#     'Longitude': 141.75799999999998,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 23.0,
#     'Confidence': 82,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.114000000000004,
#     'Longitude': 142.1377,
#     'Surface Temperature (kelvin)': 391.2,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 202.8,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 118},
#    {'Latitude': -37.5436,
#     'Longitude': 143.6122,
#     'Surface Temperature (kelvin)': 327.4,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 38.2,
#     'Confidence': 80,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6006,
#     'Longitude': 141.9657,
#     'Surface Temperature (kelvin)': 351.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 69.1,
#     'Confidence': 96,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -36.4611,
#     'Longitude': 143.14600000000002,
#     'Surface Temperature (kelvin)': 321.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 19.4,
#     'Confidence': 55,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -37.0769,
#     'Longitude': 141.042,
#     'Surface Temperature (kelvin)': 346.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 56.5,
#     'Confidence': 93,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -36.3521,
#     'Longitude': 142.2008,
#     'Surface Temperature (kelvin)': 394.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 218.7,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 120},
#    {'Latitude': -36.3539,
#     'Longitude': 142.1894,
#     'Surface Temperature (kelvin)': 327.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 23.5,
#     'Confidence': 53,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.883,
#     'Longitude': 142.1637,
#     'Surface Temperature (kelvin)': 341.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 45.2,
#     'Confidence': 79,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 67},
#    {'Latitude': -36.0973,
#     'Longitude': 143.4279,
#     'Surface Temperature (kelvin)': 365.8,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 108.2,
#     'Confidence': 87,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 92},
#    {'Latitude': -36.7722,
#     'Longitude': 141.5514,
#     'Surface Temperature (kelvin)': 331.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 29.5,
#     'Confidence': 79,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.0081,
#     'Longitude': 141.7654,
#     'Surface Temperature (kelvin)': 335.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 38.0,
#     'Confidence': 66,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.0967,
#     'Longitude': 141.7587,
#     'Surface Temperature (kelvin)': 374.3,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 129.4,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 101},
#    {'Latitude': -36.4204,
#     'Longitude': 141.3765,
#     'Surface Temperature (kelvin)': 330.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 27.2,
#     'Confidence': 73,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.2889,
#     'Longitude': 141.7692,
#     'Surface Temperature (kelvin)': 324.4,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.6,
#     'Confidence': 64,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -35.4439,
#     'Longitude': 143.2005,
#     'Surface Temperature (kelvin)': 327.5,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 20.5,
#     'Confidence': 74,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6228,
#     'Longitude': 142.428,
#     'Surface Temperature (kelvin)': 317.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.0,
#     'Confidence': 67,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.2205,
#     'Longitude': 141.7933,
#     'Surface Temperature (kelvin)': 327.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 18.8,
#     'Confidence': 81,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -38.1177,
#     'Longitude': 143.6409,
#     'Surface Temperature (kelvin)': 314.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.4,
#     'Confidence': 60,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1819,
#     'Longitude': 145.9269,
#     'Surface Temperature (kelvin)': 372.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 122.4,
#     'Confidence': 100,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 98},
#    {'Latitude': -35.4594,
#     'Longitude': 143.7125,
#     'Surface Temperature (kelvin)': 319.9,
#     'Datetime': '2017-04-04T00:14:30',
#     'Power': 17.1,
#     'Confidence': 72,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2708,
#     'Longitude': 141.6158,
#     'Surface Temperature (kelvin)': 326.0,
#     'Datetime': '2017-04-04T00:12:50',
#     'Power': 22.4,
#     'Confidence': 79,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.4616,
#     'Longitude': 143.7251,
#     'Surface Temperature (kelvin)': 326.7,
#     'Datetime': '2017-04-04T00:12:50',
#     'Power': 26.0,
#     'Confidence': 80,
#     'Date': '2017-04-04',
#     'Surface Temperature (Celcius)': 53}]},
#  {'Station': 948701,
#   'Date': '2017-04-05',
#   'AirTemperature(Celcius)': 17,
#   'RelativeHumidity': 47.2,
#   'WindSpeed(knots)': 4.9,
#   'MaxWindSpeed': 13.0,
#   'MAX': '76.8*',
#   'MIN': '47.1',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -38.3499,
#     'Longitude': 147.033,
#     'Surface Temperature (kelvin)': 308.5,
#     'Datetime': '2017-04-05T13:10:10',
#     'Power': 19.0,
#     'Confidence': 61,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -38.2003,
#     'Longitude': 146.8378,
#     'Surface Temperature (kelvin)': 331.8,
#     'Datetime': '2017-04-05T13:09:00',
#     'Power': 45.3,
#     'Confidence': 100,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.4583,
#     'Longitude': 148.2459,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-05T13:09:00',
#     'Power': 21.5,
#     'Confidence': 81,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.6784,
#     'Longitude': 146.1432,
#     'Surface Temperature (kelvin)': 317.3,
#     'Datetime': '2017-04-05T13:08:40',
#     'Power': 27.2,
#     'Confidence': 93,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.4492,
#     'Longitude': 148.2438,
#     'Surface Temperature (kelvin)': 320.4,
#     'Datetime': '2017-04-05T13:08:40',
#     'Power': 29.6,
#     'Confidence': 100,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -38.2153,
#     'Longitude': 146.8652,
#     'Surface Temperature (kelvin)': 313.3,
#     'Datetime': '2017-04-05T13:07:00',
#     'Power': 22.2,
#     'Confidence': 82,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.7652,
#     'Longitude': 147.1289,
#     'Surface Temperature (kelvin)': 312.4,
#     'Datetime': '2017-04-05T13:06:30',
#     'Power': 20.3,
#     'Confidence': 78,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -35.6922,
#     'Longitude': 143.1619,
#     'Surface Temperature (kelvin)': 322.2,
#     'Datetime': '2017-04-05T13:04:20',
#     'Power': 32.3,
#     'Confidence': 100,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -38.2094,
#     'Longitude': 146.8398,
#     'Surface Temperature (kelvin)': 328.2,
#     'Datetime': '2017-04-05T13:03:20',
#     'Power': 39.6,
#     'Confidence': 100,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.2464,
#     'Longitude': 141.1143,
#     'Surface Temperature (kelvin)': 319.1,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 29.1,
#     'Confidence': 98,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -38.2078,
#     'Longitude': 146.8515,
#     'Surface Temperature (kelvin)': 328.9,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 40.9,
#     'Confidence': 100,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7024,
#     'Longitude': 143.1637,
#     'Surface Temperature (kelvin)': 313.0,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 22.0,
#     'Confidence': 81,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -38.3483,
#     'Longitude': 147.0446,
#     'Surface Temperature (kelvin)': 310.3,
#     'Datetime': '2017-04-05T13:02:50',
#     'Power': 20.4,
#     'Confidence': 70,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 37},
#    {'Latitude': -37.4015,
#     'Longitude': 145.5947,
#     'Surface Temperature (kelvin)': 315.5,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 24.2,
#     'Confidence': 88,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -38.2169,
#     'Longitude': 146.8535,
#     'Surface Temperature (kelvin)': 312.9,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 21.5,
#     'Confidence': 80,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.6435,
#     'Longitude': 146.1417,
#     'Surface Temperature (kelvin)': 309.5,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 19.7,
#     'Confidence': 66,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 36},
#    {'Latitude': -37.6387,
#     'Longitude': 142.9032,
#     'Surface Temperature (kelvin)': 361.8,
#     'Datetime': '2017-04-05T05:16:50',
#     'Power': 99.8,
#     'Confidence': 87,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 88},
#    {'Latitude': -38.0045,
#     'Longitude': 143.9075,
#     'Surface Temperature (kelvin)': 337.4,
#     'Datetime': '2017-04-05T05:15:50',
#     'Power': 43.5,
#     'Confidence': 77,
#     'Date': '2017-04-05',
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.7522,
#     'Longitude': 142.3183,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-05T05:15:40',
#     'Power': 22.1,
# ...
#     'Datetime': '2017-04-06T00:06:10',
#     'Power': 19.2,
#     'Confidence': 73,
#     'Date': '2017-04-06',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -35.4625,
#     'Longitude': 143.1486,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-06T00:03:50',
#     'Power': 11.3,
#     'Confidence': 67,
#     'Date': '2017-04-06',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -38.0942,
#     'Longitude': 146.9603,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-06T00:01:40',
#     'Power': 11.3,
#     'Confidence': 52,
#     'Date': '2017-04-06',
#     'Surface Temperature (Celcius)': 39}]},
#  {'Station': 948701,
#   'Date': '2017-04-07',
#   'AirTemperature(Celcius)': 21,
#   'RelativeHumidity': 47.0,
#   'WindSpeed(knots)': 13.2,
#   'MaxWindSpeed': 20.0,
#   'MAX': '78.3*',
#   'MIN': '56.7',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.7394,
#     'Longitude': 147.1366,
#     'Surface Temperature (kelvin)': 317.6,
#     'Datetime': '2017-04-07T12:58:30',
#     'Power': 25.1,
#     'Confidence': 78,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.3257,
#     'Longitude': 149.1209,
#     'Surface Temperature (kelvin)': 314.5,
#     'Datetime': '2017-04-07T12:56:50',
#     'Power': 22.4,
#     'Confidence': 85,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3176,
#     'Longitude': 149.3776,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 22.4,
#     'Confidence': 76,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.7507,
#     'Longitude': 147.1308,
#     'Surface Temperature (kelvin)': 312.7,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 19.0,
#     'Confidence': 80,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.3268,
#     'Longitude': 149.3795,
#     'Surface Temperature (kelvin)': 322.3,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 27.0,
#     'Confidence': 94,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.7606,
#     'Longitude': 147.1326,
#     'Surface Temperature (kelvin)': 314.5,
#     'Datetime': '2017-04-07T12:54:00',
#     'Power': 20.5,
#     'Confidence': 75,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -35.6961,
#     'Longitude': 143.1935,
#     'Surface Temperature (kelvin)': 308.5,
#     'Datetime': '2017-04-07T12:53:40',
#     'Power': 16.6,
#     'Confidence': 61,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -37.3252,
#     'Longitude': 149.3911,
#     'Surface Temperature (kelvin)': 314.6,
#     'Datetime': '2017-04-07T12:53:40',
#     'Power': 20.0,
#     'Confidence': 86,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3314,
#     'Longitude': 149.1283,
#     'Surface Temperature (kelvin)': 309.1,
#     'Datetime': '2017-04-07T12:52:10',
#     'Power': 15.8,
#     'Confidence': 65,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -36.3477,
#     'Longitude': 144.533,
#     'Surface Temperature (kelvin)': 314.8,
#     'Datetime': '2017-04-07T12:52:10',
#     'Power': 24.4,
#     'Confidence': 86,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3191,
#     'Longitude': 149.366,
#     'Surface Temperature (kelvin)': 318.8,
#     'Datetime': '2017-04-07T12:51:20',
#     'Power': 25.7,
#     'Confidence': 97,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.3359,
#     'Longitude': 149.3816,
#     'Surface Temperature (kelvin)': 321.3,
#     'Datetime': '2017-04-07T12:51:20',
#     'Power': 24.0,
#     'Confidence': 51,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -37.3526,
#     'Longitude': 149.3972,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T12:51:00',
#     'Power': 20.6,
#     'Confidence': 66,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.7408,
#     'Longitude': 147.1243,
#     'Surface Temperature (kelvin)': 322.6,
#     'Datetime': '2017-04-07T12:51:00',
#     'Power': 30.5,
#     'Confidence': 100,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.762,
#     'Longitude': 147.12,
#     'Surface Temperature (kelvin)': 316.9,
#     'Datetime': '2017-04-07T12:50:50',
#     'Power': 23.1,
#     'Confidence': 92,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3344,
#     'Longitude': 149.3933,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 24.7,
#     'Confidence': 68,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.3283,
#     'Longitude': 149.368,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 21.5,
#     'Confidence': 74,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3511,
#     'Longitude': 149.4088,
#     'Surface Temperature (kelvin)': 319.5,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 24.2,
#     'Confidence': 61,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.3085,
#     'Longitude': 149.3756,
#     'Surface Temperature (kelvin)': 311.8,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 18.7,
#     'Confidence': 76,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.7508,
#     'Longitude': 147.1254,
#     'Surface Temperature (kelvin)': 312.4,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 19.2,
#     'Confidence': 66,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -36.7309,
#     'Longitude': 147.1227,
#     'Surface Temperature (kelvin)': 315.8,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 23.3,
#     'Confidence': 89,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -37.8361,
#     'Longitude': 142.7482,
#     'Surface Temperature (kelvin)': 327.3,
#     'Datetime': '2017-04-07T05:09:50',
#     'Power': 25.3,
#     'Confidence': 80,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.8277,
#     'Longitude': 142.7498,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-07T05:04:00',
#     'Power': 15.1,
#     'Confidence': 72,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.1031,
#     'Longitude': 143.0782,
#     'Surface Temperature (kelvin)': 318.4,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 12.6,
#     'Confidence': 63,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -36.1025,
#     'Longitude': 143.0825,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 11.1,
#     'Confidence': 66,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.701,
#     'Longitude': 141.6351,
#     'Surface Temperature (kelvin)': 326.5,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 19.7,
#     'Confidence': 80,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.7034,
#     'Longitude': 141.6168,
#     'Surface Temperature (kelvin)': 319.3,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 11.0,
#     'Confidence': 71,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.698,
#     'Longitude': 141.6416,
#     'Surface Temperature (kelvin)': 328.1,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 22.4,
#     'Confidence': 81,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.7054,
#     'Longitude': 141.6708,
#     'Surface Temperature (kelvin)': 322.0,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 15.0,
#     'Confidence': 75,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.6999,
#     'Longitude': 141.6955,
#     'Surface Temperature (kelvin)': 325.6,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 20.3,
#     'Confidence': 79,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.7314,
#     'Longitude': 141.8698,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 10.5,
#     'Confidence': 67,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7931,
#     'Longitude': 148.385,
#     'Surface Temperature (kelvin)': 331.6,
#     'Datetime': '2017-04-07T03:31:40',
#     'Power': 33.8,
#     'Confidence': 64,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.2168,
#     'Longitude': 147.4748,
#     'Surface Temperature (kelvin)': 362.7,
#     'Datetime': '2017-04-07T03:31:40',
#     'Power': 106.5,
#     'Confidence': 100,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -37.222,
#     'Longitude': 147.4689,
#     'Surface Temperature (kelvin)': 352.0,
#     'Datetime': '2017-04-07T03:28:20',
#     'Power': 79.2,
#     'Confidence': 96,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -37.7974,
#     'Longitude': 148.5498,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-07T03:27:50',
#     'Power': 28.8,
#     'Confidence': 60,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.2063,
#     'Longitude': 147.4713,
#     'Surface Temperature (kelvin)': 343.6,
#     'Datetime': '2017-04-07T03:27:30',
#     'Power': 61.1,
#     'Confidence': 92,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 70},
#    {'Latitude': -37.2082,
#     'Longitude': 147.4368,
#     'Surface Temperature (kelvin)': 343.9,
#     'Datetime': '2017-04-07T03:27:20',
#     'Power': 62.6,
#     'Confidence': 92,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 70},
#    {'Latitude': -37.224000000000004,
#     'Longitude': 147.4347,
#     'Surface Temperature (kelvin)': 349.5,
#     'Datetime': '2017-04-07T03:27:20',
#     'Power': 74.4,
#     'Confidence': 95,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -37.2185,
#     'Longitude': 147.4402,
#     'Surface Temperature (kelvin)': 379.4,
#     'Datetime': '2017-04-07T03:27:10',
#     'Power': 163.7,
#     'Confidence': 100,
#     'Date': '2017-04-07',
#     'Surface Temperature (Celcius)': 106}]},
#  {'Station': 948701,
#   'Date': '2017-04-08',
#   'AirTemperature(Celcius)': 19,
#   'RelativeHumidity': 52.8,
#   'WindSpeed(knots)': 12.5,
#   'MaxWindSpeed': 21.0,
#   'MAX': '81.9*',
#   'MIN': '54.3*',
#   'Precipitation': '0.47G',
#   'fire': [{'Latitude': -37.34,
#     'Longitude': 149.3668,
#     'Surface Temperature (kelvin)': 347.6,
#     'Datetime': '2017-04-08T04:15:20',
#     'Power': 61.2,
#     'Confidence': 67,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 74},
#    {'Latitude': -37.8567,
#     'Longitude': 147.1576,
#     'Surface Temperature (kelvin)': 321.4,
#     'Datetime': '2017-04-08T04:14:40',
#     'Power': 19.9,
#     'Confidence': 62,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.7287,
#     'Longitude': 142.6017,
#     'Surface Temperature (kelvin)': 359.1,
#     'Datetime': '2017-04-08T04:14:00',
#     'Power': 82.1,
#     'Confidence': 99,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 85},
#    {'Latitude': -35.2363,
#     'Longitude': 143.0004,
#     'Surface Temperature (kelvin)': 342.5,
#     'Datetime': '2017-04-08T04:12:50',
#     'Power': 43.9,
#     'Confidence': 91,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 69},
#    {'Latitude': -37.4368,
#     'Longitude': 149.1191,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-08T04:12:20',
#     'Power': 28.0,
#     'Confidence': 56,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.2378,
#     'Longitude': 142.9864,
#     'Surface Temperature (kelvin)': 367.5,
#     'Datetime': '2017-04-08T04:12:20',
#     'Power': 106.2,
#     'Confidence': 100,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 94},
#    {'Latitude': -35.2397,
#     'Longitude': 142.98,
#     'Surface Temperature (kelvin)': 332.4,
#     'Datetime': '2017-04-08T04:12:00',
#     'Power': 25.4,
#     'Confidence': 80,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -36.2115,
#     'Longitude': 141.6878,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-08T04:11:50',
#     'Power': 15.3,
#     'Confidence': 77,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.9408,
#     'Longitude': 146.0611,
#     'Surface Temperature (kelvin)': 320.7,
#     'Datetime': '2017-04-08T04:11:40',
#     'Power': 19.7,
#     'Confidence': 58,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.6994,
#     'Longitude': 146.2162,
#     'Surface Temperature (kelvin)': 314.0,
#     'Datetime': '2017-04-08T04:09:20',
#     'Power': 16.3,
#     'Confidence': 59,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.2726,
#     'Longitude': 145.506,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-08T04:09:00',
#     'Power': 21.6,
#     'Confidence': 77,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -35.2381,
#     'Longitude': 142.994,
#     'Surface Temperature (kelvin)': 357.1,
#     'Datetime': '2017-04-08T04:08:50',
#     'Power': 75.9,
#     'Confidence': 98,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 83},
#    {'Latitude': -36.7199,
#     'Longitude': 142.5844,
#     'Surface Temperature (kelvin)': 329.9,
#     'Datetime': '2017-04-08T04:08:50',
#     'Power': 23.1,
#     'Confidence': 63,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 56},
#    {'Latitude': -37.3493,
#     'Longitude': 149.3691,
#     'Surface Temperature (kelvin)': 353.4,
#     'Datetime': '2017-04-08T04:08:40',
#     'Power': 73.1,
#     'Confidence': 66,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 80},
#    {'Latitude': -37.6447,
#     'Longitude': 148.6039,
#     'Surface Temperature (kelvin)': 323.7,
#     'Datetime': '2017-04-08T04:08:40',
#     'Power': 27.5,
#     'Confidence': 61,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.7165,
#     'Longitude': 142.6155,
#     'Surface Temperature (kelvin)': 340.1,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 39.6,
#     'Confidence': 90,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.7076,
#     'Longitude': 142.5982,
#     'Surface Temperature (kelvin)': 320.6,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 11.6,
#     'Confidence': 73,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.5652,
#     'Longitude': 145.5105,
#     'Surface Temperature (kelvin)': 327.2,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 23.3,
#     'Confidence': 80,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.7009,
#     'Longitude': 146.2046,
#     'Surface Temperature (kelvin)': 326.6,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 31.7,
#     'Confidence': 80,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.4023,
#     'Longitude': 145.7705,
#     'Surface Temperature (kelvin)': 332.0,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 29.0,
#     'Confidence': 80,
#     'Date': '2017-04-08',
#     'Surface Temperature (Celcius)': 58}]},
#  {'Station': 948701,
#   'Date': '2017-04-09',
#   'AirTemperature(Celcius)': 11,
#   'RelativeHumidity': 48.2,
#   'WindSpeed(knots)': 10.8,
#   'MaxWindSpeed': 22.9,
#   'MAX': '59.7*',
#   'MIN': '46.8*',
#   'Precipitation': '0.59G',
#   'fire': []},
#  {'Station': 948701,
#   'Date': '2017-04-10',
#   'AirTemperature(Celcius)': 14,
#   'RelativeHumidity': 50.4,
#   'WindSpeed(knots)': 12.8,
#   'MaxWindSpeed': 20.0,
#   'MAX': '62.4*',
#   'MIN': '46.8',
#   'Precipitation': '0.01G',
#   'fire': []}]

# %%
# drop unnecessary field 
for i in range(len(climatelist)):
    for j in range(len(climatelist[i]['fire'])):
        del climatelist[i]['fire'][j]['Date']

# %%
# Check results
climatelist[90:100]
# Out:
# [{'Station': 948701,
#   'Date': '2017-04-01',
#   'AirTemperature(Celcius)': 14,
#   'RelativeHumidity': 45.7,
#   'WindSpeed(knots)': 9.2,
#   'MaxWindSpeed': 15.9,
#   'MAX': '63.9*',
#   'MIN': '50.4',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.1948,
#     'Longitude': 145.7688,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-01T04:11:30',
#     'Power': 18.7,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.2721,
#     'Longitude': 146.847,
#     'Surface Temperature (kelvin)': 318.9,
#     'Datetime': '2017-04-01T04:09:20',
#     'Power': 20.2,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -36.1017,
#     'Longitude': 147.6381,
#     'Surface Temperature (kelvin)': 319.2,
#     'Datetime': '2017-04-01T04:04:50',
#     'Power': 21.6,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.1256,
#     'Longitude': 145.2444,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-01T04:02:50',
#     'Power': 24.0,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.2044,
#     'Longitude': 145.7706,
#     'Surface Temperature (kelvin)': 324.7,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 19.1,
#     'Confidence': 58,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.5245,
#     'Longitude': 143.1556,
#     'Surface Temperature (kelvin)': 316.5,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 12.3,
#     'Confidence': 57,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.1002,
#     'Longitude': 147.6494,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 14.8,
#     'Confidence': 50,
#     'Surface Temperature (Celcius)': 39}]},
#  {'Station': 948701,
#   'Date': '2017-04-02',
#   'AirTemperature(Celcius)': 12,
#   'RelativeHumidity': 43.4,
#   'WindSpeed(knots)': 9.3,
#   'MaxWindSpeed': 15.0,
#   'MAX': '63.3*',
#   'MIN': '45.0*',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.3872,
#     'Longitude': 145.3858,
#     'Surface Temperature (kelvin)': 314.1,
#     'Datetime': '2017-04-02T04:53:30',
#     'Power': 11.1,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.6664,
#     'Longitude': 145.2554,
#     'Surface Temperature (kelvin)': 325.7,
#     'Datetime': '2017-04-02T04:51:40',
#     'Power': 24.4,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.6688,
#     'Longitude': 145.2635,
#     'Surface Temperature (kelvin)': 321.0,
#     'Datetime': '2017-04-02T04:45:10',
#     'Power': 17.7,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.494,
#     'Longitude': 145.4522,
#     'Surface Temperature (kelvin)': 315.0,
#     'Datetime': '2017-04-02T04:45:10',
#     'Power': 11.3,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.324,
#     'Longitude': 146.1647,
#     'Surface Temperature (kelvin)': 319.6,
#     'Datetime': '2017-04-02T00:24:50',
#     'Power': 23.2,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 46}]},
#  {'Station': 948701,
#   'Date': '2017-04-03',
#   'AirTemperature(Celcius)': 15,
#   'RelativeHumidity': 47.7,
#   'WindSpeed(knots)': 5.9,
#   'MaxWindSpeed': 13.0,
#   'MAX': '71.1*',
#   'MIN': '43',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.1141,
#     'Longitude': 141.6787,
#     'Surface Temperature (kelvin)': 310.8,
#     'Datetime': '2017-04-03T13:20:00',
#     'Power': 20.5,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 37},
#    {'Latitude': -37.8046,
#     'Longitude': 146.0304,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-03T13:17:00',
#     'Power': 26.2,
#     'Confidence': 91,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.9068,
#     'Longitude': 145.9047,
#     'Surface Temperature (kelvin)': 313.8,
#     'Datetime': '2017-04-03T13:15:30',
#     'Power': 23.7,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1156,
#     'Longitude': 141.6664,
#     'Surface Temperature (kelvin)': 335.7,
#     'Datetime': '2017-04-03T13:15:10',
#     'Power': 52.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.8064,
#     'Longitude': 146.0189,
#     'Surface Temperature (kelvin)': 318.5,
#     'Datetime': '2017-04-03T13:15:10',
#     'Power': 28.3,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.0221,
#     'Longitude': 141.5517,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-03T04:00:00',
#     'Power': 20.1,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3735,
#     'Longitude': 145.886,
#     'Surface Temperature (kelvin)': 369.2,
#     'Datetime': '2017-04-03T03:59:10',
#     'Power': 124.4,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 96},
#    {'Latitude': -37.5422,
#     'Longitude': 143.2276,
#     'Surface Temperature (kelvin)': 322.3,
#     'Datetime': '2017-04-03T03:58:20',
#     'Power': 17.4,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.7465,
#     'Longitude': 143.3806,
#     'Surface Temperature (kelvin)': 345.7,
#     'Datetime': '2017-04-03T03:57:50',
#     'Power': 55.0,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -37.3094,
#     'Longitude': 146.1945,
#     'Surface Temperature (kelvin)': 333.6,
#     'Datetime': '2017-04-03T03:56:40',
#     'Power': 39.8,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 60},
#    {'Latitude': -36.7199,
#     'Longitude': 141.3946,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-03T03:56:20',
#     'Power': 26.7,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7638,
#     'Longitude': 142.1215,
#     'Surface Temperature (kelvin)': 326.0,
#     'Datetime': '2017-04-03T03:56:20',
#     'Power': 18.1,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.1534,
#     'Longitude': 141.5948,
#     'Surface Temperature (kelvin)': 337.3,
#     'Datetime': '2017-04-03T03:55:10',
#     'Power': 38.1,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.8072,
#     'Longitude': 145.9738,
#     'Surface Temperature (kelvin)': 350.8,
#     'Datetime': '2017-04-03T03:55:10',
#     'Power': 75.9,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 77},
#    {'Latitude': -37.3704,
#     'Longitude': 145.8942,
#     'Surface Temperature (kelvin)': 351.6,
#     'Datetime': '2017-04-03T03:54:00',
#     'Power': 76.4,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -37.297,
#     'Longitude': 143.5753,
#     'Surface Temperature (kelvin)': 367.0,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 108.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 93},
#    {'Latitude': -36.9172,
#     'Longitude': 142.0472,
#     'Surface Temperature (kelvin)': 319.1,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 11.3,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.8668,
#     'Longitude': 143.0472,
#     'Surface Temperature (kelvin)': 318.0,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 14.4,
#     'Confidence': 69,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7602,
#     'Longitude': 143.382,
#     'Surface Temperature (kelvin)': 317.5,
#     'Datetime': '2017-04-03T03:53:40',
#     'Power': 12.7,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7529,
#     'Longitude': 143.3745,
#     'Surface Temperature (kelvin)': 332.5,
#     'Datetime': '2017-04-03T03:53:30',
#     'Power': 32.5,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -37.7885,
#     'Longitude': 142.9509,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-03T03:53:30',
#     'Power': 12.4,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -34.2714,
#     'Longitude': 141.6197,
#     'Surface Temperature (kelvin)': 321.7,
#     'Datetime': '2017-04-03T03:53:00',
#     'Power': 12.2,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.1698,
#     'Longitude': 142.0536,
#     'Surface Temperature (kelvin)': 331.2,
#     'Datetime': '2017-04-03T03:52:30',
#     'Power': 26.5,
#     'Confidence': 84,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.2988,
#     'Longitude': 143.5487,
#     'Surface Temperature (kelvin)': 363.3,
#     'Datetime': '2017-04-03T03:52:30',
#     'Power': 98.0,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 90},
#    {'Latitude': -37.3716,
#     'Longitude': 145.9065,
#     'Surface Temperature (kelvin)': 389.0,
#     'Datetime': '2017-04-03T03:52:20',
#     'Power': 203.8,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 115},
#    {'Latitude': -37.8662,
#     'Longitude': 143.251,
#     'Surface Temperature (kelvin)': 319.3,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 16.0,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.4291,
#     'Longitude': 141.2426,
#     'Surface Temperature (kelvin)': 334.6,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 33.3,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.2891,
#     'Longitude': 143.5697,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 18.7,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3025,
#     'Longitude': 143.5714,
#     'Surface Temperature (kelvin)': 372.0,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 124.9,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 98},
#    {'Latitude': -37.383,
#     'Longitude': 145.9089,
#     'Surface Temperature (kelvin)': 362.4,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 104.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -37.7216,
#     'Longitude': 143.4272,
#     'Surface Temperature (kelvin)': 332.8,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 33.0,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -37.8717,
#     'Longitude': 143.3652,
#     'Surface Temperature (kelvin)': 322.5,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 19.2,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.8717,
#     'Longitude': 143.2566,
#     'Surface Temperature (kelvin)': 316.5,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 13.0,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3851,
#     'Longitude': 145.8878,
#     'Surface Temperature (kelvin)': 336.5,
#     'Datetime': '2017-04-03T03:51:30',
#     'Power': 46.2,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.7446,
#     'Longitude': 143.4085,
#     'Surface Temperature (kelvin)': 339.4,
#     'Datetime': '2017-04-03T03:51:30',
#     'Power': 42.8,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.7159,
#     'Longitude': 141.3991,
#     'Surface Temperature (kelvin)': 322.5,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 17.7,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -35.7626,
#     'Longitude': 142.1167,
#     'Surface Temperature (kelvin)': 336.0,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 33.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.8011,
#     'Longitude': 144.7343,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 12.4,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.8777,
#     'Longitude': 143.371,
#     'Surface Temperature (kelvin)': 327.5,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 26.6,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.7509,
#     'Longitude': 143.4023,
#     'Surface Temperature (kelvin)': 355.9,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 79.3,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 82},
#    {'Latitude': -36.6085,
#     'Longitude': 142.4451,
#     'Surface Temperature (kelvin)': 326.7,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 20.9,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.3802,
#     'Longitude': 145.9147,
#     'Surface Temperature (kelvin)': 376.3,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 149.0,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 103},
#    {'Latitude': -37.7974,
#     'Longitude': 145.9535,
#     'Surface Temperature (kelvin)': 370.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 131.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 97},
#    {'Latitude': -37.0241,
#     'Longitude': 141.5163,
#     'Surface Temperature (kelvin)': 316.9,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 13.4,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.2912,
#     'Longitude': 143.543,
#     'Surface Temperature (kelvin)': 316.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 11.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.313,
#     'Longitude': 146.1561,
#     'Surface Temperature (kelvin)': 319.9,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 21.6,
#     'Confidence': 52,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -38.0226,
#     'Longitude': 143.6739,
#     'Surface Temperature (kelvin)': 312.8,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 10.1,
#     'Confidence': 56,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -35.7657,
#     'Longitude': 142.0906,
#     'Surface Temperature (kelvin)': 340.1,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 40.5,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -37.9029,
#     'Longitude': 143.5946,
#     'Surface Temperature (kelvin)': 320.6,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 16.8,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.9151,
#     'Longitude': 142.0798,
#     'Surface Temperature (kelvin)': 323.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 16.6,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.9112,
#     'Longitude': 143.6025,
#     'Surface Temperature (kelvin)': 334.2,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 34.9,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.8089,
#     'Longitude': 145.9555,
#     'Surface Temperature (kelvin)': 314.8,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 18.9,
#     'Confidence': 56,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.9009,
#     'Longitude': 143.6217,
#     'Surface Temperature (kelvin)': 318.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 14.3,
#     'Confidence': 62,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.7583,
#     'Longitude': 143.41,
#     'Surface Temperature (kelvin)': 318.6,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.8,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.7836,
#     'Longitude': 142.9437,
#     'Surface Temperature (kelvin)': 318.0,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 14.5,
#     'Confidence': 69,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7236,
#     'Longitude': 143.3995,
#     'Surface Temperature (kelvin)': 359.3,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 88.0,
#     'Confidence': 99,
#     'Surface Temperature (Celcius)': 86},
#    {'Latitude': -37.5402,
#     'Longitude': 143.2559,
#     'Surface Temperature (kelvin)': 323.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 18.6,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3046,
#     'Longitude': 143.5448,
#     'Surface Temperature (kelvin)': 345.3,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 53.9,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -37.0484,
#     'Longitude': 141.6245,
#     'Surface Temperature (kelvin)': 315.8,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 10.5,
#     'Confidence': 52,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -36.911,
#     'Longitude': 142.1445,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.3,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.4312,
#     'Longitude': 141.2064,
#     'Surface Temperature (kelvin)': 349.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 61.7,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -36.1702,
#     'Longitude': 142.0586,
#     'Surface Temperature (kelvin)': 333.6,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 30.8,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 60},
#    {'Latitude': -36.1722,
#     'Longitude': 142.0266,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.3,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.1556,
#     'Longitude': 141.5904,
#     'Surface Temperature (kelvin)': 338.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 40.5,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -35.7598,
#     'Longitude': 143.851,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 12.0,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -35.7609,
#     'Longitude': 143.8442,
#     'Surface Temperature (kelvin)': 328.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 23.0,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7647,
#     'Longitude': 142.0858,
#     'Surface Temperature (kelvin)': 338.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 37.5,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -34.2536,
#     'Longitude': 141.6199,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-03T01:11:00',
#     'Power': 13.8,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2674,
#     'Longitude': 141.6183,
#     'Surface Temperature (kelvin)': 324.2,
#     'Datetime': '2017-04-03T01:10:50',
#     'Power': 19.5,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.7885,
#     'Longitude': 142.1258,
#     'Surface Temperature (kelvin)': 319.5,
#     'Datetime': '2017-04-03T01:07:30',
#     'Power': 16.4,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2594,
#     'Longitude': 141.6139,
#     'Surface Temperature (kelvin)': 327.7,
#     'Datetime': '2017-04-03T01:07:20',
#     'Power': 24.6,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -34.2614,
#     'Longitude': 141.6412,
#     'Surface Temperature (kelvin)': 317.0,
#     'Datetime': '2017-04-03T01:07:00',
#     'Power': 11.0,
#     'Confidence': 57,
#     'Surface Temperature (Celcius)': 43}]},
#  {'Station': 948701,
#   'Date': '2017-04-04',
#   'AirTemperature(Celcius)': 16,
#   'RelativeHumidity': 47.5,
#   'WindSpeed(knots)': 5.4,
#   'MaxWindSpeed': 12.0,
#   'MAX': '73.4*',
#   'MIN': '46.8',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -37.2162,
#     'Longitude': 146.2408,
#     'Surface Temperature (kelvin)': 311.8,
#     'Datetime': '2017-04-04T15:33:40',
#     'Power': 20.0,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.086999999999996,
#     'Longitude': 141.7227,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-04T15:31:00',
#     'Power': 27.5,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -36.0933,
#     'Longitude': 141.7154,
#     'Surface Temperature (kelvin)': 308.8,
#     'Datetime': '2017-04-04T15:30:40',
#     'Power': 19.7,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -36.0852,
#     'Longitude': 141.7112,
#     'Surface Temperature (kelvin)': 337.2,
#     'Datetime': '2017-04-04T15:30:40',
#     'Power': 55.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -36.3194,
#     'Longitude': 141.7531,
#     'Surface Temperature (kelvin)': 337.1,
#     'Datetime': '2017-04-04T04:41:50',
#     'Power': 34.5,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.3601,
#     'Longitude': 145.8519,
#     'Surface Temperature (kelvin)': 335.3,
#     'Datetime': '2017-04-04T04:41:10',
#     'Power': 44.8,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.1598,
#     'Longitude': 141.8841,
#     'Surface Temperature (kelvin)': 337.7,
#     'Datetime': '2017-04-04T04:41:00',
#     'Power': 35.0,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -36.6936,
#     'Longitude': 145.2788,
#     'Surface Temperature (kelvin)': 334.4,
#     'Datetime': '2017-04-04T04:41:00',
#     'Power': 35.9,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.1057,
#     'Longitude': 141.7608,
#     'Surface Temperature (kelvin)': 393.8,
#     'Datetime': '2017-04-04T04:40:00',
#     'Power': 212.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 120},
#    {'Latitude': -35.4033,
#     'Longitude': 143.267,
#     'Surface Temperature (kelvin)': 340.4,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 40.3,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 67},
#    {'Latitude': -36.6281,
#     'Longitude': 142.4349,
#     'Surface Temperature (kelvin)': 341.6,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 51.0,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 68},
#    {'Latitude': -36.111,
#     'Longitude': 145.124,
#     'Surface Temperature (kelvin)': 340.0,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 46.0,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.1615,
#     'Longitude': 141.8728,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 37.9,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -37.3074,
#     'Longitude': 142.9925,
#     'Surface Temperature (kelvin)': 328.1,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 31.4,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.937,
#     'Longitude': 142.1176,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 22.9,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -38.1868,
#     'Longitude': 143.0938,
#     'Surface Temperature (kelvin)': 318.9,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 22.6,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -35.2601,
#     'Longitude': 143.1931,
#     'Surface Temperature (kelvin)': 324.1,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 15.2,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.1849,
#     'Longitude': 145.9109,
#     'Surface Temperature (kelvin)': 381.0,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 155.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 107},
#    {'Latitude': -37.2109,
#     'Longitude': 142.7966,
#     'Surface Temperature (kelvin)': 325.5,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 27.6,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.6951,
#     'Longitude': 145.424,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-04T04:38:10',
#     'Power': 12.2,
#     'Confidence': 50,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.1376,
#     'Longitude': 145.84,
#     'Surface Temperature (kelvin)': 329.0,
#     'Datetime': '2017-04-04T04:37:30',
#     'Power': 27.2,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.6965,
#     'Longitude': 142.7116,
#     'Surface Temperature (kelvin)': 337.9,
#     'Datetime': '2017-04-04T04:37:10',
#     'Power': 40.1,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.0753,
#     'Longitude': 141.0532,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-04T04:36:40',
#     'Power': 22.1,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -37.6714,
#     'Longitude': 144.2154,
#     'Surface Temperature (kelvin)': 319.6,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 20.6,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.4465,
#     'Longitude': 143.5163,
#     'Surface Temperature (kelvin)': 324.1,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 27.7,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -38.0494,
#     'Longitude': 143.9141,
#     'Surface Temperature (kelvin)': 331.5,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 38.7,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -38.1356,
#     'Longitude': 143.7098,
#     'Surface Temperature (kelvin)': 323.6,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 28.0,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3632,
#     'Longitude': 145.8356,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 32.9,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.6078,
#     'Longitude': 141.9742,
#     'Surface Temperature (kelvin)': 336.7,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 36.9,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.3765,
#     'Longitude': 145.8221,
#     'Surface Temperature (kelvin)': 335.4,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 47.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.0694,
#     'Longitude': 141.5717,
#     'Surface Temperature (kelvin)': 327.3,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 19.4,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.1122,
#     'Longitude': 142.1491,
#     'Surface Temperature (kelvin)': 349.4,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 61.2,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -36.400999999999996,
#     'Longitude': 145.5113,
#     'Surface Temperature (kelvin)': 328.5,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 26.7,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -37.9048,
#     'Longitude': 145.7738,
#     'Surface Temperature (kelvin)': 322.8,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 29.8,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.3735,
#     'Longitude': 145.8384,
#     'Surface Temperature (kelvin)': 368.4,
#     'Datetime': '2017-04-04T04:35:00',
#     'Power': 125.0,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 95},
#    {'Latitude': -35.4128,
#     'Longitude': 143.2693,
#     'Surface Temperature (kelvin)': 330.8,
#     'Datetime': '2017-04-04T04:34:50',
#     'Power': 24.1,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.8848,
#     'Longitude': 142.1523,
#     'Surface Temperature (kelvin)': 324.4,
#     'Datetime': '2017-04-04T04:34:30',
#     'Power': 19.9,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -35.4255,
#     'Longitude': 143.6306,
#     'Surface Temperature (kelvin)': 338.8,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 42.8,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -36.1198,
#     'Longitude': 145.6369,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 20.6,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -38.4879,
#     'Longitude': 143.9971,
#     'Surface Temperature (kelvin)': 313.6,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 17.3,
#     'Confidence': 54,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1955,
#     'Longitude': 145.914,
#     'Surface Temperature (kelvin)': 351.3,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 63.0,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -35.4533,
#     'Longitude': 143.2029,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 40.4,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -35.4993,
#     'Longitude': 143.3105,
#     'Surface Temperature (kelvin)': 331.1,
#     'Datetime': '2017-04-04T04:34:00',
#     'Power': 23.5,
#     'Confidence': 84,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.5989,
#     'Longitude': 141.9771,
#     'Surface Temperature (kelvin)': 354.4,
#     'Datetime': '2017-04-04T04:33:50',
#     'Power': 76.1,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 81},
#    {'Latitude': -37.4485,
#     'Longitude': 143.5041,
#     'Surface Temperature (kelvin)': 328.0,
#     'Datetime': '2017-04-04T04:33:40',
#     'Power': 32.9,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.1744,
#     'Longitude': 143.9256,
#     'Surface Temperature (kelvin)': 316.8,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 15.2,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.104,
#     'Longitude': 141.77200000000002,
#     'Surface Temperature (kelvin)': 386.7,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 178.1,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 113},
#    {'Latitude': -36.4918,
#     'Longitude': 142.2465,
#     'Surface Temperature (kelvin)': 328.0,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 25.9,
#     'Confidence': 69,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6663,
#     'Longitude': 143.2603,
#     'Surface Temperature (kelvin)': 332.0,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 36.4,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -36.0189,
#     'Longitude': 145.6844,
#     'Surface Temperature (kelvin)': 322.7,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 16.8,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -35.7523,
#     'Longitude': 143.8866,
#     'Surface Temperature (kelvin)': 333.1,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 31.7,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -36.6538,
#     'Longitude': 142.7552,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-04T04:33:20',
#     'Power': 24.5,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.6299,
#     'Longitude': 142.4234,
#     'Surface Temperature (kelvin)': 345.0,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 56.3,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 71},
#    {'Latitude': -36.0994,
#     'Longitude': 143.4156,
#     'Surface Temperature (kelvin)': 335.4,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 38.8,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.8395,
#     'Longitude': 142.2188,
#     'Surface Temperature (kelvin)': 336.1,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 36.7,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.9294,
#     'Longitude': 142.7087,
#     'Surface Temperature (kelvin)': 324.6,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 21.9,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.1439,
#     'Longitude': 145.832,
#     'Surface Temperature (kelvin)': 323.5,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 19.3,
#     'Confidence': 53,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.1925,
#     'Longitude': 145.93,
#     'Surface Temperature (kelvin)': 353.0,
#     'Datetime': '2017-04-04T04:33:00',
#     'Power': 68.2,
#     'Confidence': 97,
#     'Surface Temperature (Celcius)': 79},
#    {'Latitude': -37.8351,
#     'Longitude': 145.9789,
#     'Surface Temperature (kelvin)': 334.2,
#     'Datetime': '2017-04-04T04:33:00',
#     'Power': 44.9,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.095,
#     'Longitude': 141.7699,
#     'Surface Temperature (kelvin)': 356.1,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 74.0,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 82},
#    {'Latitude': -36.7848,
#     'Longitude': 141.9044,
#     'Surface Temperature (kelvin)': 334.6,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 34.6,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.6962,
#     'Longitude': 145.2642,
#     'Surface Temperature (kelvin)': 331.9,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 31.7,
#     'Confidence': 84,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.1089,
#     'Longitude': 143.0783,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 29.3,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.7009,
#     'Longitude': 141.541,
#     'Surface Temperature (kelvin)': 323.0,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 18.6,
#     'Confidence': 54,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.4604,
#     'Longitude': 142.1623,
#     'Surface Temperature (kelvin)': 321.4,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 19.6,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.343,
#     'Longitude': 142.1986,
#     'Surface Temperature (kelvin)': 396.3,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 233.4,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 123},
#    {'Latitude': -36.2906,
#     'Longitude': 141.75799999999998,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 23.0,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.114000000000004,
#     'Longitude': 142.1377,
#     'Surface Temperature (kelvin)': 391.2,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 202.8,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 118},
#    {'Latitude': -37.5436,
#     'Longitude': 143.6122,
#     'Surface Temperature (kelvin)': 327.4,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 38.2,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6006,
#     'Longitude': 141.9657,
#     'Surface Temperature (kelvin)': 351.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 69.1,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -36.4611,
#     'Longitude': 143.14600000000002,
#     'Surface Temperature (kelvin)': 321.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 19.4,
#     'Confidence': 55,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -37.0769,
#     'Longitude': 141.042,
#     'Surface Temperature (kelvin)': 346.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 56.5,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -36.3521,
#     'Longitude': 142.2008,
#     'Surface Temperature (kelvin)': 394.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 218.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 120},
#    {'Latitude': -36.3539,
#     'Longitude': 142.1894,
#     'Surface Temperature (kelvin)': 327.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 23.5,
#     'Confidence': 53,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.883,
#     'Longitude': 142.1637,
#     'Surface Temperature (kelvin)': 341.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 45.2,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 67},
#    {'Latitude': -36.0973,
#     'Longitude': 143.4279,
#     'Surface Temperature (kelvin)': 365.8,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 108.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 92},
#    {'Latitude': -36.7722,
#     'Longitude': 141.5514,
#     'Surface Temperature (kelvin)': 331.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 29.5,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.0081,
#     'Longitude': 141.7654,
#     'Surface Temperature (kelvin)': 335.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 38.0,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.0967,
#     'Longitude': 141.7587,
#     'Surface Temperature (kelvin)': 374.3,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 129.4,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 101},
#    {'Latitude': -36.4204,
#     'Longitude': 141.3765,
#     'Surface Temperature (kelvin)': 330.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 27.2,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.2889,
#     'Longitude': 141.7692,
#     'Surface Temperature (kelvin)': 324.4,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.6,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -35.4439,
#     'Longitude': 143.2005,
#     'Surface Temperature (kelvin)': 327.5,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 20.5,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6228,
#     'Longitude': 142.428,
#     'Surface Temperature (kelvin)': 317.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.0,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.2205,
#     'Longitude': 141.7933,
#     'Surface Temperature (kelvin)': 327.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 18.8,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -38.1177,
#     'Longitude': 143.6409,
#     'Surface Temperature (kelvin)': 314.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.4,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1819,
#     'Longitude': 145.9269,
#     'Surface Temperature (kelvin)': 372.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 122.4,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 98},
#    {'Latitude': -35.4594,
#     'Longitude': 143.7125,
#     'Surface Temperature (kelvin)': 319.9,
#     'Datetime': '2017-04-04T00:14:30',
#     'Power': 17.1,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2708,
#     'Longitude': 141.6158,
#     'Surface Temperature (kelvin)': 326.0,
#     'Datetime': '2017-04-04T00:12:50',
#     'Power': 22.4,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.4616,
#     'Longitude': 143.7251,
#     'Surface Temperature (kelvin)': 326.7,
#     'Datetime': '2017-04-04T00:12:50',
#     'Power': 26.0,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53}]},
#  {'Station': 948701,
#   'Date': '2017-04-05',
#   'AirTemperature(Celcius)': 17,
#   'RelativeHumidity': 47.2,
#   'WindSpeed(knots)': 4.9,
#   'MaxWindSpeed': 13.0,
#   'MAX': '76.8*',
#   'MIN': '47.1',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -38.3499,
#     'Longitude': 147.033,
#     'Surface Temperature (kelvin)': 308.5,
#     'Datetime': '2017-04-05T13:10:10',
#     'Power': 19.0,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -38.2003,
#     'Longitude': 146.8378,
#     'Surface Temperature (kelvin)': 331.8,
#     'Datetime': '2017-04-05T13:09:00',
#     'Power': 45.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.4583,
#     'Longitude': 148.2459,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-05T13:09:00',
#     'Power': 21.5,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.6784,
#     'Longitude': 146.1432,
#     'Surface Temperature (kelvin)': 317.3,
#     'Datetime': '2017-04-05T13:08:40',
#     'Power': 27.2,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.4492,
#     'Longitude': 148.2438,
#     'Surface Temperature (kelvin)': 320.4,
#     'Datetime': '2017-04-05T13:08:40',
#     'Power': 29.6,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -38.2153,
#     'Longitude': 146.8652,
#     'Surface Temperature (kelvin)': 313.3,
#     'Datetime': '2017-04-05T13:07:00',
#     'Power': 22.2,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.7652,
#     'Longitude': 147.1289,
#     'Surface Temperature (kelvin)': 312.4,
#     'Datetime': '2017-04-05T13:06:30',
#     'Power': 20.3,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -35.6922,
#     'Longitude': 143.1619,
#     'Surface Temperature (kelvin)': 322.2,
#     'Datetime': '2017-04-05T13:04:20',
#     'Power': 32.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -38.2094,
#     'Longitude': 146.8398,
#     'Surface Temperature (kelvin)': 328.2,
#     'Datetime': '2017-04-05T13:03:20',
#     'Power': 39.6,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.2464,
#     'Longitude': 141.1143,
#     'Surface Temperature (kelvin)': 319.1,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 29.1,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -38.2078,
#     'Longitude': 146.8515,
#     'Surface Temperature (kelvin)': 328.9,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 40.9,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7024,
#     'Longitude': 143.1637,
#     'Surface Temperature (kelvin)': 313.0,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 22.0,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -38.3483,
#     'Longitude': 147.0446,
#     'Surface Temperature (kelvin)': 310.3,
#     'Datetime': '2017-04-05T13:02:50',
#     'Power': 20.4,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 37},
#    {'Latitude': -37.4015,
#     'Longitude': 145.5947,
#     'Surface Temperature (kelvin)': 315.5,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 24.2,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -38.2169,
#     'Longitude': 146.8535,
#     'Surface Temperature (kelvin)': 312.9,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 21.5,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.6435,
#     'Longitude': 146.1417,
#     'Surface Temperature (kelvin)': 309.5,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 19.7,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 36},
#    {'Latitude': -37.6387,
#     'Longitude': 142.9032,
#     'Surface Temperature (kelvin)': 361.8,
#     'Datetime': '2017-04-05T05:16:50',
#     'Power': 99.8,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 88},
#    {'Latitude': -38.0045,
#     'Longitude': 143.9075,
#     'Surface Temperature (kelvin)': 337.4,
#     'Datetime': '2017-04-05T05:15:50',
#     'Power': 43.5,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.7522,
#     'Longitude': 142.3183,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-05T05:15:40',
#     'Power': 22.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.9396,
#     'Longitude': 141.9303,
#     'Surface Temperature (kelvin)': 318.7,
#     'Datetime': '2017-04-05T05:15:30',
#     'Power': 16.8,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.6439,
#     'Longitude': 142.91299999999998,
#     'Surface Temperature (kelvin)': 356.7,
#     'Datetime': '2017-04-05T05:15:30',
#     'Power': 85.5,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 83},
#    {'Latitude': -37.78,
#     'Longitude': 141.8091,
#     'Surface Temperature (kelvin)': 315.9,
#     'Datetime': '2017-04-05T03:45:10',
#     'Power': 13.5,
#     'Confidence': 65,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -37.7767,
#     'Longitude': 141.8127,
#     'Surface Temperature (kelvin)': 317.8,
#     'Datetime': '2017-04-05T03:44:40',
#     'Power': 15.1,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -38.1756,
#     'Longitude': 143.9829,
#     'Surface Temperature (kelvin)': 326.2,
#     'Datetime': '2017-04-05T03:44:30',
#     'Power': 25.1,
#     'Confidence': 65,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.7795,
#     'Longitude': 148.4084,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-05T03:41:40',
#     'Power': 29.7,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.3165,
#     'Longitude': 147.4932,
#     'Surface Temperature (kelvin)': 346.0,
#     'Datetime': '2017-04-05T03:40:50',
#     'Power': 69.2,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -36.9373,
#     'Longitude': 142.5327,
#     'Surface Temperature (kelvin)': 319.0,
#     'Datetime': '2017-04-05T03:40:40',
#     'Power': 15.7,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -38.3553,
#     'Longitude': 147.0231,
#     'Surface Temperature (kelvin)': 311.7,
#     'Datetime': '2017-04-05T03:40:30',
#     'Power': 12.2,
#     'Confidence': 50,
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.934,
#     'Longitude': 142.5759,
#     'Surface Temperature (kelvin)': 320.5,
#     'Datetime': '2017-04-05T03:40:30',
#     'Power': 15.4,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.3158,
#     'Longitude': 147.4986,
#     'Surface Temperature (kelvin)': 349.3,
#     'Datetime': '2017-04-05T03:40:30',
#     'Power': 76.0,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -37.7916,
#     'Longitude': 148.4098,
#     'Surface Temperature (kelvin)': 327.7,
#     'Datetime': '2017-04-05T03:40:20',
#     'Power': 32.2,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.4471,
#     'Longitude': 147.6331,
#     'Surface Temperature (kelvin)': 339.0,
#     'Datetime': '2017-04-05T03:39:30',
#     'Power': 53.3,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -37.4024,
#     'Longitude': 145.5918,
#     'Surface Temperature (kelvin)': 325.9,
#     'Datetime': '2017-04-05T03:39:30',
#     'Power': 31.9,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -37.79,
#     'Longitude': 143.3801,
#     'Surface Temperature (kelvin)': 335.8,
#     'Datetime': '2017-04-05T03:39:30',
#     'Power': 39.3,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.7835,
#     'Longitude': 148.4138,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-05T03:39:20',
#     'Power': 52.2,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.5465,
#     'Longitude': 142.0912,
#     'Surface Temperature (kelvin)': 329.9,
#     'Datetime': '2017-04-05T03:39:20',
#     'Power': 27.7,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 56},
#    {'Latitude': -38.0383,
#     'Longitude': 144.4307,
#     'Surface Temperature (kelvin)': 313.8,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 11.2,
#     'Confidence': 59,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -37.4449,
#     'Longitude': 147.6594,
#     'Surface Temperature (kelvin)': 338.4,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 52.5,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -37.7851,
#     'Longitude': 143.3753,
#     'Surface Temperature (kelvin)': 337.4,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 41.4,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.4323,
#     'Longitude': 147.6583,
#     'Surface Temperature (kelvin)': 349.4,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 74.4,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -37.4343,
#     'Longitude': 147.6327,
#     'Surface Temperature (kelvin)': 365.2,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 115.1,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 92},
#    {'Latitude': -36.5475,
#     'Longitude': 142.0881,
#     'Surface Temperature (kelvin)': 336.7,
# ...
#    {'Latitude': -37.5914,
#     'Longitude': 148.5807,
#     'Surface Temperature (kelvin)': 334.2,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 37.1,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.7496,
#     'Longitude': 148.3898,
#     'Surface Temperature (kelvin)': 319.4,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 18.4,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.7697,
#     'Longitude': 148.336,
#     'Surface Temperature (kelvin)': 330.7,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 32.6,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.4324,
#     'Longitude': 141.5582,
#     'Surface Temperature (kelvin)': 325.5,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 17.7,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -38.0052,
#     'Longitude': 142.6179,
#     'Surface Temperature (kelvin)': 362.5,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 95.2,
#     'Confidence': 94,
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -38.3557,
#     'Longitude': 147.0372,
#     'Surface Temperature (kelvin)': 325.3,
#     'Datetime': '2017-04-06T00:06:10',
#     'Power': 28.6,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.4509,
#     'Longitude': 143.1522,
#     'Surface Temperature (kelvin)': 320.7,
#     'Datetime': '2017-04-06T00:06:10',
#     'Power': 15.1,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -38.0962,
#     'Longitude': 146.9724,
#     'Surface Temperature (kelvin)': 320.4,
#     'Datetime': '2017-04-06T00:06:10',
#     'Power': 19.2,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -35.4625,
#     'Longitude': 143.1486,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-06T00:03:50',
#     'Power': 11.3,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -38.0942,
#     'Longitude': 146.9603,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-06T00:01:40',
#     'Power': 11.3,
#     'Confidence': 52,
#     'Surface Temperature (Celcius)': 39}]},
#  {'Station': 948701,
#   'Date': '2017-04-07',
#   'AirTemperature(Celcius)': 21,
#   'RelativeHumidity': 47.0,
#   'WindSpeed(knots)': 13.2,
#   'MaxWindSpeed': 20.0,
#   'MAX': '78.3*',
#   'MIN': '56.7',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.7394,
#     'Longitude': 147.1366,
#     'Surface Temperature (kelvin)': 317.6,
#     'Datetime': '2017-04-07T12:58:30',
#     'Power': 25.1,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.3257,
#     'Longitude': 149.1209,
#     'Surface Temperature (kelvin)': 314.5,
#     'Datetime': '2017-04-07T12:56:50',
#     'Power': 22.4,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3176,
#     'Longitude': 149.3776,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 22.4,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.7507,
#     'Longitude': 147.1308,
#     'Surface Temperature (kelvin)': 312.7,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 19.0,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.3268,
#     'Longitude': 149.3795,
#     'Surface Temperature (kelvin)': 322.3,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 27.0,
#     'Confidence': 94,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.7606,
#     'Longitude': 147.1326,
#     'Surface Temperature (kelvin)': 314.5,
#     'Datetime': '2017-04-07T12:54:00',
#     'Power': 20.5,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -35.6961,
#     'Longitude': 143.1935,
#     'Surface Temperature (kelvin)': 308.5,
#     'Datetime': '2017-04-07T12:53:40',
#     'Power': 16.6,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -37.3252,
#     'Longitude': 149.3911,
#     'Surface Temperature (kelvin)': 314.6,
#     'Datetime': '2017-04-07T12:53:40',
#     'Power': 20.0,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3314,
#     'Longitude': 149.1283,
#     'Surface Temperature (kelvin)': 309.1,
#     'Datetime': '2017-04-07T12:52:10',
#     'Power': 15.8,
#     'Confidence': 65,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -36.3477,
#     'Longitude': 144.533,
#     'Surface Temperature (kelvin)': 314.8,
#     'Datetime': '2017-04-07T12:52:10',
#     'Power': 24.4,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3191,
#     'Longitude': 149.366,
#     'Surface Temperature (kelvin)': 318.8,
#     'Datetime': '2017-04-07T12:51:20',
#     'Power': 25.7,
#     'Confidence': 97,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.3359,
#     'Longitude': 149.3816,
#     'Surface Temperature (kelvin)': 321.3,
#     'Datetime': '2017-04-07T12:51:20',
#     'Power': 24.0,
#     'Confidence': 51,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -37.3526,
#     'Longitude': 149.3972,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T12:51:00',
#     'Power': 20.6,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.7408,
#     'Longitude': 147.1243,
#     'Surface Temperature (kelvin)': 322.6,
#     'Datetime': '2017-04-07T12:51:00',
#     'Power': 30.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.762,
#     'Longitude': 147.12,
#     'Surface Temperature (kelvin)': 316.9,
#     'Datetime': '2017-04-07T12:50:50',
#     'Power': 23.1,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3344,
#     'Longitude': 149.3933,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 24.7,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.3283,
#     'Longitude': 149.368,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 21.5,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3511,
#     'Longitude': 149.4088,
#     'Surface Temperature (kelvin)': 319.5,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 24.2,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.3085,
#     'Longitude': 149.3756,
#     'Surface Temperature (kelvin)': 311.8,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 18.7,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.7508,
#     'Longitude': 147.1254,
#     'Surface Temperature (kelvin)': 312.4,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 19.2,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -36.7309,
#     'Longitude': 147.1227,
#     'Surface Temperature (kelvin)': 315.8,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 23.3,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -37.8361,
#     'Longitude': 142.7482,
#     'Surface Temperature (kelvin)': 327.3,
#     'Datetime': '2017-04-07T05:09:50',
#     'Power': 25.3,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.8277,
#     'Longitude': 142.7498,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-07T05:04:00',
#     'Power': 15.1,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.1031,
#     'Longitude': 143.0782,
#     'Surface Temperature (kelvin)': 318.4,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 12.6,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -36.1025,
#     'Longitude': 143.0825,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 11.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.701,
#     'Longitude': 141.6351,
#     'Surface Temperature (kelvin)': 326.5,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 19.7,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.7034,
#     'Longitude': 141.6168,
#     'Surface Temperature (kelvin)': 319.3,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 11.0,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.698,
#     'Longitude': 141.6416,
#     'Surface Temperature (kelvin)': 328.1,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 22.4,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.7054,
#     'Longitude': 141.6708,
#     'Surface Temperature (kelvin)': 322.0,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 15.0,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.6999,
#     'Longitude': 141.6955,
#     'Surface Temperature (kelvin)': 325.6,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 20.3,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.7314,
#     'Longitude': 141.8698,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 10.5,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7931,
#     'Longitude': 148.385,
#     'Surface Temperature (kelvin)': 331.6,
#     'Datetime': '2017-04-07T03:31:40',
#     'Power': 33.8,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.2168,
#     'Longitude': 147.4748,
#     'Surface Temperature (kelvin)': 362.7,
#     'Datetime': '2017-04-07T03:31:40',
#     'Power': 106.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -37.222,
#     'Longitude': 147.4689,
#     'Surface Temperature (kelvin)': 352.0,
#     'Datetime': '2017-04-07T03:28:20',
#     'Power': 79.2,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -37.7974,
#     'Longitude': 148.5498,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-07T03:27:50',
#     'Power': 28.8,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.2063,
#     'Longitude': 147.4713,
#     'Surface Temperature (kelvin)': 343.6,
#     'Datetime': '2017-04-07T03:27:30',
#     'Power': 61.1,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 70},
#    {'Latitude': -37.2082,
#     'Longitude': 147.4368,
#     'Surface Temperature (kelvin)': 343.9,
#     'Datetime': '2017-04-07T03:27:20',
#     'Power': 62.6,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 70},
#    {'Latitude': -37.224000000000004,
#     'Longitude': 147.4347,
#     'Surface Temperature (kelvin)': 349.5,
#     'Datetime': '2017-04-07T03:27:20',
#     'Power': 74.4,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -37.2185,
#     'Longitude': 147.4402,
#     'Surface Temperature (kelvin)': 379.4,
#     'Datetime': '2017-04-07T03:27:10',
#     'Power': 163.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 106}]},
#  {'Station': 948701,
#   'Date': '2017-04-08',
#   'AirTemperature(Celcius)': 19,
#   'RelativeHumidity': 52.8,
#   'WindSpeed(knots)': 12.5,
#   'MaxWindSpeed': 21.0,
#   'MAX': '81.9*',
#   'MIN': '54.3*',
#   'Precipitation': '0.47G',
#   'fire': [{'Latitude': -37.34,
#     'Longitude': 149.3668,
#     'Surface Temperature (kelvin)': 347.6,
#     'Datetime': '2017-04-08T04:15:20',
#     'Power': 61.2,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 74},
#    {'Latitude': -37.8567,
#     'Longitude': 147.1576,
#     'Surface Temperature (kelvin)': 321.4,
#     'Datetime': '2017-04-08T04:14:40',
#     'Power': 19.9,
#     'Confidence': 62,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.7287,
#     'Longitude': 142.6017,
#     'Surface Temperature (kelvin)': 359.1,
#     'Datetime': '2017-04-08T04:14:00',
#     'Power': 82.1,
#     'Confidence': 99,
#     'Surface Temperature (Celcius)': 85},
#    {'Latitude': -35.2363,
#     'Longitude': 143.0004,
#     'Surface Temperature (kelvin)': 342.5,
#     'Datetime': '2017-04-08T04:12:50',
#     'Power': 43.9,
#     'Confidence': 91,
#     'Surface Temperature (Celcius)': 69},
#    {'Latitude': -37.4368,
#     'Longitude': 149.1191,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-08T04:12:20',
#     'Power': 28.0,
#     'Confidence': 56,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.2378,
#     'Longitude': 142.9864,
#     'Surface Temperature (kelvin)': 367.5,
#     'Datetime': '2017-04-08T04:12:20',
#     'Power': 106.2,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 94},
#    {'Latitude': -35.2397,
#     'Longitude': 142.98,
#     'Surface Temperature (kelvin)': 332.4,
#     'Datetime': '2017-04-08T04:12:00',
#     'Power': 25.4,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -36.2115,
#     'Longitude': 141.6878,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-08T04:11:50',
#     'Power': 15.3,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.9408,
#     'Longitude': 146.0611,
#     'Surface Temperature (kelvin)': 320.7,
#     'Datetime': '2017-04-08T04:11:40',
#     'Power': 19.7,
#     'Confidence': 58,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.6994,
#     'Longitude': 146.2162,
#     'Surface Temperature (kelvin)': 314.0,
#     'Datetime': '2017-04-08T04:09:20',
#     'Power': 16.3,
#     'Confidence': 59,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.2726,
#     'Longitude': 145.506,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-08T04:09:00',
#     'Power': 21.6,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -35.2381,
#     'Longitude': 142.994,
#     'Surface Temperature (kelvin)': 357.1,
#     'Datetime': '2017-04-08T04:08:50',
#     'Power': 75.9,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 83},
#    {'Latitude': -36.7199,
#     'Longitude': 142.5844,
#     'Surface Temperature (kelvin)': 329.9,
#     'Datetime': '2017-04-08T04:08:50',
#     'Power': 23.1,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 56},
#    {'Latitude': -37.3493,
#     'Longitude': 149.3691,
#     'Surface Temperature (kelvin)': 353.4,
#     'Datetime': '2017-04-08T04:08:40',
#     'Power': 73.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 80},
#    {'Latitude': -37.6447,
#     'Longitude': 148.6039,
#     'Surface Temperature (kelvin)': 323.7,
#     'Datetime': '2017-04-08T04:08:40',
#     'Power': 27.5,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.7165,
#     'Longitude': 142.6155,
#     'Surface Temperature (kelvin)': 340.1,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 39.6,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.7076,
#     'Longitude': 142.5982,
#     'Surface Temperature (kelvin)': 320.6,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 11.6,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.5652,
#     'Longitude': 145.5105,
#     'Surface Temperature (kelvin)': 327.2,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 23.3,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.7009,
#     'Longitude': 146.2046,
#     'Surface Temperature (kelvin)': 326.6,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 31.7,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.4023,
#     'Longitude': 145.7705,
#     'Surface Temperature (kelvin)': 332.0,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 29.0,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 58}]},
#  {'Station': 948701,
#   'Date': '2017-04-09',
#   'AirTemperature(Celcius)': 11,
#   'RelativeHumidity': 48.2,
#   'WindSpeed(knots)': 10.8,
#   'MaxWindSpeed': 22.9,
#   'MAX': '59.7*',
#   'MIN': '46.8*',
#   'Precipitation': '0.59G',
#   'fire': []},
#  {'Station': 948701,
#   'Date': '2017-04-10',
#   'AirTemperature(Celcius)': 14,
#   'RelativeHumidity': 50.4,
#   'WindSpeed(knots)': 12.8,
#   'MaxWindSpeed': 20.0,
#   'MAX': '62.4*',
#   'MIN': '46.8',
#   'Precipitation': '0.01G',
#   'fire': []}]

# %%
#insert documents into mongoDB, the new database is named as 'Combine'
db.Combine.insert_many(climatelist)

# %% [markdown]
# **4.Write queries to answer the Tasks A2-A8 on the new database. You need to write the queries as a python program using pymongo library in Jupyter Notebook.**

# %% [markdown]
# A2. Find climate data on 15th December 2017.

# %%
A0 = db.Combine.find({'AirTemperature(Celcius)':{"$eq":24}},{"fire":1})

# %%
for ducoment in A0:
    pprint(ducoment)
# Out:
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc38'), 'fire': []}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc39'), 'fire': []}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc44'), 'fire': []}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc45'), 'fire': []}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc6e'), 'fire': []}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': [{'Confidence': 85,
#            'Datetime': '2017-03-19T04:39:50',
#            'Latitude': -37.6605,
#            'Longitude': 142.1116,
#            'Power': 19.2,
#            'Surface Temperature (Celcius)': 60,
#            'Surface Temperature (kelvin)': 333.3},
#           {'Confidence': 58,
#            'Datetime': '2017-03-19T04:39:20',
#            'Latitude': -37.9164,
#            'Longitude': 143.4866,
#            'Power': 11.7,
#            'Surface Temperature (Celcius)': 54,
#            'Surface Temperature (kelvin)': 327.6},
#           {'Confidence': 96,
#            'Datetime': '2017-03-19T04:39:20',
#            'Latitude': -37.6622,
#            'Longitude': 142.1001,
#            'Power': 55.4,
#            'Surface Temperature (Celcius)': 79,
#            'Surface Temperature (kelvin)': 352.2},
#           {'Confidence': 63,
#            'Datetime': '2017-03-19T04:39:20',
#            'Latitude': -37.9257,
#            'Longitude': 143.4891,
#            'Power': 12.3,
#            'Surface Temperature (Celcius)': 54,
#            'Surface Temperature (kelvin)': 327.9},
#           {'Confidence': 64,
#            'Datetime': '2017-03-19T04:36:00',
#            'Latitude': -37.3982,
#            'Longitude': 147.0001,
#            'Power': 25.6,
#            'Surface Temperature (Celcius)': 58,
#            'Surface Temperature (kelvin)': 331.6},
#           {'Confidence': 90,
#            'Datetime': '2017-03-19T04:36:00',
#            'Latitude': -37.4523,
#            'Longitude': 147.0175,
#            'Power': 46.6,
#            'Surface Temperature (Celcius)': 66,
#            'Surface Temperature (kelvin)': 339.7},
#           {'Confidence': 59,
#            'Datetime': '2017-03-19T04:35:00',
#            'Latitude': -37.4023,
#            'Longitude': 147.0394,
#            'Power': 20.3,
#            'Surface Temperature (Celcius)': 56,
#            'Surface Temperature (kelvin)': 329.5},
#           {'Confidence': 60,
#            'Datetime': '2017-03-19T04:33:50',
#            'Latitude': -37.4336,
#            'Longitude': 147.0534,
#            'Power': 18.8,
#            'Surface Temperature (Celcius)': 51,
#            'Surface Temperature (kelvin)': 324.9},
#           {'Confidence': 61,
#            'Datetime': '2017-03-19T04:33:30',
#            'Latitude': -37.4003,
#            'Longitude': 147.0448,
#            'Power': 18.4,
#            'Surface Temperature (Celcius)': 55,
#            'Surface Temperature (kelvin)': 328.4},
#           {'Confidence': 53,
#            'Datetime': '2017-03-19T04:33:30',
#            'Latitude': -37.9184,
#            'Longitude': 143.4745,
#            'Power': 12.4,
#            'Surface Temperature (Celcius)': 55,
#            'Surface Temperature (kelvin)': 328.3},
#           {'Confidence': 61,
#            'Datetime': '2017-03-19T04:33:10',
#            'Latitude': -37.3911,
#            'Longitude': 147.037,
#            'Power': 13.8,
#            'Surface Temperature (Celcius)': 50,
#            'Surface Temperature (kelvin)': 323.7},
#           {'Confidence': 98,
#            'Datetime': '2017-03-19T04:33:00',
#            'Latitude': -37.4261,
#            'Longitude': 147.0323,
#            'Power': 77.2,
#            'Surface Temperature (Celcius)': 83,
#            'Surface Temperature (kelvin)': 357.1},
#           {'Confidence': 100,
#            'Datetime': '2017-03-19T04:32:50',
#            'Latitude': -37.3949,
#            'Longitude': 147.0175,
#            'Power': 96.6,
#            'Surface Temperature (Celcius)': 91,
#            'Surface Temperature (kelvin)': 364.6},
#           {'Confidence': 84,
#            'Datetime': '2017-03-19T04:32:50',
#            'Latitude': -37.671,
#            'Longitude': 144.6536,
#            'Power': 17.6,
#            'Surface Temperature (Celcius)': 58,
#            'Surface Temperature (kelvin)': 331.7},
#           {'Confidence': 66,
#            'Datetime': '2017-03-19T04:32:50',
#            'Latitude': -37.9277,
#            'Longitude': 143.477,
#            'Power': 13.1,
#            'Surface Temperature (Celcius)': 55,
#            'Surface Temperature (kelvin)': 328.6},
#           {'Confidence': 100,
#            'Datetime': '2017-03-19T04:32:40',
#            'Latitude': -37.4224,
#            'Longitude': 147.0511,
#            'Power': 176.6,
#            'Surface Temperature (Celcius)': 113,
#            'Surface Temperature (kelvin)': 386.4},
#           {'Confidence': 92,
#            'Datetime': '2017-03-19T04:32:40',
#            'Latitude': -37.6625,
#            'Longitude': 144.287,
#            'Power': 42.3,
#            'Surface Temperature (Celcius)': 70,
#            'Surface Temperature (kelvin)': 343.7},
#           {'Confidence': 100,
#            'Datetime': '2017-03-19T04:32:40',
#            'Latitude': -37.4375,
#            'Longitude': 147.0336,
#            'Power': 152.1,
#            'Surface Temperature (Celcius)': 106,
#            'Surface Temperature (kelvin)': 379.2},
#           {'Confidence': 73,
#            'Datetime': '2017-03-19T04:32:40',
#            'Latitude': -37.4414,
#            'Longitude': 147.0139,
#            'Power': 33.9,
#            'Surface Temperature (Celcius)': 60,
#            'Surface Temperature (kelvin)': 334.0},
#           {'Confidence': 77,
#            'Datetime': '2017-03-19T00:15:50',
#            'Latitude': -37.4295,
#            'Longitude': 147.0428,
#            'Power': 34.0,
#            'Surface Temperature (Celcius)': 59,
#            'Surface Temperature (kelvin)': 332.6},
#           {'Confidence': 60,
#            'Datetime': '2017-03-19T00:12:50',
#            'Latitude': -37.3942,
#            'Longitude': 147.0455,
#            'Power': 12.9,
#            'Surface Temperature (Celcius)': 44,
#            'Surface Temperature (kelvin)': 317.2}]}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd71'),
#  'fire': [{'Confidence': 87,
#            'Datetime': '2017-11-13T03:52:15',
#            'Latitude': -37.621,
#            'Longitude': 143.447,
#            'Power': 104.4,
#            'Surface Temperature (Celcius)': 61,
#            'Surface Temperature (kelvin)': 334.2},
#           {'Confidence': 81,
#            'Datetime': '2017-11-13T03:52:14',
#            'Latitude': -37.614000000000004,
#            'Longitude': 143.451,
#            'Power': 69.6,
#            'Surface Temperature (Celcius)': 53,
#            'Surface Temperature (kelvin)': 326.8},
#           {'Confidence': 64,
#            'Datetime': '2017-11-13T03:52:08',
#            'Latitude': -37.954,
#            'Longitude': 143.918,
#            'Power': 16.5,
#            'Surface Temperature (Celcius)': 42,
#            'Surface Temperature (kelvin)': 315.3},
#           {'Confidence': 51,
#            'Datetime': '2017-11-13T01:16:38',
#            'Latitude': -38.167,
#            'Longitude': 143.841,
#            'Power': 40.7,
#            'Surface Temperature (Celcius)': 38,
#            'Surface Temperature (kelvin)': 312.1},
#           {'Confidence': 62,
#            'Datetime': '2017-11-13T01:16:37',
#            'Latitude': -38.16,
#            'Longitude': 143.803,
#            'Power': 49.0,
#            'Surface Temperature (Celcius)': 41,
#            'Surface Temperature (kelvin)': 314.2}]}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd78'), 'fire': []}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd79'),
#  'fire': [{'Confidence': 85,
#            'Datetime': '2017-11-21T00:27:21',
#            'Latitude': -37.758,
#            'Longitude': 144.69299999999998,
#            'Power': 19.5,
#            'Surface Temperature (Celcius)': 59,
#            'Surface Temperature (kelvin)': 332.5}]}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd7b'),
#  'fire': [{'Confidence': 84,
#            'Datetime': '2017-11-23T04:28:59',
#            'Latitude': -37.946,
#            'Longitude': 144.342,
#            'Power': 16.8,
#            'Surface Temperature (Celcius)': 60,
#            'Surface Temperature (kelvin)': 333.2},
#           {'Confidence': 93,
#            'Datetime': '2017-11-23T04:28:59',
#            'Latitude': -37.945,
#            'Longitude': 144.35399999999998,
#            'Power': 40.1,
#            'Surface Temperature (Celcius)': 73,
#            'Surface Temperature (kelvin)': 346.5},
#           {'Confidence': 68,
#            'Datetime': '2017-11-23T00:15:12',
#            'Latitude': -38.141,
#            'Longitude': 143.183,
#            'Power': 12.9,
#            'Surface Temperature (Celcius)': 46,
#            'Surface Temperature (kelvin)': 319.5},
#           {'Confidence': 63,
#            'Datetime': '2017-11-23T00:14:47',
#            'Latitude': -36.952,
#            'Longitude': 144.972,
#            'Power': 19.9,
#            'Surface Temperature (Celcius)': 60,
#            'Surface Temperature (kelvin)': 333.2},
#           {'Confidence': 70,
#            'Datetime': '2017-11-23T00:14:24',
#            'Latitude': -34.965,
#            'Longitude': 142.031,
#            'Power': 21.3,
#            'Surface Temperature (Celcius)': 55,
#            'Surface Temperature (kelvin)': 328.8}]}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd7d'), 'fire': []}

# %%
A00 = db.Combine.aggregate([{"$unwind":"$fire"},\
                            {"$match":{'AirTemperature(Celcius)':{"$eq":24}}},\
                            {"$project":{"fire":1}}])

# %%
for ducoment in A00:
    pprint(ducoment)
# Out:
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-03-19T04:39:50',
#           'Latitude': -37.6605,
#           'Longitude': 142.1116,
#           'Power': 19.2,
#           'Surface Temperature (Celcius)': 60,
#           'Surface Temperature (kelvin)': 333.3}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 58,
#           'Datetime': '2017-03-19T04:39:20',
#           'Latitude': -37.9164,
#           'Longitude': 143.4866,
#           'Power': 11.7,
#           'Surface Temperature (Celcius)': 54,
#           'Surface Temperature (kelvin)': 327.6}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-03-19T04:39:20',
#           'Latitude': -37.6622,
#           'Longitude': 142.1001,
#           'Power': 55.4,
#           'Surface Temperature (Celcius)': 79,
#           'Surface Temperature (kelvin)': 352.2}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 63,
#           'Datetime': '2017-03-19T04:39:20',
#           'Latitude': -37.9257,
#           'Longitude': 143.4891,
#           'Power': 12.3,
#           'Surface Temperature (Celcius)': 54,
#           'Surface Temperature (kelvin)': 327.9}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 64,
#           'Datetime': '2017-03-19T04:36:00',
#           'Latitude': -37.3982,
#           'Longitude': 147.0001,
#           'Power': 25.6,
#           'Surface Temperature (Celcius)': 58,
#           'Surface Temperature (kelvin)': 331.6}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-03-19T04:36:00',
#           'Latitude': -37.4523,
#           'Longitude': 147.0175,
#           'Power': 46.6,
#           'Surface Temperature (Celcius)': 66,
#           'Surface Temperature (kelvin)': 339.7}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 59,
#           'Datetime': '2017-03-19T04:35:00',
#           'Latitude': -37.4023,
#           'Longitude': 147.0394,
#           'Power': 20.3,
#           'Surface Temperature (Celcius)': 56,
#           'Surface Temperature (kelvin)': 329.5}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 60,
#           'Datetime': '2017-03-19T04:33:50',
#           'Latitude': -37.4336,
#           'Longitude': 147.0534,
#           'Power': 18.8,
#           'Surface Temperature (Celcius)': 51,
#           'Surface Temperature (kelvin)': 324.9}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 61,
#           'Datetime': '2017-03-19T04:33:30',
#           'Latitude': -37.4003,
#           'Longitude': 147.0448,
#           'Power': 18.4,
#           'Surface Temperature (Celcius)': 55,
#           'Surface Temperature (kelvin)': 328.4}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 53,
#           'Datetime': '2017-03-19T04:33:30',
#           'Latitude': -37.9184,
#           'Longitude': 143.4745,
#           'Power': 12.4,
#           'Surface Temperature (Celcius)': 55,
#           'Surface Temperature (kelvin)': 328.3}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 61,
#           'Datetime': '2017-03-19T04:33:10',
#           'Latitude': -37.3911,
#           'Longitude': 147.037,
#           'Power': 13.8,
#           'Surface Temperature (Celcius)': 50,
#           'Surface Temperature (kelvin)': 323.7}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-03-19T04:33:00',
#           'Latitude': -37.4261,
#           'Longitude': 147.0323,
#           'Power': 77.2,
#           'Surface Temperature (Celcius)': 83,
#           'Surface Temperature (kelvin)': 357.1}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-19T04:32:50',
#           'Latitude': -37.3949,
#           'Longitude': 147.0175,
#           'Power': 96.6,
#           'Surface Temperature (Celcius)': 91,
#           'Surface Temperature (kelvin)': 364.6}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-03-19T04:32:50',
#           'Latitude': -37.671,
#           'Longitude': 144.6536,
#           'Power': 17.6,
#           'Surface Temperature (Celcius)': 58,
#           'Surface Temperature (kelvin)': 331.7}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 66,
#           'Datetime': '2017-03-19T04:32:50',
#           'Latitude': -37.9277,
#           'Longitude': 143.477,
#           'Power': 13.1,
#           'Surface Temperature (Celcius)': 55,
#           'Surface Temperature (kelvin)': 328.6}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-19T04:32:40',
#           'Latitude': -37.4224,
#           'Longitude': 147.0511,
#           'Power': 176.6,
#           'Surface Temperature (Celcius)': 113,
#           'Surface Temperature (kelvin)': 386.4}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-03-19T04:32:40',
#           'Latitude': -37.6625,
#           'Longitude': 144.287,
#           'Power': 42.3,
#           'Surface Temperature (Celcius)': 70,
#           'Surface Temperature (kelvin)': 343.7}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-19T04:32:40',
#           'Latitude': -37.4375,
#           'Longitude': 147.0336,
#           'Power': 152.1,
#           'Surface Temperature (Celcius)': 106,
#           'Surface Temperature (kelvin)': 379.2}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 73,
#           'Datetime': '2017-03-19T04:32:40',
#           'Latitude': -37.4414,
#           'Longitude': 147.0139,
#           'Power': 33.9,
#           'Surface Temperature (Celcius)': 60,
#           'Surface Temperature (kelvin)': 334.0}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 77,
#           'Datetime': '2017-03-19T00:15:50',
#           'Latitude': -37.4295,
#           'Longitude': 147.0428,
#           'Power': 34.0,
#           'Surface Temperature (Celcius)': 59,
#           'Surface Temperature (kelvin)': 332.6}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbc82'),
#  'fire': {'Confidence': 60,
#           'Datetime': '2017-03-19T00:12:50',
#           'Latitude': -37.3942,
#           'Longitude': 147.0455,
#           'Power': 12.9,
#           'Surface Temperature (Celcius)': 44,
#           'Surface Temperature (kelvin)': 317.2}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd71'),
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-11-13T03:52:15',
#           'Latitude': -37.621,
#           'Longitude': 143.447,
#           'Power': 104.4,
#           'Surface Temperature (Celcius)': 61,
#           'Surface Temperature (kelvin)': 334.2}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd71'),
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-11-13T03:52:14',
#           'Latitude': -37.614000000000004,
#           'Longitude': 143.451,
#           'Power': 69.6,
#           'Surface Temperature (Celcius)': 53,
#           'Surface Temperature (kelvin)': 326.8}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd71'),
#  'fire': {'Confidence': 64,
#           'Datetime': '2017-11-13T03:52:08',
#           'Latitude': -37.954,
#           'Longitude': 143.918,
#           'Power': 16.5,
#           'Surface Temperature (Celcius)': 42,
#           'Surface Temperature (kelvin)': 315.3}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd71'),
#  'fire': {'Confidence': 51,
#           'Datetime': '2017-11-13T01:16:38',
#           'Latitude': -38.167,
#           'Longitude': 143.841,
#           'Power': 40.7,
#           'Surface Temperature (Celcius)': 38,
#           'Surface Temperature (kelvin)': 312.1}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd71'),
#  'fire': {'Confidence': 62,
#           'Datetime': '2017-11-13T01:16:37',
#           'Latitude': -38.16,
#           'Longitude': 143.803,
#           'Power': 49.0,
#           'Surface Temperature (Celcius)': 41,
#           'Surface Temperature (kelvin)': 314.2}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd79'),
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-11-21T00:27:21',
#           'Latitude': -37.758,
#           'Longitude': 144.69299999999998,
#           'Power': 19.5,
#           'Surface Temperature (Celcius)': 59,
#           'Surface Temperature (kelvin)': 332.5}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd7b'),
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-11-23T04:28:59',
#           'Latitude': -37.946,
#           'Longitude': 144.342,
#           'Power': 16.8,
#           'Surface Temperature (Celcius)': 60,
#           'Surface Temperature (kelvin)': 333.2}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd7b'),
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-11-23T04:28:59',
#           'Latitude': -37.945,
#           'Longitude': 144.35399999999998,
#           'Power': 40.1,
#           'Surface Temperature (Celcius)': 73,
#           'Surface Temperature (kelvin)': 346.5}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd7b'),
#  'fire': {'Confidence': 68,
#           'Datetime': '2017-11-23T00:15:12',
#           'Latitude': -38.141,
#           'Longitude': 143.183,
#           'Power': 12.9,
#           'Surface Temperature (Celcius)': 46,
#           'Surface Temperature (kelvin)': 319.5}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd7b'),
#  'fire': {'Confidence': 63,
#           'Datetime': '2017-11-23T00:14:47',
#           'Latitude': -36.952,
#           'Longitude': 144.972,
#           'Power': 19.9,
#           'Surface Temperature (Celcius)': 60,
#           'Surface Temperature (kelvin)': 333.2}}
# {'_id': ObjectId('5b17eb16b3dbfe1420cdbd7b'),
#  'fire': {'Confidence': 70,
#           'Datetime': '2017-11-23T00:14:24',
#           'Latitude': -34.965,
#           'Longitude': 142.031,
#           'Power': 21.3,
#           'Surface Temperature (Celcius)': 55,
#           'Surface Temperature (kelvin)': 328.8}}

# %%
# db.climate.find({ 'Date': '2017-12-15'} , {'_id': 0}).pretty()

# %%
A2 = db.Combine.find({"Date":"2017-12-15"},{'_id':0,'fire':0})

# %%
for ducoment in A2:
    pprint(ducoment)
# Out:
# {'AirTemperature(Celcius)': 18,
#  'Date': '2017-12-15',
#  'MAX': '74.5*',
#  'MIN': '53.1',
#  'MaxWindSpeed': 14.0,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 52.0,
#  'Station': 948702,
#  'WindSpeed(knots)': 7.1}

# %% [markdown]
# A3. Find the latitude, longitude and confidence when the surface temperature (°C) was between 65 °C and 100 °C.

# %%
# db.fire.find({'Surface Temperature (Celcius)':{$gte:65, $lte:100}},
            # {'Latitude':1,'Longitude':1,'Confidence':1,
            # 'Surface Temperature (Celcius)': 1,'_id':0}).pretty()

# %%
#Unwind fire to ensure retrieve fire data as stand-alone record
#Match surface temperature between 65 and 100
#Project specified field
A3 = db.Combine.aggregate([{"$unwind": "$fire"},\
                           {"$match": {"fire.Surface Temperature (Celcius)": { "$gte":65,"$lte":100}}},\
                           {"$project":{'fire.Latitude':1,'fire.Longitude': 1,'fire.Confidence':1,\
                            'fire.Surface Temperature (Celcius)':1,'_id':0}}])

# %%
for ducoment in A3:
    pprint(ducoment)
# Out:
# {'fire': {'Confidence': 94,
#           'Latitude': -37.2284,
#           'Longitude': 147.9187,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.6572,
#           'Longitude': 142.0703,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 84,
#           'Latitude': -37.0193,
#           'Longitude': 148.1459,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.4229,
#           'Longitude': 147.02700000000002,
#           'Surface Temperature (Celcius)': 99}}
# {'fire': {'Confidence': 80,
#           'Latitude': -37.0055,
#           'Longitude': 148.1582,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 85,
#           'Latitude': -37.4128,
#           'Longitude': 147.0242,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 90,
#           'Latitude': -34.357,
#           'Longitude': 141.5361,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 93,
#           'Latitude': -34.3539,
#           'Longitude': 141.5547,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.9939,
#           'Longitude': 148.2244,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.9959,
#           'Longitude': 148.2118,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 89,
#           'Latitude': -34.3654,
#           'Longitude': 141.543,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 96,
#           'Latitude': -34.3554,
#           'Longitude': 141.5413,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 94,
#           'Latitude': -34.3555,
#           'Longitude': 141.5495,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.7152,
#           'Longitude': 141.3853,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.0155,
#           'Longitude': 148.1432,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 96,
#           'Latitude': -37.6622,
#           'Longitude': 142.1001,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.4523,
#           'Longitude': 147.0175,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 98,
#           'Latitude': -37.4261,
#           'Longitude': 147.0323,
#           'Surface Temperature (Celcius)': 83}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.3949,
#           'Longitude': 147.0175,
#           'Surface Temperature (Celcius)': 91}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.6625,
#           'Longitude': 144.287,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 82,
#           'Latitude': -37.8973,
#           'Longitude': 143.4754,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.7805,
#           'Longitude': 143.5003,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.8774,
#           'Longitude': 145.8213,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.8881,
#           'Longitude': 145.8229,
#           'Surface Temperature (Celcius)': 99}}
# {'fire': {'Confidence': 71,
#           'Latitude': -37.522,
#           'Longitude': 143.3874,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 91,
#           'Latitude': -38.0674,
#           'Longitude': 142.965,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 92,
#           'Latitude': -38.0715,
#           'Longitude': 142.9591,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.0693,
#           'Longitude': 142.9722,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.4557,
#           'Longitude': 142.2434,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.8009,
#           'Longitude': 142.7259,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.8099,
#           'Longitude': 142.72799999999998,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.7806,
#           'Longitude': 141.5597,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 98,
#           'Latitude': -34.3526,
#           'Longitude': 141.6458,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.0924,
#           'Longitude': 141.89700000000002,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.9452,
#           'Longitude': 143.5834,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 99,
#           'Latitude': -34.351,
#           'Longitude': 141.6567,
#           'Surface Temperature (Celcius)': 86}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.5012,
#           'Longitude': 142.5853,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.9247,
#           'Longitude': 142.8999,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 97,
#           'Latitude': -35.0805,
#           'Longitude': 142.4642,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 87,
#           'Latitude': -37.3735,
#           'Longitude': 145.886,
#           'Surface Temperature (Celcius)': 96}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.7465,
#           'Longitude': 143.3806,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.8072,
#           'Longitude': 145.9738,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 96,
#           'Latitude': -37.3704,
#           'Longitude': 145.8942,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.297,
#           'Longitude': 143.5753,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.2988,
#           'Longitude': 143.5487,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.3025,
#           'Longitude': 143.5714,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.383,
#           'Longitude': 145.9089,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.7446,
#           'Longitude': 143.4085,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 98,
#           'Latitude': -37.7509,
#           'Longitude': 143.4023,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 87,
#           'Latitude': -37.7974,
#           'Longitude': 145.9535,
#           'Surface Temperature (Celcius)': 97}}
# {'fire': {'Confidence': 90,
#           'Latitude': -35.7657,
#           'Longitude': 142.0906,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.7236,
#           'Longitude': 143.3995,
#           'Surface Temperature (Celcius)': 86}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.3046,
#           'Longitude': 143.5448,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.4312,
#           'Longitude': 141.2064,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.1556,
#           'Longitude': 141.5904,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 89,
#           'Latitude': -35.7647,
#           'Longitude': 142.0858,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 90,
#           'Latitude': -35.4033,
#           'Longitude': 143.267,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 64,
#           'Latitude': -36.6281,
#           'Longitude': 142.4349,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 85,
#           'Latitude': -36.111,
#           'Longitude': 145.124,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.1615,
#           'Longitude': 141.8728,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.1122,
#           'Longitude': 142.1491,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.3735,
#           'Longitude': 145.8384,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 89,
#           'Latitude': -35.4255,
#           'Longitude': 143.6306,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.1955,
#           'Longitude': 145.914,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 85,
#           'Latitude': -35.4533,
#           'Longitude': 143.2029,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.5989,
#           'Longitude': 141.9771,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 66,
#           'Latitude': -36.6299,
#           'Longitude': 142.4234,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.1925,
#           'Longitude': 145.93,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 98,
#           'Latitude': -36.095,
#           'Longitude': 141.7699,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.6006,
#           'Longitude': 141.9657,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.0769,
#           'Longitude': 141.042,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 79,
#           'Latitude': -36.883,
#           'Longitude': 142.1637,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 87,
#           'Latitude': -36.0973,
#           'Longitude': 143.4279,
#           'Surface Temperature (Celcius)': 92}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.1819,
#           'Longitude': 145.9269,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 87,
#           'Latitude': -37.6387,
#           'Longitude': 142.9032,
#           'Surface Temperature (Celcius)': 88}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.6439,
#           'Longitude': 142.91299999999998,
#           'Surface Temperature (Celcius)': 83}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.3165,
#           'Longitude': 147.4932,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.3158,
#           'Longitude': 147.4986,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.4471,
#           'Longitude': 147.6331,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.7835,
#           'Longitude': 148.4138,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.4449,
#           'Longitude': 147.6594,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.4323,
#           'Longitude': 147.6583,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.4343,
#           'Longitude': 147.6327,
#           'Surface Temperature (Celcius)': 92}}
# {'fire': {'Confidence': 84,
#           'Latitude': -37.5816,
#           'Longitude': 148.5862,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.6334,
#           'Longitude': 142.2244,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 76,
#           'Latitude': -37.7966,
#           'Longitude': 142.3196,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 100,
#           'Latitude': -35.805,
#           'Longitude': 142.1326,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.8429,
#           'Longitude': 143.8366,
#           'Surface Temperature (Celcius)': 88}}
# {'fire': {'Confidence': 77,
#           'Latitude': -37.8062,
#           'Longitude': 143.3598,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.9918,
#           'Longitude': 141.8667,
#           'Surface Temperature (Celcius)': 97}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.1104,
#           'Longitude': 145.9829,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.782,
#           'Longitude': 148.3844,
#           'Surface Temperature (Celcius)': 99}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.9902,
#           'Longitude': 141.879,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.745,
#           'Longitude': 142.993,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.0157,
#           'Longitude': 145.9414,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.777,
#           'Longitude': 148.4128,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.5888,
#           'Longitude': 148.5949,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 89,
#           'Latitude': -34.3943,
#           'Longitude': 141.7567,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 81,
#           'Latitude': -36.0844,
#           'Longitude': 141.4934,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.031,
#           'Longitude': 145.6824,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 86,
#           'Latitude': -37.5814,
#           'Longitude': 148.5777,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.5788,
#           'Longitude': 148.592,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.6384,
#           'Longitude': 142.4075,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 94,
#           'Latitude': -35.811,
#           'Longitude': 142.1403,
#           'Surface Temperature (Celcius)': 96}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.9034,
#           'Longitude': 141.0013,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 88,
#           'Latitude': -37.7746,
#           'Longitude': 148.3673,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 83,
#           'Latitude': -37.803000000000004,
#           'Longitude': 142.3151,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 96,
#           'Latitude': -37.7542,
#           'Longitude': 142.9949,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.3803,
#           'Longitude': 145.611,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.7617,
#           'Longitude': 143.08100000000002,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.8161,
#           'Longitude': 142.9286,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.0387,
#           'Longitude': 145.6787,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.6349,
#           'Longitude': 142.2125,
#           'Surface Temperature (Celcius)': 86}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.9018,
#           'Longitude': 141.0146,
#           'Surface Temperature (Celcius)': 100}}
# {'fire': {'Confidence': 86,
#           'Latitude': -36.6986,
#           'Longitude': 142.7259,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 94,
#           'Latitude': -38.0052,
#           'Longitude': 142.6179,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.2168,
#           'Longitude': 147.4748,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 96,
#           'Latitude': -37.222,
#           'Longitude': 147.4689,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.2063,
#           'Longitude': 147.4713,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.2082,
#           'Longitude': 147.4368,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.224000000000004,
#           'Longitude': 147.4347,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 67,
#           'Latitude': -37.34,
#           'Longitude': 149.3668,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 99,
#           'Latitude': -36.7287,
#           'Longitude': 142.6017,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 91,
#           'Latitude': -35.2363,
#           'Longitude': 143.0004,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 100,
#           'Latitude': -35.2378,
#           'Longitude': 142.9864,
#           'Surface Temperature (Celcius)': 94}}
# {'fire': {'Confidence': 98,
#           'Latitude': -35.2381,
#           'Longitude': 142.994,
#           'Surface Temperature (Celcius)': 83}}
# {'fire': {'Confidence': 66,
#           'Latitude': -37.3493,
#           'Longitude': 149.3691,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.7165,
#           'Longitude': 142.6155,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 94,
#           'Latitude': -37.5812,
#           'Longitude': 142.7374,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.5949,
#           'Longitude': 142.6857,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.8247,
#           'Longitude': 143.6243,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.4028,
#           'Longitude': 143.6932,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.4033,
#           'Longitude': 143.6884,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.8249,
#           'Longitude': 143.6174,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.6823,
#           'Longitude': 142.5024,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.4489,
#           'Longitude': 144.7685,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.9498,
#           'Longitude': 142.2012,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.1941,
#           'Longitude': 143.1604,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.4142,
#           'Longitude': 143.1077,
#           'Surface Temperature (Celcius)': 97}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.1924,
#           'Longitude': 143.1716,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.0295,
#           'Longitude': 143.6409,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.0761,
#           'Longitude': 141.0574,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 93,
#           'Latitude': -35.0616,
#           'Longitude': 141.4417,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.3999,
#           'Longitude': 144.737,
#           'Surface Temperature (Celcius)': 88}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.1748,
#           'Longitude': 145.7582,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 99,
#           'Latitude': -36.0691,
#           'Longitude': 145.7797,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 90,
#           'Latitude': -35.1949,
#           'Longitude': 141.0622,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.91,
#           'Longitude': 141.2705,
#           'Surface Temperature (Celcius)': 96}}
# {'fire': {'Confidence': 89,
#           'Latitude': -35.8071,
#           'Longitude': 142.7318,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.7787,
#           'Longitude': 141.4449,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 98,
#           'Latitude': -36.2948,
#           'Longitude': 141.3486,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 89,
#           'Latitude': -38.1561,
#           'Longitude': 143.7846,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.8185,
#           'Longitude': 142.5609,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.1771,
#           'Longitude': 145.7451,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.027,
#           'Longitude': 142.3844,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 89,
#           'Latitude': -35.7642,
#           'Longitude': 143.3321,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.429,
#           'Longitude': 141.5759,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.1346,
#           'Longitude': 145.2196,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.0899,
#           'Longitude': 141.0238,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.3823,
#           'Longitude': 141.3146,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.1462,
#           'Longitude': 145.2096,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.5243,
#           'Longitude': 142.0839,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 98,
#           'Latitude': -37.618,
#           'Longitude': 143.0013,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.8867,
#           'Longitude': 142.1873,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.9364,
#           'Longitude': 143.4996,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.3847,
#           'Longitude': 142.8935,
#           'Surface Temperature (Celcius)': 88}}
# {'fire': {'Confidence': 100,
#           'Latitude': -35.6374,
#           'Longitude': 142.3787,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.8835,
#           'Longitude': 142.2098,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.4125,
#           'Longitude': 143.1189,
#           'Surface Temperature (Celcius)': 92}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.0669,
#           'Longitude': 141.0556,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.0714,
#           'Longitude': 145.7665,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.2933,
#           'Longitude': 141.36,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.4591,
#           'Longitude': 144.9492,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.3487,
#           'Longitude': 145.5315,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.5399,
#           'Longitude': 144.678,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.8158,
#           'Longitude': 142.6229,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.4518,
#           'Longitude': 144.7752,
#           'Surface Temperature (Celcius)': 97}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.7903,
#           'Longitude': 141.618,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.1067,
#           'Longitude': 143.7948,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.1441,
#           'Longitude': 145.2221,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.4816,
#           'Longitude': 141.6635,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.0837,
#           'Longitude': 144.2448,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.782,
#           'Longitude': 141.8851,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.5586,
#           'Longitude': 144.0423,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.5568,
#           'Longitude': 144.0538,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.4538,
#           'Longitude': 144.763,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.4612,
#           'Longitude': 144.7775,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.7089,
#           'Longitude': 143.3518,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.601,
#           'Longitude': 144.6378,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.8681,
#           'Longitude': 143.5186,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.1999,
#           'Longitude': 143.8231,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.6171,
#           'Longitude': 142.9426,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 84,
#           'Latitude': -37.7587,
#           'Longitude': 142.8521,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.4611,
#           'Longitude': 144.9371,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.0254,
#           'Longitude': 142.3959,
#           'Surface Temperature (Celcius)': 99}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.88,
#           'Longitude': 143.7233,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.8885,
#           'Longitude': 143.9157,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 95,
#           'Latitude': -35.0706,
#           'Longitude': 141.4435,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.0795,
#           'Longitude': 143.2449,
#           'Surface Temperature (Celcius)': 91}}
# {'fire': {'Confidence': 100,
#           'Latitude': -35.1857,
#           'Longitude': 141.0604,
#           'Surface Temperature (Celcius)': 92}}
# {'fire': {'Confidence': 100,
#           'Latitude': -35.6469,
#           'Longitude': 142.376,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 91,
#           'Latitude': -35.6453,
#           'Longitude': 142.387,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.4409,
#           'Longitude': 141.6948,
#           'Surface Temperature (Celcius)': 92}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.9174,
#           'Longitude': 145.8678,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.9152,
#           'Longitude': 145.8808,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.8906,
#           'Longitude': 146.2035,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 100,
#           'Latitude': -35.8182,
#           'Longitude': 143.8739,
#           'Surface Temperature (Celcius)': 92}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.9246,
#           'Longitude': 146.2464,
#           'Surface Temperature (Celcius)': 96}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.3313,
#           'Longitude': 141.0017,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.2857,
#           'Longitude': 141.3467,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.0749,
#           'Longitude': 143.4058,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.4449,
#           'Longitude': 140.9836,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.3972,
#           'Longitude': 141.6041,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.5532,
#           'Longitude': 142.5349,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.1367,
#           'Longitude': 145.2071,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.1518,
#           'Longitude': 144.0233,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.1418,
#           'Longitude': 144.0261,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 75,
#           'Latitude': -36.7499,
#           'Longitude': 141.3006,
#           'Surface Temperature (Celcius)': 99}}
# {'fire': {'Confidence': 84,
#           'Latitude': -36.7432,
#           'Longitude': 141.3296,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 84,
#           'Latitude': -36.7531,
#           'Longitude': 141.3253,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 99,
#           'Latitude': -36.7943,
#           'Longitude': 143.9571,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.7957,
#           'Longitude': 143.9652,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 98,
#           'Latitude': -36.9329,
#           'Longitude': 143.7796,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 99,
#           'Latitude': -35.8276,
#           'Longitude': 143.7549,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 78,
#           'Latitude': -35.9326,
#           'Longitude': 141.958,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.6892,
#           'Longitude': 145.2775,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.73,
#           'Longitude': 143.935,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.8283,
#           'Longitude': 143.4605,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.6527,
#           'Longitude': 142.7392,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.1898,
#           'Longitude': 145.0922,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.8298,
#           'Longitude': 143.4483,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.6615,
#           'Longitude': 144.6014,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.8238,
#           'Longitude': 143.5724,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.1988,
#           'Longitude': 145.0941,
#           'Surface Temperature (Celcius)': 100}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.7651,
#           'Longitude': 143.5801,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.5199,
#           'Longitude': 144.7311,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.0782,
#           'Longitude': 145.3625,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.3966,
#           'Longitude': 141.406,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.1349,
#           'Longitude': 141.9491,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.6397,
#           'Longitude': 142.5968,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.6267,
#           'Longitude': 142.9993,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.5871,
#           'Longitude': 144.4958,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.2618,
#           'Longitude': 141.8783,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.6828,
#           'Longitude': 144.784,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.4843,
#           'Longitude': 143.0592,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 94,
#           'Latitude': -37.7274,
#           'Longitude': 142.9536,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.6964,
#           'Longitude': 142.8583,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 98,
#           'Latitude': -38.0509,
#           'Longitude': 143.9423,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.9284,
#           'Longitude': 143.108,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.5701,
#           'Longitude': 142.6497,
#           'Surface Temperature (Celcius)': 94}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.7101,
#           'Longitude': 142.3865,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 93,
#           'Latitude': -38.1693,
#           'Longitude': 143.0466,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.7128,
#           'Longitude': 142.3717,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.4885,
#           'Longitude': 142.0658,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 77,
#           'Latitude': -36.7101,
#           'Longitude': 142.981,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.0959,
#           'Longitude': 143.8206,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.9594,
#           'Longitude': 143.5638,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 98,
#           'Latitude': -36.5921,
#           'Longitude': 144.4905,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.6787,
#           'Longitude': 144.8042,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 84,
#           'Latitude': -38.0423,
#           'Longitude': 146.4048,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 94,
#           'Latitude': -38.1224,
#           'Longitude': 143.7553,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 94,
#           'Latitude': -38.0792,
#           'Longitude': 143.7361,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.9157,
#           'Longitude': 143.3544,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 96,
#           'Latitude': -37.7935,
#           'Longitude': 143.1606,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.7756,
#           'Longitude': 143.1388,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.7171,
#           'Longitude': 142.9505,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 94,
#           'Latitude': -37.7236,
#           'Longitude': 142.947,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.7002,
#           'Longitude': 142.9562,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.6498,
#           'Longitude': 142.5997,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.5728,
#           'Longitude': 142.6348,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.4352,
#           'Longitude': 143.1444,
#           'Surface Temperature (Celcius)': 96}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.5828,
#           'Longitude': 144.5775,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.5987,
#           'Longitude': 144.4995,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 98,
#           'Latitude': -36.5262,
#           'Longitude': 144.5737,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.6995,
#           'Longitude': 142.97799999999998,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.8879,
#           'Longitude': 141.6647,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 100,
#           'Latitude': -35.8768,
#           'Longitude': 145.4627,
#           'Surface Temperature (Celcius)': 86}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.4899,
#           'Longitude': 142.2805,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.663000000000004,
#           'Longitude': 141.3038,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.092,
#           'Longitude': 141.7306,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 89,
#           'Latitude': -34.9023,
#           'Longitude': 142.0557,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.2637,
#           'Longitude': 145.3649,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.2609,
#           'Longitude': 141.7999,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.91,
#           'Longitude': 141.0704,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.2652,
#           'Longitude': 145.3769,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.738,
#           'Longitude': 142.1177,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 89,
#           'Latitude': -37.876,
#           'Longitude': 143.7804,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 88,
#           'Latitude': -36.1546,
#           'Longitude': 141.8146,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 87,
#           'Latitude': -37.9091,
#           'Longitude': 143.5105,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 80,
#           'Latitude': -36.1559,
#           'Longitude': 141.8102,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.9071,
#           'Longitude': 143.53799999999998,
#           'Surface Temperature (Celcius)': 88}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.3902,
#           'Longitude': 148.2955,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.5027,
#           'Longitude': 146.347,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.5043,
#           'Longitude': 146.3299,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.1964,
#           'Longitude': 144.5217,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.769,
#           'Longitude': 147.94,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.1303,
#           'Longitude': 146.3606,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 98,
#           'Latitude': -36.1345,
#           'Longitude': 146.351,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 99,
#           'Latitude': -36.1586,
#           'Longitude': 145.6666,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.5847,
#           'Longitude': 145.1968,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.9111,
#           'Longitude': 142.692,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.5115,
#           'Longitude': 143.14,
#           'Surface Temperature (Celcius)': 86}}
# {'fire': {'Confidence': 86,
#           'Latitude': -37.6775,
#           'Longitude': 148.5131,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 87,
#           'Latitude': -36.3332,
#           'Longitude': 145.8594,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 70,
#           'Latitude': -36.9303,
#           'Longitude': 143.1034,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 83,
#           'Latitude': -36.3195,
#           'Longitude': 146.0601,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.5839,
#           'Longitude': 143.0588,
#           'Surface Temperature (Celcius)': 99}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.5854,
#           'Longitude': 143.0462,
#           'Surface Temperature (Celcius)': 94}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.3014,
#           'Longitude': 143.203,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.1917,
#           'Longitude': 147.0745,
#           'Surface Temperature (Celcius)': 94}}
# {'fire': {'Confidence': 95,
#           'Latitude': -38.1987,
#           'Longitude': 147.0666,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.5454,
#           'Longitude': 144.7402,
#           'Surface Temperature (Celcius)': 96}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.7593,
#           'Longitude': 142.895,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.3435,
#           'Longitude': 141.5513,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.6942,
#           'Longitude': 143.8021,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.3459,
#           'Longitude': 141.5586,
#           'Surface Temperature (Celcius)': 91}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.4046,
#           'Longitude': 141.1534,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.0594,
#           'Longitude': 141.5907,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.0576,
#           'Longitude': 141.6122,
#           'Surface Temperature (Celcius)': 94}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.388000000000005,
#           'Longitude': 141.8309,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.094,
#           'Longitude': 145.7646,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 99,
#           'Latitude': -36.5438,
#           'Longitude': 144.7548,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.6537,
#           'Longitude': 143.8781,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.663000000000004,
#           'Longitude': 142.8567,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 94,
#           'Latitude': -37.6982,
#           'Longitude': 143.0549,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.7187,
#           'Longitude': 143.805,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.7742,
#           'Longitude': 145.1991,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.5061,
#           'Longitude': 144.5675,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.4035,
#           'Longitude': 140.9935,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 99,
#           'Latitude': -36.4286,
#           'Longitude': 141.1567,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.3635,
#           'Longitude': 142.2809,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.664,
#           'Longitude': 142.8802,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.6564,
#           'Longitude': 142.8615,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.6657,
#           'Longitude': 143.1675,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 98,
#           'Latitude': -36.8742,
#           'Longitude': 142.7177,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.7751,
#           'Longitude': 145.1696,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.3961,
#           'Longitude': 140.9781,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.7708,
#           'Longitude': 145.1908,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 98,
#           'Latitude': -37.758,
#           'Longitude': 143.179,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 94,
#           'Latitude': -37.7609,
# ...
#           'Latitude': -37.7889,
#           'Longitude': 143.1324,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 93,
#           'Latitude': -36.2306,
#           'Longitude': 143.6408,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.4168,
#           'Longitude': 141.6939,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.4211,
#           'Longitude': 141.6875,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.8094,
#           'Longitude': 142.8885,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 84,
#           'Latitude': -37.8323,
#           'Longitude': 147.2232,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 98,
#           'Latitude': -38.2853,
#           'Longitude': 145.9519,
#           'Surface Temperature (Celcius)': 83}}
# {'fire': {'Confidence': 98,
#           'Latitude': -38.2375,
#           'Longitude': 142.8363,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.4463,
#           'Longitude': 142.7829,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.6854,
#           'Longitude': 143.4543,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 99,
#           'Latitude': -38.0881,
#           'Longitude': 143.9391,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 96,
#           'Latitude': -38.0866,
#           'Longitude': 143.9534,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 92,
#           'Latitude': -38.2391,
#           'Longitude': 142.82,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.5123,
#           'Longitude': 146.4007,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.3438,
#           'Longitude': 141.5832,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 94,
#           'Latitude': -37.4357,
#           'Longitude': 142.7813,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.5867,
#           'Longitude': 143.6256,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.2911,
#           'Longitude': 141.1664,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.2842,
#           'Longitude': 141.1741,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.7218,
#           'Longitude': 141.6411,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 84,
#           'Latitude': -37.3656,
#           'Longitude': 141.3903,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.4179,
#           'Longitude': 144.2924,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.3207,
#           'Longitude': 140.9737,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 99,
#           'Latitude': -36.2882,
#           'Longitude': 141.1821,
#           'Surface Temperature (Celcius)': 86}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.3153,
#           'Longitude': 140.9789,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.4169,
#           'Longitude': 144.2994,
#           'Surface Temperature (Celcius)': 81}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.4671,
#           'Longitude': 145.9962,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.3254,
#           'Longitude': 144.3638,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.0816,
#           'Longitude': 145.859,
#           'Surface Temperature (Celcius)': 98}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.1532,
#           'Longitude': 143.5527,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.0077,
#           'Longitude': 141.7747,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.0828,
#           'Longitude': 145.873,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.5541,
#           'Longitude': 144.1321,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 91,
#           'Latitude': -35.6819,
#           'Longitude': 143.5275,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 90,
#           'Latitude': -35.6871,
#           'Longitude': 143.5235,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.1506,
#           'Longitude': 143.5671,
#           'Surface Temperature (Celcius)': 95}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.4984,
#           'Longitude': 142.9739,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 96,
#           'Latitude': -37.253,
#           'Longitude': 144.3681,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.9396,
#           'Longitude': 143.1462,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.3387,
#           'Longitude': 141.7542,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.3433,
#           'Longitude': 143.4369,
#           'Surface Temperature (Celcius)': 94}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.345,
#           'Longitude': 143.4256,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.7032,
#           'Longitude': 144.0992,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.3402,
#           'Longitude': 141.7429,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.5661,
#           'Longitude': 142.2956,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 85,
#           'Latitude': -36.5023,
#           'Longitude': 143.6038,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.8616,
#           'Longitude': 142.8025,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 90,
#           'Latitude': -38.0372,
#           'Longitude': 146.0616,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 94,
#           'Latitude': -38.049,
#           'Longitude': 146.0513,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 89,
#           'Latitude': -35.4666,
#           'Longitude': 142.0749,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 95,
#           'Latitude': -36.0396,
#           'Longitude': 141.7183,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.2775,
#           'Longitude': 146.1026,
#           'Surface Temperature (Celcius)': 74}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.0361,
#           'Longitude': 146.0567,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.7746,
#           'Longitude': 146.6642,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.8359,
#           'Longitude': 146.6448,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 98,
#           'Latitude': -37.9085,
#           'Longitude': 141.1038,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 100,
#           'Latitude': -38.4349,
#           'Longitude': 146.3122,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 89,
#           'Latitude': -38.4792,
#           'Longitude': 146.3081,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.9047,
#           'Longitude': 141.0945,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.7685,
#           'Longitude': 142.7134,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.7801,
#           'Longitude': 142.7151,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 96,
#           'Latitude': -36.1002,
#           'Longitude': 142.3405,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 90,
#           'Latitude': -36.4325,
#           'Longitude': 144.3142,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 94,
#           'Latitude': -36.2693,
#           'Longitude': 143.1768,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 91,
#           'Latitude': -36.3774,
#           'Longitude': 143.7079,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.3756,
#           'Longitude': 143.7243,
#           'Surface Temperature (Celcius)': 88}}
# {'fire': {'Confidence': 97,
#           'Latitude': -36.369,
#           'Longitude': 143.7132,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.3799,
#           'Longitude': 143.7149,
#           'Surface Temperature (Celcius)': 89}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.8644,
#           'Longitude': 143.4263,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 89,
#           'Latitude': -38.3998,
#           'Longitude': 147.064,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 94,
#           'Latitude': -37.4796,
#           'Longitude': 141.9403,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 58,
#           'Latitude': -37.379,
#           'Longitude': 148.126,
#           'Surface Temperature (Celcius)': 82}}
# {'fire': {'Confidence': 62,
#           'Latitude': -37.379,
#           'Longitude': 148.132,
#           'Surface Temperature (Celcius)': 78}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.396,
#           'Longitude': 148.086,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.399,
#           'Longitude': 148.08100000000002,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.400999999999996,
#           'Longitude': 148.067,
#           'Surface Temperature (Celcius)': 79}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.446,
#           'Longitude': 148.102,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.406,
#           'Longitude': 148.123,
#           'Surface Temperature (Celcius)': 88}}
# {'fire': {'Confidence': 68,
#           'Latitude': -37.452,
#           'Longitude': 148.115,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 64,
#           'Latitude': -37.45,
#           'Longitude': 148.126,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 86,
#           'Latitude': -37.436,
#           'Longitude': 148.088,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 73,
#           'Latitude': -37.444,
#           'Longitude': 148.101,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 61,
#           'Latitude': -37.562,
#           'Longitude': 148.05,
#           'Surface Temperature (Celcius)': 72}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.461999999999996,
#           'Longitude': 148.089,
#           'Surface Temperature (Celcius)': 90}}
# {'fire': {'Confidence': 88,
#           'Latitude': -37.46,
#           'Longitude': 148.102,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 96,
#           'Latitude': -38.126999999999995,
#           'Longitude': 143.82,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.294000000000004,
#           'Longitude': 141.232,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.293,
#           'Longitude': 141.245,
#           'Surface Temperature (Celcius)': 85}}
# {'fire': {'Confidence': 91,
#           'Latitude': -37.247,
#           'Longitude': 141.278,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 92,
#           'Latitude': -36.098,
#           'Longitude': 143.74,
#           'Surface Temperature (Celcius)': 67}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.330999999999996,
#           'Longitude': 143.122,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.477,
#           'Longitude': 143.352,
#           'Surface Temperature (Celcius)': 93}}
# {'fire': {'Confidence': 96,
#           'Latitude': -37.475,
#           'Longitude': 143.365,
#           'Surface Temperature (Celcius)': 77}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.69,
#           'Longitude': 143.605,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 89,
#           'Latitude': -36.94,
#           'Longitude': 143.281,
#           'Surface Temperature (Celcius)': 69}}
# {'fire': {'Confidence': 87,
#           'Latitude': -37.861999999999995,
#           'Longitude': 144.175,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.945,
#           'Longitude': 144.35399999999998,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.606,
#           'Longitude': 149.312,
#           'Surface Temperature (Celcius)': 87}}
# {'fire': {'Confidence': 97,
#           'Latitude': -37.61,
#           'Longitude': 149.30700000000002,
#           'Surface Temperature (Celcius)': 80}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.609,
#           'Longitude': 149.32,
#           'Surface Temperature (Celcius)': 84}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.641999999999996,
#           'Longitude': 149.263,
#           'Surface Temperature (Celcius)': 65}}
# {'fire': {'Confidence': 100,
#           'Latitude': -37.634,
#           'Longitude': 149.237,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 98,
#           'Latitude': -37.605,
#           'Longitude': 149.30200000000002,
#           'Surface Temperature (Celcius)': 83}}
# {'fire': {'Confidence': 99,
#           'Latitude': -37.6,
#           'Longitude': 149.325,
#           'Surface Temperature (Celcius)': 86}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.618,
#           'Longitude': 149.281,
#           'Surface Temperature (Celcius)': 76}}
# {'fire': {'Confidence': 100,
#           'Latitude': -36.282,
#           'Longitude': 146.157,
#           'Surface Temperature (Celcius)': 71}}
# {'fire': {'Confidence': 92,
#           'Latitude': -37.95,
#           'Longitude': 142.366,
#           'Surface Temperature (Celcius)': 70}}
# {'fire': {'Confidence': 93,
#           'Latitude': -37.875,
#           'Longitude': 142.51,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 95,
#           'Latitude': -37.613,
#           'Longitude': 149.305,
#           'Surface Temperature (Celcius)': 75}}
# {'fire': {'Confidence': 90,
#           'Latitude': -37.624,
#           'Longitude': 149.314,
#           'Surface Temperature (Celcius)': 66}}
# {'fire': {'Confidence': 93,
#           'Latitude': -38.056999999999995,
#           'Longitude': 144.211,
#           'Surface Temperature (Celcius)': 73}}
# {'fire': {'Confidence': 78,
#           'Latitude': -37.966,
#           'Longitude': 145.05100000000002,
#           'Surface Temperature (Celcius)': 68}}
# {'fire': {'Confidence': 86,
#           'Latitude': -35.543,
#           'Longitude': 143.316,
#           'Surface Temperature (Celcius)': 67}}

# %% [markdown]
# A4.Find surface temperature (°C), air temperature (°C), relative humidity and maximum wind speed on 15th and 16th of December 2017.

# %%
# db.climate.aggregate([{
#     $match: { "Date": { $in: [ "2017-12-15", "2017-12-16" ] } }
#     },
#     {
#         $lookup:
#         {
#             from: "fire",
#             localField : "Date",
#             foreignField : "Date",
#             as : "FireData"
#         }
#     },
#     {
#         $unwind: "$FireData"
#     },
#     {
#         $replaceRoot: { newRoot: { $mergeObjects: [ "$FireData", "$$ROOT" ] } }
#     },
#     {
#         $project: 
#         { 
#             "_id": 0,
#             "Surface Temperature (Celcius)" : 1, 
#             "Air Temperature(Celcius)": 1,
#             "Relative Humidity": 1,
#             "Date": 1,
#             "Max Wind Speed": 1
#         }
#     }
# ]).pretty()

# %%
#Match Date in 2017-12-15 and 2017-12-16
#Project specified field
A4 = db.Combine.find({'Date': {"$in":["2017-12-15", "2017-12-16"]}},\
                     {'_id': 0,'Date':1,'AirTemperature(Celcius)':1,'MaxWindSpeed':1,\
                     'RelativeHumidity':1,'fire.Surface Temperature (Celcius)':1})

# %%
for ducoment in A4:
    pprint(ducoment)
# Out:
# {'AirTemperature(Celcius)': 18,
#  'Date': '2017-12-15',
#  'MaxWindSpeed': 14.0,
#  'RelativeHumidity': 52.0,
#  'fire': [{'Surface Temperature (Celcius)': 42},
#           {'Surface Temperature (Celcius)': 36},
#           {'Surface Temperature (Celcius)': 38},
#           {'Surface Temperature (Celcius)': 40}]}
# {'AirTemperature(Celcius)': 18,
#  'Date': '2017-12-16',
#  'MaxWindSpeed': 13.0,
#  'RelativeHumidity': 53.7,
#  'fire': [{'Surface Temperature (Celcius)': 43},
#           {'Surface Temperature (Celcius)': 33},
#           {'Surface Temperature (Celcius)': 54},
#           {'Surface Temperature (Celcius)': 73},
#           {'Surface Temperature (Celcius)': 55},
#           {'Surface Temperature (Celcius)': 75},
#           {'Surface Temperature (Celcius)': 55},
#           {'Surface Temperature (Celcius)': 66},
#           {'Surface Temperature (Celcius)': 56},
#           {'Surface Temperature (Celcius)': 60},
#           {'Surface Temperature (Celcius)': 73},
#           {'Surface Temperature (Celcius)': 48},
#           {'Surface Temperature (Celcius)': 55},
#           {'Surface Temperature (Celcius)': 64},
#           {'Surface Temperature (Celcius)': 57}]}

# %% [markdown]
# A5.Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
# db.fire.aggregate([
#     {
#         $match: {'Confidence':{$gte:80, $lte:100}}
#     },
#     {
#         $lookup:
#         {
#             from: "climate",
#             localField: "Date",
#             foreignField: "Date",
#             as:"climate"
#         }
#     },
#     {
#         $unwind: "$climate"
#     },
#     {
#         $replaceRoot: {newRoot: {$mergeObjects: ["$climate","$$ROOT"]}}
#     },
#     {
#         $project: 
#         { 
#             "_id": 0,
#             "Datetime" : 1, 
#             "Air Temperature(Celcius)": 1,
#             "Surface Temperature (Celcius)": 1,
#             "Confidence": 1
#         }
#     }
# ]).pretty()

# %%
#Unwind fire to ensure retrieve fire data as stand-alone record
#Match surface confidence between 80 and 100
#Project specified field
A5 = db.Combine.aggregate([{"$unwind":"$fire"},\
                            {"$match":{"fire.Confidence":{ "$gte":80,"$lte":100}}},\
                            {"$project":{'fire.Datetime':1,'AirTemperature(Celcius)':1,\
                            'fire.Confidence':1,'fire.Surface Temperature (Celcius)':1,'_id':0}}])

# %%
for document in A5: 
    pprint(document)
# Out:
# {'AirTemperature(Celcius)': 20,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-03-06T05:06:30',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 20,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-03-06T05:06:20',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-03-07T04:16:10',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-03-09T13:23:40',
#           'Surface Temperature (Celcius)': 41}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-10T04:48:40',
#           'Surface Temperature (Celcius)': 105}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-10T04:46:20',
#           'Surface Temperature (Celcius)': 109}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-03-10T04:45:30',
#           'Surface Temperature (Celcius)': 73}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-03-10T04:45:30',
#           'Surface Temperature (Celcius)': 80}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-10T04:43:50',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-03-12T04:33:50',
#           'Surface Temperature (Celcius)': 105}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-03-12T04:29:50',
#           'Surface Temperature (Celcius)': 71}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-12T04:28:20',
#           'Surface Temperature (Celcius)': 99}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-03-12T04:28:00',
#           'Surface Temperature (Celcius)': 68}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-03-12T04:27:20',
#           'Surface Temperature (Celcius)': 98}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-03-14T04:24:40',
#           'Surface Temperature (Celcius)': 67}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-03-14T04:22:20',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-03-14T04:20:50',
#           'Surface Temperature (Celcius)': 68}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-03-14T04:16:30',
#           'Surface Temperature (Celcius)': 75}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-03-14T04:16:20',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-14T04:14:40',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-03-14T04:14:30',
#           'Surface Temperature (Celcius)': 79}}
# {'AirTemperature(Celcius)': 25,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-03-14T04:14:30',
#           'Surface Temperature (Celcius)': 75}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-03-17T04:48:20',
#           'Surface Temperature (Celcius)': 74}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-03-17T04:45:10',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-03-17T04:45:00',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-18T03:50:50',
#           'Surface Temperature (Celcius)': 121}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-03-18T03:50:40',
#           'Surface Temperature (Celcius)': 80}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-03-19T04:39:50',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-03-19T04:39:20',
#           'Surface Temperature (Celcius)': 79}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-03-19T04:36:00',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-03-19T04:33:00',
#           'Surface Temperature (Celcius)': 83}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-19T04:32:50',
#           'Surface Temperature (Celcius)': 91}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-03-19T04:32:50',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-19T04:32:40',
#           'Surface Temperature (Celcius)': 113}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-03-19T04:32:40',
#           'Surface Temperature (Celcius)': 70}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-19T04:32:40',
#           'Surface Temperature (Celcius)': 106}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-03-25T03:59:50',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-03-25T03:58:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-03-25T03:58:10',
#           'Surface Temperature (Celcius)': 75}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-03-25T03:57:10',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-25T03:57:10',
#           'Surface Temperature (Celcius)': 111}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-03-25T03:57:10',
#           'Surface Temperature (Celcius)': 77}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-25T03:56:40',
#           'Surface Temperature (Celcius)': 99}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-26T04:43:20',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-03-26T04:40:50',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-26T04:39:50',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 91,
#           'Datetime': '2017-03-26T04:39:10',
#           'Surface Temperature (Celcius)': 68}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-03-26T04:39:10',
#           'Surface Temperature (Celcius)': 70}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-26T04:39:10',
#           'Surface Temperature (Celcius)': 89}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-03-26T04:39:10',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-03-26T04:39:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-03-26T04:39:10',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-03-28T04:38:00',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-03-28T04:33:40',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-03-28T04:33:30',
#           'Surface Temperature (Celcius)': 71}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-03-28T04:33:30',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-03-28T04:32:20',
#           'Surface Temperature (Celcius)': 73}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-03-28T04:30:50',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-03-28T04:30:20',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-03-28T04:30:10',
#           'Surface Temperature (Celcius)': 74}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-03-28T04:30:10',
#           'Surface Temperature (Celcius)': 82}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-28T04:30:10',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-03-28T04:30:10',
#           'Surface Temperature (Celcius)': 80}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-28T04:28:30',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-03-28T04:28:30',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-03-28T04:28:30',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-03-28T04:27:40',
#           'Surface Temperature (Celcius)': 80}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-28T04:27:20',
#           'Surface Temperature (Celcius)': 107}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-28T04:27:10',
#           'Surface Temperature (Celcius)': 108}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-03-28T04:27:00',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 99,
#           'Datetime': '2017-03-28T04:27:00',
#           'Surface Temperature (Celcius)': 86}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 90}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 81}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 81}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-03-28T04:26:50',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-03-31T05:07:10',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-03-31T05:01:20',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-03-31T04:58:30',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-03-31T04:58:00',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-03-31T04:57:10',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-03-31T00:36:30',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 91,
#           'Datetime': '2017-04-03T13:17:00',
#           'Surface Temperature (Celcius)': 43}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-03T13:15:30',
#           'Surface Temperature (Celcius)': 40}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-03T13:15:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-04-03T13:15:10',
#           'Surface Temperature (Celcius)': 45}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-03T03:59:10',
#           'Surface Temperature (Celcius)': 96}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-03T03:57:50',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-03T03:56:20',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-03T03:55:10',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-04-03T03:55:10',
#           'Surface Temperature (Celcius)': 77}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-04-03T03:54:00',
#           'Surface Temperature (Celcius)': 78}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-03T03:53:50',
#           'Surface Temperature (Celcius)': 93}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-03T03:53:30',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-03T03:52:30',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-03T03:52:30',
#           'Surface Temperature (Celcius)': 90}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-03T03:52:20',
#           'Surface Temperature (Celcius)': 115}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-03T03:52:10',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-03T03:52:10',
#           'Surface Temperature (Celcius)': 98}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-03T03:52:10',
#           'Surface Temperature (Celcius)': 89}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-03T03:52:10',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-03T03:51:30',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-03T03:51:30',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-03T03:51:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-03T03:51:00',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-04-03T03:51:00',
#           'Surface Temperature (Celcius)': 82}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-03T03:51:00',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-03T03:51:00',
#           'Surface Temperature (Celcius)': 103}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-03T03:50:50',
#           'Surface Temperature (Celcius)': 97}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-03T03:50:50',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 99,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 86}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-03T03:50:40',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-03T01:07:20',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-04T15:31:00',
#           'Surface Temperature (Celcius)': 44}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T15:30:40',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-04T04:41:50',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-04T04:41:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-04T04:41:00',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-04T04:41:00',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:40:00',
#           'Surface Temperature (Celcius)': 120}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-04T04:39:50',
#           'Surface Temperature (Celcius)': 67}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-04T04:39:50',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-04T04:39:40',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-04T04:39:40',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:39:20',
#           'Surface Temperature (Celcius)': 107}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-04T04:37:10',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-04T04:36:10',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-04T04:36:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-04T04:36:00',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:35:00',
#           'Surface Temperature (Celcius)': 95}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-04T04:34:50',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-04T04:34:20',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-04-04T04:34:20',
#           'Surface Temperature (Celcius)': 78}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-04T04:34:20',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-04T04:34:00',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-04T04:33:50',
#           'Surface Temperature (Celcius)': 81}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-04T04:33:40',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:33:30',
#           'Surface Temperature (Celcius)': 113}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-04T04:33:30',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-04T04:33:30',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-04T04:33:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-04T04:33:10',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-04-04T04:33:00',
#           'Surface Temperature (Celcius)': 79}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-04T04:33:00',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-04-04T04:32:50',
#           'Surface Temperature (Celcius)': 82}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-04T04:32:50',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-04T04:32:50',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-04T04:32:50',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:32:50',
#           'Surface Temperature (Celcius)': 123}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-04T04:32:50',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:32:50',
#           'Surface Temperature (Celcius)': 118}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 78}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 120}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 92}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 101}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:32:40',
#           'Surface Temperature (Celcius)': 98}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-04T00:12:50',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-05T13:09:00',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-05T13:09:00',
#           'Surface Temperature (Celcius)': 39}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-05T13:08:40',
#           'Surface Temperature (Celcius)': 44}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-05T13:08:40',
#           'Surface Temperature (Celcius)': 47}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-05T13:07:00',
#           'Surface Temperature (Celcius)': 40}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-05T13:04:20',
#           'Surface Temperature (Celcius)': 49}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-05T13:03:20',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-04-05T13:03:00',
#           'Surface Temperature (Celcius)': 45}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-05T13:03:00',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-05T13:03:00',
#           'Surface Temperature (Celcius)': 39}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-05T13:02:40',
#           'Surface Temperature (Celcius)': 42}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-05T13:02:40',
#           'Surface Temperature (Celcius)': 39}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-05T05:16:50',
#           'Surface Temperature (Celcius)': 88}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-05T05:15:30',
#           'Surface Temperature (Celcius)': 83}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-05T03:40:50',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-04-05T03:40:30',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-05T03:40:20',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-05T03:39:30',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-05T03:39:30',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-05T03:39:20',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-05T03:39:20',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-05T03:39:10',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-05T03:39:10',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-04-05T03:39:10',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-05T03:39:10',
#           'Surface Temperature (Celcius)': 92}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-05T03:39:10',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-05T03:39:10',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-04-06T13:45:30',
#           'Surface Temperature (Celcius)': 45}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-06T04:32:20',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-06T04:31:10',
#           'Surface Temperature (Celcius)': 69}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:27:50',
#           'Surface Temperature (Celcius)': 95}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:27:50',
#           'Surface Temperature (Celcius)': 88}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-06T04:27:10',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:27:00',
#           'Surface Temperature (Celcius)': 97}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-06T04:27:00',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-06T04:27:00',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:27:00',
#           'Surface Temperature (Celcius)': 99}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-06T04:27:00',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-06T04:24:40',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-06T04:24:20',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-06T04:24:20',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-06T04:24:00',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-06T04:23:50',
#           'Surface Temperature (Celcius)': 70}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 99,
#           'Datetime': '2017-04-06T04:23:50',
#           'Surface Temperature (Celcius)': 85}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-06T04:23:30',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-06T04:23:10',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-06T04:23:00',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-06T04:22:40',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-06T04:22:20',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-06T04:22:20',
#           'Surface Temperature (Celcius)': 71}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-06T04:22:20',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:22:20',
#           'Surface Temperature (Celcius)': 103}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 91,
#           'Datetime': '2017-04-06T04:22:20',
#           'Surface Temperature (Celcius)': 69}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-06T04:22:10',
#           'Surface Temperature (Celcius)': 68}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-06T04:22:10',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-06T04:22:10',
#           'Surface Temperature (Celcius)': 67}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-06T04:21:30',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-04-06T04:21:10',
#           'Surface Temperature (Celcius)': 96}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:21:00',
#           'Surface Temperature (Celcius)': 115}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-06T04:21:00',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:20:50',
#           'Surface Temperature (Celcius)': 95}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-04-06T04:20:50',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-06T04:20:50',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 78}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 77}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 91,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 68}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 81}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 104}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 71}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 67}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 86}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 100}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-04-06T04:20:40',
#           'Surface Temperature (Celcius)': 89}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-07T12:56:50',
#           'Surface Temperature (Celcius)': 41}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-07T12:56:30',
#           'Surface Temperature (Celcius)': 39}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-04-07T12:56:30',
#           'Surface Temperature (Celcius)': 49}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-07T12:53:40',
#           'Surface Temperature (Celcius)': 41}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-07T12:52:10',
#           'Surface Temperature (Celcius)': 41}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-04-07T12:51:20',
#           'Surface Temperature (Celcius)': 45}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-07T12:51:00',
#           'Surface Temperature (Celcius)': 49}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-07T12:50:50',
#           'Surface Temperature (Celcius)': 43}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-04-07T12:50:40',
#           'Surface Temperature (Celcius)': 42}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-07T05:09:50',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-07T05:03:10',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-07T05:03:10',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-07T03:31:40',
#           'Surface Temperature (Celcius)': 89}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-04-07T03:28:20',
#           'Surface Temperature (Celcius)': 78}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-07T03:27:30',
#           'Surface Temperature (Celcius)': 70}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-07T03:27:20',
#           'Surface Temperature (Celcius)': 70}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-04-07T03:27:20',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 21,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-07T03:27:10',
#           'Surface Temperature (Celcius)': 106}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 99,
#           'Datetime': '2017-04-08T04:14:00',
#           'Surface Temperature (Celcius)': 85}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 91,
#           'Datetime': '2017-04-08T04:12:50',
#           'Surface Temperature (Celcius)': 69}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-08T04:12:20',
#           'Surface Temperature (Celcius)': 94}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-08T04:12:00',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-04-08T04:08:50',
#           'Surface Temperature (Celcius)': 83}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-04-08T04:08:30',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-08T04:08:30',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-08T04:08:30',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-04-08T04:08:30',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-04-11T04:39:20',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-11T04:39:00',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-11T04:39:00',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-12T13:15:10',
#           'Surface Temperature (Celcius)': 43}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-12T05:28:10',
#           'Surface Temperature (Celcius)': 106}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-12T05:28:00',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-04-12T05:21:40',
#           'Surface Temperature (Celcius)': 75}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-12T05:21:40',
#           'Surface Temperature (Celcius)': 98}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-04-12T03:54:10',
#           'Surface Temperature (Celcius)': 77}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-12T03:50:00',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-04-12T03:50:00',
#           'Surface Temperature (Celcius)': 75}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-04-12T03:50:00',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-04-12T03:47:50',
#           'Surface Temperature (Celcius)': 70}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-12T03:47:50',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-12T03:47:30',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-12T03:47:30',
#           'Surface Temperature (Celcius)': 106}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-04-12T03:47:20',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-04-12T03:47:20',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-04-12T03:45:10',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-12T03:44:50',
#           'Surface Temperature (Celcius)': 98}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-04-12T03:44:40',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-12T03:44:40',
#           'Surface Temperature (Celcius)': 71}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-04-12T03:44:40',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-12T03:44:40',
#           'Surface Temperature (Celcius)': 73}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-12T03:44:40',
#           'Surface Temperature (Celcius)': 111}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-04-13T04:38:00',
#           'Surface Temperature (Celcius)': 78}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-04-13T04:38:00',
#           'Surface Temperature (Celcius)': 72}}
# {'AirTemperature(Celcius)': 16,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-13T04:38:00',
#           'Surface Temperature (Celcius)': 97}}
# ...
#           'Surface Temperature (Celcius)': 50}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-09-24T04:04:19',
#           'Surface Temperature (Celcius)': 88}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-09-24T04:04:18',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-09-24T04:04:04',
#           'Surface Temperature (Celcius)': 52}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-09-27T04:35:36',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-09-27T04:35:36',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-09-29T04:22:31',
#           'Surface Temperature (Celcius)': 49}}
# {'AirTemperature(Celcius)': 12,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-10-01T15:13:56',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 12,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-10-01T04:10:28',
#           'Surface Temperature (Celcius)': 52}}
# {'AirTemperature(Celcius)': 12,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-10-01T04:10:28',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 11,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-10-02T04:53:10',
#           'Surface Temperature (Celcius)': 50}}
# {'AirTemperature(Celcius)': 11,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-10-02T04:53:09',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-10-03T13:23:43',
#           'Surface Temperature (Celcius)': 42}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-10-03T03:58:15',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-10-03T03:58:15',
#           'Surface Temperature (Celcius)': 48}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-10-03T03:58:15',
#           'Surface Temperature (Celcius)': 49}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-10-03T03:58:15',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-10-03T03:58:15',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-10-03T03:58:14',
#           'Surface Temperature (Celcius)': 90}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-10-03T03:58:14',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-10-03T03:58:14',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-10-04T04:41:02',
#           'Surface Temperature (Celcius)': 46}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-10-04T04:41:00',
#           'Surface Temperature (Celcius)': 46}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-10-04T04:41:00',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 19,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-10-04T04:41:00',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 91,
#           'Datetime': '2017-10-07T12:59:33',
#           'Surface Temperature (Celcius)': 42}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-10-10T04:04:19',
#           'Surface Temperature (Celcius)': 77}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-10-15T04:23:01',
#           'Surface Temperature (Celcius)': 87}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 99,
#           'Datetime': '2017-10-15T04:23:01',
#           'Surface Temperature (Celcius)': 85}}
# {'AirTemperature(Celcius)': 22,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-10-17T13:36:12',
#           'Surface Temperature (Celcius)': 43}}
# {'AirTemperature(Celcius)': 22,
#  'fire': {'Confidence': 91,
#           'Datetime': '2017-10-17T04:10:45',
#           'Surface Temperature (Celcius)': 68}}
# {'AirTemperature(Celcius)': 22,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-10-17T04:10:32',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-10-18T00:39:02',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-10-18T00:39:02',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-10-20T04:41:19',
#           'Surface Temperature (Celcius)': 46}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-10-20T04:41:19',
#           'Surface Temperature (Celcius)': 50}}
# {'AirTemperature(Celcius)': 12,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-10-21T01:09:55',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 12,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-10-21T01:09:54',
#           'Surface Temperature (Celcius)': 67}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-10-26T13:30:31',
#           'Surface Temperature (Celcius)': 48}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-10-26T13:30:31',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 22,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-10-27T04:47:31',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-10-28T03:52:17',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-11-05T04:41:34',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-11-05T04:41:19',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 13,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-11-05T04:41:19',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-11-09T04:16:48',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-09T04:16:48',
#           'Surface Temperature (Celcius)': 93}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 96,
#           'Datetime': '2017-11-09T04:16:48',
#           'Surface Temperature (Celcius)': 77}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-11-09T04:16:44',
#           'Surface Temperature (Celcius)': 62}}
# {'AirTemperature(Celcius)': 14,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-11-09T04:16:44',
#           'Surface Temperature (Celcius)': 80}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-11-11T13:30:08',
#           'Surface Temperature (Celcius)': 37}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-11T13:30:08',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-11-11T04:04:25',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 89,
#           'Datetime': '2017-11-12T00:33:15',
#           'Surface Temperature (Celcius)': 69}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-11-13T03:52:15',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-11-13T03:52:14',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-11-14T04:35:04',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 85,
#           'Datetime': '2017-11-21T00:27:21',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-11-22T03:46:00',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 23,
#  'fire': {'Confidence': 88,
#           'Datetime': '2017-11-22T03:46:00',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-11-23T04:28:59',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 24,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-11-23T04:28:59',
#           'Surface Temperature (Celcius)': 73}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-29T13:17:24',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-29T03:52:10',
#           'Surface Temperature (Celcius)': 87}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 97,
#           'Datetime': '2017-11-29T03:52:10',
#           'Surface Temperature (Celcius)': 80}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 99,
#           'Datetime': '2017-11-29T03:52:10',
#           'Surface Temperature (Celcius)': 84}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-30T15:38:36',
#           'Surface Temperature (Celcius)': 53}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-30T15:38:35',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-30T15:38:35',
#           'Surface Temperature (Celcius)': 49}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-11-30T12:22:15',
#           'Surface Temperature (Celcius)': 38}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-11-30T12:22:15',
#           'Surface Temperature (Celcius)': 42}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-30T12:22:15',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-30T12:22:15',
#           'Surface Temperature (Celcius)': 65}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-11-30T12:22:14',
#           'Surface Temperature (Celcius)': 71}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-11-30T04:35:00',
#           'Surface Temperature (Celcius)': 59}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 98,
#           'Datetime': '2017-11-30T04:34:57',
#           'Surface Temperature (Celcius)': 83}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-11-30T04:34:57',
#           'Surface Temperature (Celcius)': 57}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-11-30T04:34:57',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 99,
#           'Datetime': '2017-11-30T04:34:57',
#           'Surface Temperature (Celcius)': 86}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-11-30T00:20:53',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-11-30T00:20:53',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-11-30T00:20:53',
#           'Surface Temperature (Celcius)': 76}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-11-30T00:20:53',
#           'Surface Temperature (Celcius)': 56}}
# {'AirTemperature(Celcius)': 26,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-11-30T00:20:53',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-12-08T13:11:44',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-12-08T13:11:44',
#           'Surface Temperature (Celcius)': 71}}
# {'AirTemperature(Celcius)': 15,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-12-08T13:11:43',
#           'Surface Temperature (Celcius)': 52}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 87,
#           'Datetime': '2017-12-09T00:14:34',
#           'Surface Temperature (Celcius)': 61}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 81,
#           'Datetime': '2017-12-09T00:14:34',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-12-09T00:14:33',
#           'Surface Temperature (Celcius)': 58}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-12-09T00:14:33',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 83,
#           'Datetime': '2017-12-13T04:04:19',
#           'Surface Temperature (Celcius)': 60}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-12-14T04:47:25',
#           'Surface Temperature (Celcius)': 70}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 92,
#           'Datetime': '2017-12-15T13:17:17',
#           'Surface Temperature (Celcius)': 42}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 94,
#           'Datetime': '2017-12-16T15:38:39',
#           'Surface Temperature (Celcius)': 43}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-12-16T04:35:13',
#           'Surface Temperature (Celcius)': 73}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 84,
#           'Datetime': '2017-12-16T04:34:58',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 95,
#           'Datetime': '2017-12-16T04:34:58',
#           'Surface Temperature (Celcius)': 75}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 90,
#           'Datetime': '2017-12-16T04:34:57',
#           'Surface Temperature (Celcius)': 66}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 93,
#           'Datetime': '2017-12-16T00:21:12',
#           'Surface Temperature (Celcius)': 73}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-12-16T00:21:11',
#           'Surface Temperature (Celcius)': 55}}
# {'AirTemperature(Celcius)': 18,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-12-16T00:20:53',
#           'Surface Temperature (Celcius)': 64}}
# {'AirTemperature(Celcius)': 17,
#  'fire': {'Confidence': 80,
#           'Datetime': '2017-12-25T04:29:08',
#           'Surface Temperature (Celcius)': 54}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 82,
#           'Datetime': '2017-12-27T00:02:15',
#           'Surface Temperature (Celcius)': 63}}
# {'AirTemperature(Celcius)': 28,
#  'fire': {'Confidence': 86,
#           'Datetime': '2017-12-27T00:02:14',
#           'Surface Temperature (Celcius)': 67}}

# %% [markdown]
# A6. Find top 10 records with highest surface temperature (°C).

# %%
# db.fire.find({},{"_id":0}).sort({"Surface Temperature (Celcius)":-1}).limit(10).pretty();

# %%
#Unwind fire to ensure retrieve fire data as stand-alone record
#Sort by surface temperature in descending order(max to min)
#Project specified field
A6 = db.Combine.aggregate([{"$unwind": "$fire"},\
                            {"$sort": {"fire.Surface Temperature (Celcius)":-1}},\
                            {"$limit":10},\
                            {"$project":{'_id':0}}])

# %%
for document in A6: 
    pprint(document)
# Out:
# {'AirTemperature(Celcius)': 15,
#  'Date': '2017-04-18',
#  'MAX': '69.8*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 9.9,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 56.1,
#  'Station': 948701,
#  'WindSpeed(knots)': 5.1,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-18T04:52:00',
#           'Latitude': -38.1665,
#           'Longitude': 143.062,
#           'Power': 239.8,
#           'Surface Temperature (Celcius)': 124,
#           'Surface Temperature (kelvin)': 397.5}}
# {'AirTemperature(Celcius)': 16,
#  'Date': '2017-04-04',
#  'MAX': '73.4*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 12.0,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 47.5,
#  'Station': 948701,
#  'WindSpeed(knots)': 5.4,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:32:50',
#           'Latitude': -36.343,
#           'Longitude': 142.1986,
#           'Power': 233.4,
#           'Surface Temperature (Celcius)': 123,
#           'Surface Temperature (kelvin)': 396.3}}
# {'AirTemperature(Celcius)': 14,
#  'Date': '2017-05-01',
#  'MAX': '67.5*',
#  'MIN': '51.3*',
#  'MaxWindSpeed': 20.0,
#  'Precipitation': '0.12G',
#  'RelativeHumidity': 49.2,
#  'Station': 948701,
#  'WindSpeed(knots)': 10.5,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-05-01T04:14:20',
#           'Latitude': -36.9318,
#           'Longitude': 143.0907,
#           'Power': 236.0,
#           'Surface Temperature (Celcius)': 122,
#           'Surface Temperature (kelvin)': 396.0}}
# {'AirTemperature(Celcius)': 21,
#  'Date': '2017-03-18',
#  'MAX': '84.9*',
#  'MIN': '51.6',
#  'MaxWindSpeed': 11.1,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 52.8,
#  'Station': 948701,
#  'WindSpeed(knots)': 4.1,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-03-18T03:50:50',
#           'Latitude': -37.016999999999996,
#           'Longitude': 148.1297,
#           'Power': 224.3,
#           'Surface Temperature (Celcius)': 121,
#           'Surface Temperature (kelvin)': 394.3}}
# {'AirTemperature(Celcius)': 16,
#  'Date': '2017-04-04',
#  'MAX': '73.4*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 12.0,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 47.5,
#  'Station': 948701,
#  'WindSpeed(knots)': 5.4,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:40:00',
#           'Latitude': -36.1057,
#           'Longitude': 141.7608,
#           'Power': 212.5,
#           'Surface Temperature (Celcius)': 120,
#           'Surface Temperature (kelvin)': 393.8}}
# {'AirTemperature(Celcius)': 15,
#  'Date': '2017-04-18',
#  'MAX': '69.8*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 9.9,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 56.1,
#  'Station': 948701,
#  'WindSpeed(knots)': 5.1,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-18T04:44:50',
#           'Latitude': -37.8326,
#           'Longitude': 143.4999,
#           'Power': 220.4,
#           'Surface Temperature (Celcius)': 120,
#           'Surface Temperature (kelvin)': 393.8}}
# {'AirTemperature(Celcius)': 9,
#  'Date': '2017-05-13',
#  'MAX': '58.5*',
#  'MIN': '41.4*',
#  'MaxWindSpeed': 8.0,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 44.0,
#  'Station': 948701,
#  'WindSpeed(knots)': 2.8,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-05-13T04:40:20',
#           'Latitude': -34.9938,
#           'Longitude': 141.876,
#           'Power': 223.8,
#           'Surface Temperature (Celcius)': 120,
#           'Surface Temperature (kelvin)': 394.0}}
# {'AirTemperature(Celcius)': 16,
#  'Date': '2017-04-04',
#  'MAX': '73.4*',
#  'MIN': '46.8',
#  'MaxWindSpeed': 12.0,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 47.5,
#  'Station': 948701,
#  'WindSpeed(knots)': 5.4,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-04T04:32:40',
#           'Latitude': -36.3521,
#           'Longitude': 142.2008,
#           'Power': 218.7,
#           'Surface Temperature (Celcius)': 120,
#           'Surface Temperature (kelvin)': 394.0}}
# {'AirTemperature(Celcius)': 16,
#  'Date': '2017-04-13',
#  'MAX': '69.1*',
#  'MIN': '48.2',
#  'MaxWindSpeed': 9.9,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 54.9,
#  'Station': 948701,
#  'WindSpeed(knots)': 5.9,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-04-13T04:28:10',
#           'Latitude': -37.0745,
#           'Longitude': 141.0692,
#           'Power': 218.7,
#           'Surface Temperature (Celcius)': 120,
#           'Surface Temperature (kelvin)': 393.7}}
# {'AirTemperature(Celcius)': 10,
#  'Date': '2017-05-04',
#  'MAX': '59.7*',
#  'MIN': '39.4',
#  'MaxWindSpeed': 7.0,
#  'Precipitation': '0.00I',
#  'RelativeHumidity': 43.3,
#  'Station': 948701,
#  'WindSpeed(knots)': 2.6,
#  'fire': {'Confidence': 100,
#           'Datetime': '2017-05-04T04:44:50',
#           'Latitude': -36.4057,
#           'Longitude': 140.9806,
#           'Power': 214.4,
#           'Surface Temperature (Celcius)': 119,
#           'Surface Temperature (kelvin)': 392.2}}

# %% [markdown]
# A7. Find the number of fire in each day. You are required to only display total number of fire
# and the date in the output.

# %%
# db.fire.aggregate(
# [
#     {
#         $group : 
#         {
#             _id : "$Date",
#             "Firecount" : {$sum : 1}
#         }
#     },
#     {
#         $sort :
#         {
#             '_id': 1
#         }
#     },
#     { 
#         $project: 
#         {  
#             _id: 0,
#             "Date": "$_id",
#             Firecount: 1
#         }
#     }
# ])

# %%
#Unwind fire to ensure retrieve fire data as stand-alone record
#Count only date has fire
#group by date and caculate sum
#sort by date
#Project specified field
A7 = db.Combine.aggregate([{"$unwind": "$fire"},\
                            {"$match": {"fire" : {"$ne": []}}},\
                            {"$group":{'_id':'$Date','Firecount':{'$sum':1}}},\
                            {"$sort":{'_id':1}},\
                            {"$project":{'_id':0,"Date":'$_id','Firecount':1}}])

# %%
for document in A7: 
    pprint(document)
# Out:
# {'Date': '2017-03-06', 'Firecount': 2}
# {'Date': '2017-03-07', 'Firecount': 1}
# {'Date': '2017-03-08', 'Firecount': 2}
# {'Date': '2017-03-09', 'Firecount': 3}
# {'Date': '2017-03-10', 'Firecount': 8}
# {'Date': '2017-03-12', 'Firecount': 5}
# {'Date': '2017-03-13', 'Firecount': 2}
# {'Date': '2017-03-14', 'Firecount': 10}
# {'Date': '2017-03-15', 'Firecount': 7}
# {'Date': '2017-03-17', 'Firecount': 6}
# {'Date': '2017-03-18', 'Firecount': 3}
# {'Date': '2017-03-19', 'Firecount': 21}
# {'Date': '2017-03-24', 'Firecount': 2}
# {'Date': '2017-03-25', 'Firecount': 13}
# {'Date': '2017-03-26', 'Firecount': 17}
# {'Date': '2017-03-28', 'Firecount': 54}
# {'Date': '2017-03-29', 'Firecount': 1}
# {'Date': '2017-03-31', 'Firecount': 22}
# {'Date': '2017-04-01', 'Firecount': 7}
# {'Date': '2017-04-02', 'Firecount': 5}
# {'Date': '2017-04-03', 'Firecount': 72}
# {'Date': '2017-04-04', 'Firecount': 89}
# {'Date': '2017-04-05', 'Firecount': 49}
# {'Date': '2017-04-06', 'Firecount': 118}
# {'Date': '2017-04-07', 'Firecount': 39}
# {'Date': '2017-04-08', 'Firecount': 20}
# {'Date': '2017-04-11', 'Firecount': 24}
# {'Date': '2017-04-12', 'Firecount': 69}
# {'Date': '2017-04-13', 'Firecount': 357}
# {'Date': '2017-04-14', 'Firecount': 18}
# {'Date': '2017-04-15', 'Firecount': 69}
# {'Date': '2017-04-16', 'Firecount': 18}
# {'Date': '2017-04-17', 'Firecount': 38}
# {'Date': '2017-04-18', 'Firecount': 325}
# {'Date': '2017-04-19', 'Firecount': 50}
# {'Date': '2017-04-20', 'Firecount': 31}
# {'Date': '2017-04-22', 'Firecount': 2}
# {'Date': '2017-04-23', 'Firecount': 19}
# {'Date': '2017-04-24', 'Firecount': 8}
# {'Date': '2017-04-25', 'Firecount': 3}
# {'Date': '2017-04-26', 'Firecount': 1}
# {'Date': '2017-04-29', 'Firecount': 3}
# {'Date': '2017-05-01', 'Firecount': 20}
# {'Date': '2017-05-02', 'Firecount': 10}
# {'Date': '2017-05-03', 'Firecount': 64}
# {'Date': '2017-05-04', 'Firecount': 135}
# {'Date': '2017-05-05', 'Firecount': 31}
# {'Date': '2017-05-06', 'Firecount': 17}
# {'Date': '2017-05-07', 'Firecount': 3}
# {'Date': '2017-05-08', 'Firecount': 24}
# {'Date': '2017-05-09', 'Firecount': 13}
# {'Date': '2017-05-10', 'Firecount': 114}
# {'Date': '2017-05-11', 'Firecount': 19}
# {'Date': '2017-05-12', 'Firecount': 10}
# {'Date': '2017-05-13', 'Firecount': 54}
# {'Date': '2017-05-14', 'Firecount': 1}
# {'Date': '2017-05-15', 'Firecount': 102}
# {'Date': '2017-05-16', 'Firecount': 3}
# {'Date': '2017-05-17', 'Firecount': 1}
# {'Date': '2017-05-18', 'Firecount': 7}
# {'Date': '2017-05-22', 'Firecount': 33}
# {'Date': '2017-05-23', 'Firecount': 5}
# {'Date': '2017-05-24', 'Firecount': 3}
# {'Date': '2017-05-26', 'Firecount': 4}
# {'Date': '2017-06-01', 'Firecount': 2}
# {'Date': '2017-06-02', 'Firecount': 11}
# {'Date': '2017-06-03', 'Firecount': 2}
# {'Date': '2017-06-04', 'Firecount': 9}
# {'Date': '2017-06-07', 'Firecount': 14}
# {'Date': '2017-06-09', 'Firecount': 3}
# {'Date': '2017-06-11', 'Firecount': 2}
# {'Date': '2017-06-13', 'Firecount': 1}
# {'Date': '2017-06-14', 'Firecount': 4}
# {'Date': '2017-06-16', 'Firecount': 2}
# {'Date': '2017-06-18', 'Firecount': 2}
# {'Date': '2017-06-20', 'Firecount': 6}
# {'Date': '2017-06-22', 'Firecount': 1}
# {'Date': '2017-06-30', 'Firecount': 6}
# {'Date': '2017-07-01', 'Firecount': 4}
# {'Date': '2017-07-02', 'Firecount': 8}
# {'Date': '2017-07-04', 'Firecount': 1}
# {'Date': '2017-07-05', 'Firecount': 1}
# {'Date': '2017-07-06', 'Firecount': 3}
# {'Date': '2017-07-14', 'Firecount': 2}
# {'Date': '2017-07-29', 'Firecount': 2}
# {'Date': '2017-07-31', 'Firecount': 2}
# {'Date': '2017-08-01', 'Firecount': 2}
# {'Date': '2017-08-02', 'Firecount': 2}
# {'Date': '2017-08-05', 'Firecount': 1}
# {'Date': '2017-08-10', 'Firecount': 1}
# {'Date': '2017-08-13', 'Firecount': 9}
# {'Date': '2017-08-14', 'Firecount': 5}
# {'Date': '2017-09-10', 'Firecount': 4}
# {'Date': '2017-09-20', 'Firecount': 5}
# {'Date': '2017-09-21', 'Firecount': 2}
# {'Date': '2017-09-22', 'Firecount': 1}
# {'Date': '2017-09-23', 'Firecount': 23}
# {'Date': '2017-09-24', 'Firecount': 28}
# {'Date': '2017-09-26', 'Firecount': 1}
# {'Date': '2017-09-27', 'Firecount': 7}
# {'Date': '2017-09-29', 'Firecount': 2}
# {'Date': '2017-10-01', 'Firecount': 8}
# {'Date': '2017-10-02', 'Firecount': 7}
# {'Date': '2017-10-03', 'Firecount': 18}
# {'Date': '2017-10-04', 'Firecount': 5}
# {'Date': '2017-10-06', 'Firecount': 2}
# {'Date': '2017-10-07', 'Firecount': 1}
# {'Date': '2017-10-08', 'Firecount': 1}
# {'Date': '2017-10-09', 'Firecount': 1}
# {'Date': '2017-10-10', 'Firecount': 3}
# {'Date': '2017-10-15', 'Firecount': 3}
# {'Date': '2017-10-16', 'Firecount': 1}
# {'Date': '2017-10-17', 'Firecount': 5}
# {'Date': '2017-10-18', 'Firecount': 6}
# {'Date': '2017-10-20', 'Firecount': 3}
# {'Date': '2017-10-21', 'Firecount': 4}
# {'Date': '2017-10-23', 'Firecount': 1}
# {'Date': '2017-10-26', 'Firecount': 5}
# {'Date': '2017-10-27', 'Firecount': 5}
# {'Date': '2017-10-28', 'Firecount': 1}
# {'Date': '2017-11-05', 'Firecount': 4}
# {'Date': '2017-11-08', 'Firecount': 2}
# {'Date': '2017-11-09', 'Firecount': 10}
# {'Date': '2017-11-11', 'Firecount': 4}
# {'Date': '2017-11-12', 'Firecount': 5}
# {'Date': '2017-11-13', 'Firecount': 5}
# {'Date': '2017-11-14', 'Firecount': 3}
# {'Date': '2017-11-21', 'Firecount': 1}
# {'Date': '2017-11-22', 'Firecount': 2}
# {'Date': '2017-11-23', 'Firecount': 5}
# {'Date': '2017-11-28', 'Firecount': 1}
# {'Date': '2017-11-29', 'Firecount': 8}
# {'Date': '2017-11-30', 'Firecount': 31}
# {'Date': '2017-12-08', 'Firecount': 5}
# {'Date': '2017-12-09', 'Firecount': 4}
# {'Date': '2017-12-10', 'Firecount': 2}
# {'Date': '2017-12-12', 'Firecount': 1}
# {'Date': '2017-12-13', 'Firecount': 1}
# {'Date': '2017-12-14', 'Firecount': 1}
# {'Date': '2017-12-15', 'Firecount': 4}
# {'Date': '2017-12-16', 'Firecount': 15}
# {'Date': '2017-12-21', 'Firecount': 1}
# {'Date': '2017-12-24', 'Firecount': 1}
# {'Date': '2017-12-25', 'Firecount': 1}
# {'Date': '2017-12-27', 'Firecount': 4}

# %% [markdown]
# A8. Find the average surface temperature (°C) for each day. You are required to only display
# average surface temperature (°C) and the date in the output.

# %%
# db.fire.aggregate(
# [
#     {
#         $group : 
#         {
#             _id : "$Date",
#             "Avg temperature" : {$avg : "$Surface Temperature (Celcius)"}
#         }
#     },
#     {
#         $sort :
#         {
#             '_id': 1
#         }
#     },
#     { 
#         $project: 
#         {  
#             _id: 0,
#             "Date" : "$_id",
#             "Avg temperature" : 1
#         }
#     }
# ])

# %%
#Unwind fire to ensure retrieve fire data as stand-alone record
#Count only date has fire
#group by date and caculate Average
#sort by date
#Project specified field
A8 = db.Combine.aggregate([{"$unwind": "$fire"},\
                            {"$match": {"fire" : {"$ne": []}}},\
                            {"$group":{'_id':'$Date','Avg Temperature':{'$avg':"$fire.Surface Temperature (Celcius)"}}},\
                            {"$sort":{'_id':1}},\
                            {"$project":{'_id':0,"Date":'$_id','Avg Temperature':1}}])

# %%
for document in A8: 
    pprint(document)
# Out:
# {'Avg Temperature': 60.5, 'Date': '2017-03-06'}
# {'Avg Temperature': 64.0, 'Date': '2017-03-07'}
# {'Avg Temperature': 51.5, 'Date': '2017-03-08'}
# {'Avg Temperature': 46.666666666666664, 'Date': '2017-03-09'}
# {'Avg Temperature': 69.375, 'Date': '2017-03-10'}
# {'Avg Temperature': 88.2, 'Date': '2017-03-12'}
# {'Avg Temperature': 38.5, 'Date': '2017-03-13'}
# {'Avg Temperature': 65.6, 'Date': '2017-03-14'}
# {'Avg Temperature': 46.0, 'Date': '2017-03-15'}
# {'Avg Temperature': 59.5, 'Date': '2017-03-17'}
# {'Avg Temperature': 79.33333333333333, 'Date': '2017-03-18'}
# {'Avg Temperature': 65.57142857142857, 'Date': '2017-03-19'}
# {'Avg Temperature': 49.0, 'Date': '2017-03-24'}
# {'Avg Temperature': 66.0, 'Date': '2017-03-25'}
# {'Avg Temperature': 56.88235294117647, 'Date': '2017-03-26'}
# {'Avg Temperature': 60.925925925925924, 'Date': '2017-03-28'}
# {'Avg Temperature': 51.0, 'Date': '2017-03-29'}
# {'Avg Temperature': 48.72727272727273, 'Date': '2017-03-31'}
# {'Avg Temperature': 46.714285714285715, 'Date': '2017-04-01'}
# {'Avg Temperature': 45.2, 'Date': '2017-04-02'}
# {'Avg Temperature': 58.44444444444444, 'Date': '2017-04-03'}
# {'Avg Temperature': 62.57303370786517, 'Date': '2017-04-04'}
# {'Avg Temperature': 53.142857142857146, 'Date': '2017-04-05'}
# {'Avg Temperature': 61.71186440677966, 'Date': '2017-04-06'}
# {'Avg Temperature': 50.69230769230769, 'Date': '2017-04-07'}
# {'Avg Temperature': 60.75, 'Date': '2017-04-08'}
# {'Avg Temperature': 46.291666666666664, 'Date': '2017-04-11'}
# {'Avg Temperature': 52.69565217391305, 'Date': '2017-04-12'}
# {'Avg Temperature': 58.57983193277311, 'Date': '2017-04-13'}
# {'Avg Temperature': 61.94444444444444, 'Date': '2017-04-14'}
# {'Avg Temperature': 59.57971014492754, 'Date': '2017-04-15'}
# {'Avg Temperature': 48.72222222222222, 'Date': '2017-04-16'}
# {'Avg Temperature': 50.921052631578945, 'Date': '2017-04-17'}
# {'Avg Temperature': 53.36615384615384, 'Date': '2017-04-18'}
# {'Avg Temperature': 54.16, 'Date': '2017-04-19'}
# {'Avg Temperature': 56.58064516129032, 'Date': '2017-04-20'}
# {'Avg Temperature': 54.5, 'Date': '2017-04-22'}
# {'Avg Temperature': 53.89473684210526, 'Date': '2017-04-23'}
# {'Avg Temperature': 59.375, 'Date': '2017-04-24'}
# {'Avg Temperature': 48.666666666666664, 'Date': '2017-04-25'}
# {'Avg Temperature': 34.0, 'Date': '2017-04-26'}
# {'Avg Temperature': 63.0, 'Date': '2017-04-29'}
# {'Avg Temperature': 68.4, 'Date': '2017-05-01'}
# {'Avg Temperature': 55.6, 'Date': '2017-05-02'}
# {'Avg Temperature': 56.796875, 'Date': '2017-05-03'}
# {'Avg Temperature': 56.80740740740741, 'Date': '2017-05-04'}
# {'Avg Temperature': 51.70967741935484, 'Date': '2017-05-05'}
# {'Avg Temperature': 57.529411764705884, 'Date': '2017-05-06'}
# {'Avg Temperature': 50.333333333333336, 'Date': '2017-05-07'}
# {'Avg Temperature': 56.291666666666664, 'Date': '2017-05-08'}
# {'Avg Temperature': 42.46153846153846, 'Date': '2017-05-09'}
# {'Avg Temperature': 52.86842105263158, 'Date': '2017-05-10'}
# {'Avg Temperature': 59.36842105263158, 'Date': '2017-05-11'}
# {'Avg Temperature': 51.5, 'Date': '2017-05-12'}
# {'Avg Temperature': 58.611111111111114, 'Date': '2017-05-13'}
# {'Avg Temperature': 49.0, 'Date': '2017-05-14'}
# {'Avg Temperature': 53.950980392156865, 'Date': '2017-05-15'}
# {'Avg Temperature': 39.666666666666664, 'Date': '2017-05-16'}
# {'Avg Temperature': 52.0, 'Date': '2017-05-17'}
# {'Avg Temperature': 44.142857142857146, 'Date': '2017-05-18'}
# {'Avg Temperature': 54.484848484848484, 'Date': '2017-05-22'}
# {'Avg Temperature': 51.2, 'Date': '2017-05-23'}
# {'Avg Temperature': 40.333333333333336, 'Date': '2017-05-24'}
# {'Avg Temperature': 49.5, 'Date': '2017-05-26'}
# {'Avg Temperature': 54.0, 'Date': '2017-06-01'}
# {'Avg Temperature': 47.72727272727273, 'Date': '2017-06-02'}
# {'Avg Temperature': 47.0, 'Date': '2017-06-03'}
# {'Avg Temperature': 52.22222222222222, 'Date': '2017-06-04'}
# {'Avg Temperature': 51.857142857142854, 'Date': '2017-06-07'}
# {'Avg Temperature': 49.0, 'Date': '2017-06-09'}
# {'Avg Temperature': 41.5, 'Date': '2017-06-11'}
# {'Avg Temperature': 41.0, 'Date': '2017-06-13'}
# {'Avg Temperature': 53.25, 'Date': '2017-06-14'}
# {'Avg Temperature': 42.5, 'Date': '2017-06-16'}
# {'Avg Temperature': 42.0, 'Date': '2017-06-18'}
# {'Avg Temperature': 71.16666666666667, 'Date': '2017-06-20'}
# {'Avg Temperature': 46.0, 'Date': '2017-06-22'}
# {'Avg Temperature': 44.333333333333336, 'Date': '2017-06-30'}
# {'Avg Temperature': 30.5, 'Date': '2017-07-01'}
# {'Avg Temperature': 43.5, 'Date': '2017-07-02'}
# {'Avg Temperature': 40.0, 'Date': '2017-07-04'}
# {'Avg Temperature': 45.0, 'Date': '2017-07-05'}
# {'Avg Temperature': 56.0, 'Date': '2017-07-06'}
# {'Avg Temperature': 41.5, 'Date': '2017-07-14'}
# {'Avg Temperature': 48.0, 'Date': '2017-07-29'}
# {'Avg Temperature': 47.0, 'Date': '2017-07-31'}
# {'Avg Temperature': 58.0, 'Date': '2017-08-01'}
# {'Avg Temperature': 63.5, 'Date': '2017-08-02'}
# {'Avg Temperature': 40.0, 'Date': '2017-08-05'}
# {'Avg Temperature': 63.0, 'Date': '2017-08-10'}
# {'Avg Temperature': 49.0, 'Date': '2017-08-13'}
# {'Avg Temperature': 40.8, 'Date': '2017-08-14'}
# {'Avg Temperature': 56.5, 'Date': '2017-09-10'}
# {'Avg Temperature': 63.6, 'Date': '2017-09-20'}
# {'Avg Temperature': 40.5, 'Date': '2017-09-21'}
# {'Avg Temperature': 45.0, 'Date': '2017-09-22'}
# {'Avg Temperature': 52.73913043478261, 'Date': '2017-09-23'}
# {'Avg Temperature': 53.57142857142857, 'Date': '2017-09-24'}
# {'Avg Temperature': 33.0, 'Date': '2017-09-26'}
# {'Avg Temperature': 49.714285714285715, 'Date': '2017-09-27'}
# {'Avg Temperature': 43.0, 'Date': '2017-09-29'}
# {'Avg Temperature': 48.25, 'Date': '2017-10-01'}
# {'Avg Temperature': 43.57142857142857, 'Date': '2017-10-02'}
# {'Avg Temperature': 50.0, 'Date': '2017-10-03'}
# {'Avg Temperature': 49.0, 'Date': '2017-10-04'}
# {'Avg Temperature': 44.0, 'Date': '2017-10-06'}
# {'Avg Temperature': 42.0, 'Date': '2017-10-07'}
# {'Avg Temperature': 41.0, 'Date': '2017-10-08'}
# {'Avg Temperature': 44.0, 'Date': '2017-10-09'}
# {'Avg Temperature': 53.333333333333336, 'Date': '2017-10-10'}
# {'Avg Temperature': 72.66666666666667, 'Date': '2017-10-15'}
# {'Avg Temperature': 36.0, 'Date': '2017-10-16'}
# {'Avg Temperature': 51.6, 'Date': '2017-10-17'}
# {'Avg Temperature': 52.166666666666664, 'Date': '2017-10-18'}
# {'Avg Temperature': 50.0, 'Date': '2017-10-20'}
# {'Avg Temperature': 51.25, 'Date': '2017-10-21'}
# {'Avg Temperature': 38.0, 'Date': '2017-10-23'}
# {'Avg Temperature': 44.6, 'Date': '2017-10-26'}
# {'Avg Temperature': 50.4, 'Date': '2017-10-27'}
# {'Avg Temperature': 56.0, 'Date': '2017-10-28'}
# {'Avg Temperature': 58.5, 'Date': '2017-11-05'}
# {'Avg Temperature': 45.5, 'Date': '2017-11-08'}
# {'Avg Temperature': 61.3, 'Date': '2017-11-09'}
# {'Avg Temperature': 46.25, 'Date': '2017-11-11'}
# {'Avg Temperature': 53.0, 'Date': '2017-11-12'}
# {'Avg Temperature': 47.0, 'Date': '2017-11-13'}
# {'Avg Temperature': 52.0, 'Date': '2017-11-14'}
# {'Avg Temperature': 59.0, 'Date': '2017-11-21'}
# {'Avg Temperature': 61.5, 'Date': '2017-11-22'}
# {'Avg Temperature': 58.8, 'Date': '2017-11-23'}
# {'Avg Temperature': 42.0, 'Date': '2017-11-28'}
# {'Avg Temperature': 60.625, 'Date': '2017-11-29'}
# {'Avg Temperature': 52.41935483870968, 'Date': '2017-11-30'}
# {'Avg Temperature': 50.6, 'Date': '2017-12-08'}
# {'Avg Temperature': 58.25, 'Date': '2017-12-09'}
# {'Avg Temperature': 46.0, 'Date': '2017-12-10'}
# {'Avg Temperature': 44.0, 'Date': '2017-12-12'}
# {'Avg Temperature': 60.0, 'Date': '2017-12-13'}
# {'Avg Temperature': 70.0, 'Date': '2017-12-14'}
# {'Avg Temperature': 39.0, 'Date': '2017-12-15'}
# {'Avg Temperature': 57.8, 'Date': '2017-12-16'}
# {'Avg Temperature': 46.0, 'Date': '2017-12-21'}
# {'Avg Temperature': 32.0, 'Date': '2017-12-24'}
# {'Avg Temperature': 54.0, 'Date': '2017-12-25'}
# {'Avg Temperature': 62.75, 'Date': '2017-12-27'}

# %% [markdown]
# **Please choose ONE of the Task A2-A8 and implement it in parallel.
# A7. Find the number of fire in each day. You are required to only display total number of fire and the date in the output.**

# %%
#convert entire 'Combine' database to list
result = list(db.Combine.find())

# %%
result[90:100]
# Out:
# [{'_id': ObjectId('5b019c55b3dbfe3de262dcbf'),
#   'Station': 948701,
#   'Date': '2017-04-01',
#   'AirTemperature(Celcius)': 14,
#   'RelativeHumidity': 45.7,
#   'WindSpeed(knots)': 9.2,
#   'MaxWindSpeed': 15.9,
#   'MAX': '63.9*',
#   'MIN': '50.4',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.1948,
#     'Longitude': 145.7688,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-01T04:11:30',
#     'Power': 18.7,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.2721,
#     'Longitude': 146.847,
#     'Surface Temperature (kelvin)': 318.9,
#     'Datetime': '2017-04-01T04:09:20',
#     'Power': 20.2,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -36.1017,
#     'Longitude': 147.6381,
#     'Surface Temperature (kelvin)': 319.2,
#     'Datetime': '2017-04-01T04:04:50',
#     'Power': 21.6,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.1256,
#     'Longitude': 145.2444,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-01T04:02:50',
#     'Power': 24.0,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.2044,
#     'Longitude': 145.7706,
#     'Surface Temperature (kelvin)': 324.7,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 19.1,
#     'Confidence': 58,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.5245,
#     'Longitude': 143.1556,
#     'Surface Temperature (kelvin)': 316.5,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 12.3,
#     'Confidence': 57,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.1002,
#     'Longitude': 147.6494,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-01T04:02:40',
#     'Power': 14.8,
#     'Confidence': 50,
#     'Surface Temperature (Celcius)': 39}]},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc0'),
#   'Station': 948701,
#   'Date': '2017-04-02',
#   'AirTemperature(Celcius)': 12,
#   'RelativeHumidity': 43.4,
#   'WindSpeed(knots)': 9.3,
#   'MaxWindSpeed': 15.0,
#   'MAX': '63.3*',
#   'MIN': '45.0*',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.3872,
#     'Longitude': 145.3858,
#     'Surface Temperature (kelvin)': 314.1,
#     'Datetime': '2017-04-02T04:53:30',
#     'Power': 11.1,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.6664,
#     'Longitude': 145.2554,
#     'Surface Temperature (kelvin)': 325.7,
#     'Datetime': '2017-04-02T04:51:40',
#     'Power': 24.4,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.6688,
#     'Longitude': 145.2635,
#     'Surface Temperature (kelvin)': 321.0,
#     'Datetime': '2017-04-02T04:45:10',
#     'Power': 17.7,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.494,
#     'Longitude': 145.4522,
#     'Surface Temperature (kelvin)': 315.0,
#     'Datetime': '2017-04-02T04:45:10',
#     'Power': 11.3,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.324,
#     'Longitude': 146.1647,
#     'Surface Temperature (kelvin)': 319.6,
#     'Datetime': '2017-04-02T00:24:50',
#     'Power': 23.2,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 46}]},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc1'),
#   'Station': 948701,
#   'Date': '2017-04-03',
#   'AirTemperature(Celcius)': 15,
#   'RelativeHumidity': 47.7,
#   'WindSpeed(knots)': 5.9,
#   'MaxWindSpeed': 13.0,
#   'MAX': '71.1*',
#   'MIN': '43',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.1141,
#     'Longitude': 141.6787,
#     'Surface Temperature (kelvin)': 310.8,
#     'Datetime': '2017-04-03T13:20:00',
#     'Power': 20.5,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 37},
#    {'Latitude': -37.8046,
#     'Longitude': 146.0304,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-03T13:17:00',
#     'Power': 26.2,
#     'Confidence': 91,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.9068,
#     'Longitude': 145.9047,
#     'Surface Temperature (kelvin)': 313.8,
#     'Datetime': '2017-04-03T13:15:30',
#     'Power': 23.7,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1156,
#     'Longitude': 141.6664,
#     'Surface Temperature (kelvin)': 335.7,
#     'Datetime': '2017-04-03T13:15:10',
#     'Power': 52.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.8064,
#     'Longitude': 146.0189,
#     'Surface Temperature (kelvin)': 318.5,
#     'Datetime': '2017-04-03T13:15:10',
#     'Power': 28.3,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.0221,
#     'Longitude': 141.5517,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-03T04:00:00',
#     'Power': 20.1,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3735,
#     'Longitude': 145.886,
#     'Surface Temperature (kelvin)': 369.2,
#     'Datetime': '2017-04-03T03:59:10',
#     'Power': 124.4,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 96},
#    {'Latitude': -37.5422,
#     'Longitude': 143.2276,
#     'Surface Temperature (kelvin)': 322.3,
#     'Datetime': '2017-04-03T03:58:20',
#     'Power': 17.4,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.7465,
#     'Longitude': 143.3806,
#     'Surface Temperature (kelvin)': 345.7,
#     'Datetime': '2017-04-03T03:57:50',
#     'Power': 55.0,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -37.3094,
#     'Longitude': 146.1945,
#     'Surface Temperature (kelvin)': 333.6,
#     'Datetime': '2017-04-03T03:56:40',
#     'Power': 39.8,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 60},
#    {'Latitude': -36.7199,
#     'Longitude': 141.3946,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-03T03:56:20',
#     'Power': 26.7,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7638,
#     'Longitude': 142.1215,
#     'Surface Temperature (kelvin)': 326.0,
#     'Datetime': '2017-04-03T03:56:20',
#     'Power': 18.1,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.1534,
#     'Longitude': 141.5948,
#     'Surface Temperature (kelvin)': 337.3,
#     'Datetime': '2017-04-03T03:55:10',
#     'Power': 38.1,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.8072,
#     'Longitude': 145.9738,
#     'Surface Temperature (kelvin)': 350.8,
#     'Datetime': '2017-04-03T03:55:10',
#     'Power': 75.9,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 77},
#    {'Latitude': -37.3704,
#     'Longitude': 145.8942,
#     'Surface Temperature (kelvin)': 351.6,
#     'Datetime': '2017-04-03T03:54:00',
#     'Power': 76.4,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -37.297,
#     'Longitude': 143.5753,
#     'Surface Temperature (kelvin)': 367.0,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 108.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 93},
#    {'Latitude': -36.9172,
#     'Longitude': 142.0472,
#     'Surface Temperature (kelvin)': 319.1,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 11.3,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.8668,
#     'Longitude': 143.0472,
#     'Surface Temperature (kelvin)': 318.0,
#     'Datetime': '2017-04-03T03:53:50',
#     'Power': 14.4,
#     'Confidence': 69,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7602,
#     'Longitude': 143.382,
#     'Surface Temperature (kelvin)': 317.5,
#     'Datetime': '2017-04-03T03:53:40',
#     'Power': 12.7,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7529,
#     'Longitude': 143.3745,
#     'Surface Temperature (kelvin)': 332.5,
#     'Datetime': '2017-04-03T03:53:30',
#     'Power': 32.5,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -37.7885,
#     'Longitude': 142.9509,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-03T03:53:30',
#     'Power': 12.4,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -34.2714,
#     'Longitude': 141.6197,
#     'Surface Temperature (kelvin)': 321.7,
#     'Datetime': '2017-04-03T03:53:00',
#     'Power': 12.2,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.1698,
#     'Longitude': 142.0536,
#     'Surface Temperature (kelvin)': 331.2,
#     'Datetime': '2017-04-03T03:52:30',
#     'Power': 26.5,
#     'Confidence': 84,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.2988,
#     'Longitude': 143.5487,
#     'Surface Temperature (kelvin)': 363.3,
#     'Datetime': '2017-04-03T03:52:30',
#     'Power': 98.0,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 90},
#    {'Latitude': -37.3716,
#     'Longitude': 145.9065,
#     'Surface Temperature (kelvin)': 389.0,
#     'Datetime': '2017-04-03T03:52:20',
#     'Power': 203.8,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 115},
#    {'Latitude': -37.8662,
#     'Longitude': 143.251,
#     'Surface Temperature (kelvin)': 319.3,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 16.0,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.4291,
#     'Longitude': 141.2426,
#     'Surface Temperature (kelvin)': 334.6,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 33.3,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.2891,
#     'Longitude': 143.5697,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 18.7,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3025,
#     'Longitude': 143.5714,
#     'Surface Temperature (kelvin)': 372.0,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 124.9,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 98},
#    {'Latitude': -37.383,
#     'Longitude': 145.9089,
#     'Surface Temperature (kelvin)': 362.4,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 104.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -37.7216,
#     'Longitude': 143.4272,
#     'Surface Temperature (kelvin)': 332.8,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 33.0,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -37.8717,
#     'Longitude': 143.3652,
#     'Surface Temperature (kelvin)': 322.5,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 19.2,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.8717,
#     'Longitude': 143.2566,
#     'Surface Temperature (kelvin)': 316.5,
#     'Datetime': '2017-04-03T03:52:10',
#     'Power': 13.0,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3851,
#     'Longitude': 145.8878,
#     'Surface Temperature (kelvin)': 336.5,
#     'Datetime': '2017-04-03T03:51:30',
#     'Power': 46.2,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.7446,
#     'Longitude': 143.4085,
#     'Surface Temperature (kelvin)': 339.4,
#     'Datetime': '2017-04-03T03:51:30',
#     'Power': 42.8,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.7159,
#     'Longitude': 141.3991,
#     'Surface Temperature (kelvin)': 322.5,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 17.7,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -35.7626,
#     'Longitude': 142.1167,
#     'Surface Temperature (kelvin)': 336.0,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 33.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.8011,
#     'Longitude': 144.7343,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-03T03:51:10',
#     'Power': 12.4,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.8777,
#     'Longitude': 143.371,
#     'Surface Temperature (kelvin)': 327.5,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 26.6,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.7509,
#     'Longitude': 143.4023,
#     'Surface Temperature (kelvin)': 355.9,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 79.3,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 82},
#    {'Latitude': -36.6085,
#     'Longitude': 142.4451,
#     'Surface Temperature (kelvin)': 326.7,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 20.9,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.3802,
#     'Longitude': 145.9147,
#     'Surface Temperature (kelvin)': 376.3,
#     'Datetime': '2017-04-03T03:51:00',
#     'Power': 149.0,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 103},
#    {'Latitude': -37.7974,
#     'Longitude': 145.9535,
#     'Surface Temperature (kelvin)': 370.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 131.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 97},
#    {'Latitude': -37.0241,
#     'Longitude': 141.5163,
#     'Surface Temperature (kelvin)': 316.9,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 13.4,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.2912,
#     'Longitude': 143.543,
#     'Surface Temperature (kelvin)': 316.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 11.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.313,
#     'Longitude': 146.1561,
#     'Surface Temperature (kelvin)': 319.9,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 21.6,
#     'Confidence': 52,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -38.0226,
#     'Longitude': 143.6739,
#     'Surface Temperature (kelvin)': 312.8,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 10.1,
#     'Confidence': 56,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -35.7657,
#     'Longitude': 142.0906,
#     'Surface Temperature (kelvin)': 340.1,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 40.5,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -37.9029,
#     'Longitude': 143.5946,
#     'Surface Temperature (kelvin)': 320.6,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 16.8,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.9151,
#     'Longitude': 142.0798,
#     'Surface Temperature (kelvin)': 323.7,
#     'Datetime': '2017-04-03T03:50:50',
#     'Power': 16.6,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.9112,
#     'Longitude': 143.6025,
#     'Surface Temperature (kelvin)': 334.2,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 34.9,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.8089,
#     'Longitude': 145.9555,
#     'Surface Temperature (kelvin)': 314.8,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 18.9,
#     'Confidence': 56,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.9009,
#     'Longitude': 143.6217,
#     'Surface Temperature (kelvin)': 318.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 14.3,
#     'Confidence': 62,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.7583,
#     'Longitude': 143.41,
#     'Surface Temperature (kelvin)': 318.6,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.8,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.7836,
#     'Longitude': 142.9437,
#     'Surface Temperature (kelvin)': 318.0,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 14.5,
#     'Confidence': 69,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7236,
#     'Longitude': 143.3995,
#     'Surface Temperature (kelvin)': 359.3,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 88.0,
#     'Confidence': 99,
#     'Surface Temperature (Celcius)': 86},
#    {'Latitude': -37.5402,
#     'Longitude': 143.2559,
#     'Surface Temperature (kelvin)': 323.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 18.6,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3046,
#     'Longitude': 143.5448,
#     'Surface Temperature (kelvin)': 345.3,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 53.9,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -37.0484,
#     'Longitude': 141.6245,
#     'Surface Temperature (kelvin)': 315.8,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 10.5,
#     'Confidence': 52,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -36.911,
#     'Longitude': 142.1445,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.3,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.4312,
#     'Longitude': 141.2064,
#     'Surface Temperature (kelvin)': 349.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 61.7,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -36.1702,
#     'Longitude': 142.0586,
#     'Surface Temperature (kelvin)': 333.6,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 30.8,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 60},
#    {'Latitude': -36.1722,
#     'Longitude': 142.0266,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 13.3,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.1556,
#     'Longitude': 141.5904,
#     'Surface Temperature (kelvin)': 338.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 40.5,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -35.7598,
#     'Longitude': 143.851,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 12.0,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -35.7609,
#     'Longitude': 143.8442,
#     'Surface Temperature (kelvin)': 328.7,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 23.0,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7647,
#     'Longitude': 142.0858,
#     'Surface Temperature (kelvin)': 338.5,
#     'Datetime': '2017-04-03T03:50:40',
#     'Power': 37.5,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -34.2536,
#     'Longitude': 141.6199,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-03T01:11:00',
#     'Power': 13.8,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2674,
#     'Longitude': 141.6183,
#     'Surface Temperature (kelvin)': 324.2,
#     'Datetime': '2017-04-03T01:10:50',
#     'Power': 19.5,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.7885,
#     'Longitude': 142.1258,
#     'Surface Temperature (kelvin)': 319.5,
#     'Datetime': '2017-04-03T01:07:30',
#     'Power': 16.4,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2594,
#     'Longitude': 141.6139,
#     'Surface Temperature (kelvin)': 327.7,
#     'Datetime': '2017-04-03T01:07:20',
#     'Power': 24.6,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -34.2614,
#     'Longitude': 141.6412,
#     'Surface Temperature (kelvin)': 317.0,
#     'Datetime': '2017-04-03T01:07:00',
#     'Power': 11.0,
#     'Confidence': 57,
#     'Surface Temperature (Celcius)': 43}]},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc2'),
#   'Station': 948701,
#   'Date': '2017-04-04',
#   'AirTemperature(Celcius)': 16,
#   'RelativeHumidity': 47.5,
#   'WindSpeed(knots)': 5.4,
#   'MaxWindSpeed': 12.0,
#   'MAX': '73.4*',
#   'MIN': '46.8',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -37.2162,
#     'Longitude': 146.2408,
#     'Surface Temperature (kelvin)': 311.8,
#     'Datetime': '2017-04-04T15:33:40',
#     'Power': 20.0,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.086999999999996,
#     'Longitude': 141.7227,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-04T15:31:00',
#     'Power': 27.5,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -36.0933,
#     'Longitude': 141.7154,
#     'Surface Temperature (kelvin)': 308.8,
#     'Datetime': '2017-04-04T15:30:40',
#     'Power': 19.7,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -36.0852,
#     'Longitude': 141.7112,
#     'Surface Temperature (kelvin)': 337.2,
#     'Datetime': '2017-04-04T15:30:40',
#     'Power': 55.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -36.3194,
#     'Longitude': 141.7531,
#     'Surface Temperature (kelvin)': 337.1,
#     'Datetime': '2017-04-04T04:41:50',
#     'Power': 34.5,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.3601,
#     'Longitude': 145.8519,
#     'Surface Temperature (kelvin)': 335.3,
#     'Datetime': '2017-04-04T04:41:10',
#     'Power': 44.8,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.1598,
#     'Longitude': 141.8841,
#     'Surface Temperature (kelvin)': 337.7,
#     'Datetime': '2017-04-04T04:41:00',
#     'Power': 35.0,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -36.6936,
#     'Longitude': 145.2788,
#     'Surface Temperature (kelvin)': 334.4,
#     'Datetime': '2017-04-04T04:41:00',
#     'Power': 35.9,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.1057,
#     'Longitude': 141.7608,
#     'Surface Temperature (kelvin)': 393.8,
#     'Datetime': '2017-04-04T04:40:00',
#     'Power': 212.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 120},
#    {'Latitude': -35.4033,
#     'Longitude': 143.267,
#     'Surface Temperature (kelvin)': 340.4,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 40.3,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 67},
#    {'Latitude': -36.6281,
#     'Longitude': 142.4349,
#     'Surface Temperature (kelvin)': 341.6,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 51.0,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 68},
#    {'Latitude': -36.111,
#     'Longitude': 145.124,
#     'Surface Temperature (kelvin)': 340.0,
#     'Datetime': '2017-04-04T04:39:50',
#     'Power': 46.0,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.1615,
#     'Longitude': 141.8728,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 37.9,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -37.3074,
#     'Longitude': 142.9925,
#     'Surface Temperature (kelvin)': 328.1,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 31.4,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.937,
#     'Longitude': 142.1176,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-04T04:39:40',
#     'Power': 22.9,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -38.1868,
#     'Longitude': 143.0938,
#     'Surface Temperature (kelvin)': 318.9,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 22.6,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -35.2601,
#     'Longitude': 143.1931,
#     'Surface Temperature (kelvin)': 324.1,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 15.2,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.1849,
#     'Longitude': 145.9109,
#     'Surface Temperature (kelvin)': 381.0,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 155.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 107},
#    {'Latitude': -37.2109,
#     'Longitude': 142.7966,
#     'Surface Temperature (kelvin)': 325.5,
#     'Datetime': '2017-04-04T04:39:20',
#     'Power': 27.6,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.6951,
#     'Longitude': 145.424,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-04T04:38:10',
#     'Power': 12.2,
#     'Confidence': 50,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.1376,
#     'Longitude': 145.84,
#     'Surface Temperature (kelvin)': 329.0,
#     'Datetime': '2017-04-04T04:37:30',
#     'Power': 27.2,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.6965,
#     'Longitude': 142.7116,
#     'Surface Temperature (kelvin)': 337.9,
#     'Datetime': '2017-04-04T04:37:10',
#     'Power': 40.1,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.0753,
#     'Longitude': 141.0532,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-04T04:36:40',
#     'Power': 22.1,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -37.6714,
#     'Longitude': 144.2154,
#     'Surface Temperature (kelvin)': 319.6,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 20.6,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.4465,
#     'Longitude': 143.5163,
#     'Surface Temperature (kelvin)': 324.1,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 27.7,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -38.0494,
#     'Longitude': 143.9141,
#     'Surface Temperature (kelvin)': 331.5,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 38.7,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -38.1356,
#     'Longitude': 143.7098,
#     'Surface Temperature (kelvin)': 323.6,
#     'Datetime': '2017-04-04T04:36:30',
#     'Power': 28.0,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.3632,
#     'Longitude': 145.8356,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 32.9,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.6078,
#     'Longitude': 141.9742,
#     'Surface Temperature (kelvin)': 336.7,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 36.9,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 63},
#    {'Latitude': -37.3765,
#     'Longitude': 145.8221,
#     'Surface Temperature (kelvin)': 335.4,
#     'Datetime': '2017-04-04T04:36:10',
#     'Power': 47.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.0694,
#     'Longitude': 141.5717,
#     'Surface Temperature (kelvin)': 327.3,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 19.4,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.1122,
#     'Longitude': 142.1491,
#     'Surface Temperature (kelvin)': 349.4,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 61.2,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -36.400999999999996,
#     'Longitude': 145.5113,
#     'Surface Temperature (kelvin)': 328.5,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 26.7,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -37.9048,
#     'Longitude': 145.7738,
#     'Surface Temperature (kelvin)': 322.8,
#     'Datetime': '2017-04-04T04:36:00',
#     'Power': 29.8,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -37.3735,
#     'Longitude': 145.8384,
#     'Surface Temperature (kelvin)': 368.4,
#     'Datetime': '2017-04-04T04:35:00',
#     'Power': 125.0,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 95},
#    {'Latitude': -35.4128,
#     'Longitude': 143.2693,
#     'Surface Temperature (kelvin)': 330.8,
#     'Datetime': '2017-04-04T04:34:50',
#     'Power': 24.1,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.8848,
#     'Longitude': 142.1523,
#     'Surface Temperature (kelvin)': 324.4,
#     'Datetime': '2017-04-04T04:34:30',
#     'Power': 19.9,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -35.4255,
#     'Longitude': 143.6306,
#     'Surface Temperature (kelvin)': 338.8,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 42.8,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -36.1198,
#     'Longitude': 145.6369,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 20.6,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -38.4879,
#     'Longitude': 143.9971,
#     'Surface Temperature (kelvin)': 313.6,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 17.3,
#     'Confidence': 54,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1955,
#     'Longitude': 145.914,
#     'Surface Temperature (kelvin)': 351.3,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 63.0,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -35.4533,
#     'Longitude': 143.2029,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-04T04:34:20',
#     'Power': 40.4,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -35.4993,
#     'Longitude': 143.3105,
#     'Surface Temperature (kelvin)': 331.1,
#     'Datetime': '2017-04-04T04:34:00',
#     'Power': 23.5,
#     'Confidence': 84,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.5989,
#     'Longitude': 141.9771,
#     'Surface Temperature (kelvin)': 354.4,
#     'Datetime': '2017-04-04T04:33:50',
#     'Power': 76.1,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 81},
#    {'Latitude': -37.4485,
#     'Longitude': 143.5041,
#     'Surface Temperature (kelvin)': 328.0,
#     'Datetime': '2017-04-04T04:33:40',
#     'Power': 32.9,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.1744,
#     'Longitude': 143.9256,
#     'Surface Temperature (kelvin)': 316.8,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 15.2,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.104,
#     'Longitude': 141.77200000000002,
#     'Surface Temperature (kelvin)': 386.7,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 178.1,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 113},
#    {'Latitude': -36.4918,
#     'Longitude': 142.2465,
#     'Surface Temperature (kelvin)': 328.0,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 25.9,
#     'Confidence': 69,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6663,
#     'Longitude': 143.2603,
#     'Surface Temperature (kelvin)': 332.0,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 36.4,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -36.0189,
#     'Longitude': 145.6844,
#     'Surface Temperature (kelvin)': 322.7,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 16.8,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -35.7523,
#     'Longitude': 143.8866,
#     'Surface Temperature (kelvin)': 333.1,
#     'Datetime': '2017-04-04T04:33:30',
#     'Power': 31.7,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -36.6538,
#     'Longitude': 142.7552,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-04T04:33:20',
#     'Power': 24.5,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.6299,
#     'Longitude': 142.4234,
#     'Surface Temperature (kelvin)': 345.0,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 56.3,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 71},
#    {'Latitude': -36.0994,
#     'Longitude': 143.4156,
#     'Surface Temperature (kelvin)': 335.4,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 38.8,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.8395,
#     'Longitude': 142.2188,
#     'Surface Temperature (kelvin)': 336.1,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 36.7,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.9294,
#     'Longitude': 142.7087,
#     'Surface Temperature (kelvin)': 324.6,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 21.9,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -36.1439,
#     'Longitude': 145.832,
#     'Surface Temperature (kelvin)': 323.5,
#     'Datetime': '2017-04-04T04:33:10',
#     'Power': 19.3,
#     'Confidence': 53,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.1925,
#     'Longitude': 145.93,
#     'Surface Temperature (kelvin)': 353.0,
#     'Datetime': '2017-04-04T04:33:00',
#     'Power': 68.2,
#     'Confidence': 97,
#     'Surface Temperature (Celcius)': 79},
#    {'Latitude': -37.8351,
#     'Longitude': 145.9789,
#     'Surface Temperature (kelvin)': 334.2,
#     'Datetime': '2017-04-04T04:33:00',
#     'Power': 44.9,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.095,
#     'Longitude': 141.7699,
#     'Surface Temperature (kelvin)': 356.1,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 74.0,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 82},
#    {'Latitude': -36.7848,
#     'Longitude': 141.9044,
#     'Surface Temperature (kelvin)': 334.6,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 34.6,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -36.6962,
#     'Longitude': 145.2642,
#     'Surface Temperature (kelvin)': 331.9,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 31.7,
#     'Confidence': 84,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.1089,
#     'Longitude': 143.0783,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 29.3,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.7009,
#     'Longitude': 141.541,
#     'Surface Temperature (kelvin)': 323.0,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 18.6,
#     'Confidence': 54,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.4604,
#     'Longitude': 142.1623,
#     'Surface Temperature (kelvin)': 321.4,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 19.6,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.343,
#     'Longitude': 142.1986,
#     'Surface Temperature (kelvin)': 396.3,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 233.4,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 123},
#    {'Latitude': -36.2906,
#     'Longitude': 141.75799999999998,
#     'Surface Temperature (kelvin)': 328.8,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 23.0,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -36.114000000000004,
#     'Longitude': 142.1377,
#     'Surface Temperature (kelvin)': 391.2,
#     'Datetime': '2017-04-04T04:32:50',
#     'Power': 202.8,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 118},
#    {'Latitude': -37.5436,
#     'Longitude': 143.6122,
#     'Surface Temperature (kelvin)': 327.4,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 38.2,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6006,
#     'Longitude': 141.9657,
#     'Surface Temperature (kelvin)': 351.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 69.1,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -36.4611,
#     'Longitude': 143.14600000000002,
#     'Surface Temperature (kelvin)': 321.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 19.4,
#     'Confidence': 55,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -37.0769,
#     'Longitude': 141.042,
#     'Surface Temperature (kelvin)': 346.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 56.5,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -36.3521,
#     'Longitude': 142.2008,
#     'Surface Temperature (kelvin)': 394.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 218.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 120},
#    {'Latitude': -36.3539,
#     'Longitude': 142.1894,
#     'Surface Temperature (kelvin)': 327.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 23.5,
#     'Confidence': 53,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.883,
#     'Longitude': 142.1637,
#     'Surface Temperature (kelvin)': 341.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 45.2,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 67},
#    {'Latitude': -36.0973,
#     'Longitude': 143.4279,
#     'Surface Temperature (kelvin)': 365.8,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 108.2,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 92},
#    {'Latitude': -36.7722,
#     'Longitude': 141.5514,
#     'Surface Temperature (kelvin)': 331.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 29.5,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.0081,
#     'Longitude': 141.7654,
#     'Surface Temperature (kelvin)': 335.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 38.0,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -36.0967,
#     'Longitude': 141.7587,
#     'Surface Temperature (kelvin)': 374.3,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 129.4,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 101},
#    {'Latitude': -36.4204,
#     'Longitude': 141.3765,
#     'Surface Temperature (kelvin)': 330.7,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 27.2,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.2889,
#     'Longitude': 141.7692,
#     'Surface Temperature (kelvin)': 324.4,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.6,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 51},
#    {'Latitude': -35.4439,
#     'Longitude': 143.2005,
#     'Surface Temperature (kelvin)': 327.5,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 20.5,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.6228,
#     'Longitude': 142.428,
#     'Surface Temperature (kelvin)': 317.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.0,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.2205,
#     'Longitude': 141.7933,
#     'Surface Temperature (kelvin)': 327.6,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 18.8,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -38.1177,
#     'Longitude': 143.6409,
#     'Surface Temperature (kelvin)': 314.1,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 16.4,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.1819,
#     'Longitude': 145.9269,
#     'Surface Temperature (kelvin)': 372.0,
#     'Datetime': '2017-04-04T04:32:40',
#     'Power': 122.4,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 98},
#    {'Latitude': -35.4594,
#     'Longitude': 143.7125,
#     'Surface Temperature (kelvin)': 319.9,
#     'Datetime': '2017-04-04T00:14:30',
#     'Power': 17.1,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -34.2708,
#     'Longitude': 141.6158,
#     'Surface Temperature (kelvin)': 326.0,
#     'Datetime': '2017-04-04T00:12:50',
#     'Power': 22.4,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.4616,
#     'Longitude': 143.7251,
#     'Surface Temperature (kelvin)': 326.7,
#     'Datetime': '2017-04-04T00:12:50',
#     'Power': 26.0,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53}]},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc3'),
#   'Station': 948701,
#   'Date': '2017-04-05',
#   'AirTemperature(Celcius)': 17,
#   'RelativeHumidity': 47.2,
#   'WindSpeed(knots)': 4.9,
#   'MaxWindSpeed': 13.0,
#   'MAX': '76.8*',
#   'MIN': '47.1',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -38.3499,
#     'Longitude': 147.033,
#     'Surface Temperature (kelvin)': 308.5,
#     'Datetime': '2017-04-05T13:10:10',
#     'Power': 19.0,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -38.2003,
#     'Longitude': 146.8378,
#     'Surface Temperature (kelvin)': 331.8,
#     'Datetime': '2017-04-05T13:09:00',
#     'Power': 45.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.4583,
#     'Longitude': 148.2459,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-05T13:09:00',
#     'Power': 21.5,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.6784,
#     'Longitude': 146.1432,
#     'Surface Temperature (kelvin)': 317.3,
#     'Datetime': '2017-04-05T13:08:40',
#     'Power': 27.2,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.4492,
#     'Longitude': 148.2438,
#     'Surface Temperature (kelvin)': 320.4,
#     'Datetime': '2017-04-05T13:08:40',
#     'Power': 29.6,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -38.2153,
#     'Longitude': 146.8652,
#     'Surface Temperature (kelvin)': 313.3,
#     'Datetime': '2017-04-05T13:07:00',
#     'Power': 22.2,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.7652,
#     'Longitude': 147.1289,
#     'Surface Temperature (kelvin)': 312.4,
#     'Datetime': '2017-04-05T13:06:30',
#     'Power': 20.3,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -35.6922,
#     'Longitude': 143.1619,
#     'Surface Temperature (kelvin)': 322.2,
#     'Datetime': '2017-04-05T13:04:20',
#     'Power': 32.3,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -38.2094,
#     'Longitude': 146.8398,
#     'Surface Temperature (kelvin)': 328.2,
#     'Datetime': '2017-04-05T13:03:20',
#     'Power': 39.6,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.2464,
#     'Longitude': 141.1143,
#     'Surface Temperature (kelvin)': 319.1,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 29.1,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -38.2078,
#     'Longitude': 146.8515,
#     'Surface Temperature (kelvin)': 328.9,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 40.9,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 55},
#    {'Latitude': -35.7024,
#     'Longitude': 143.1637,
#     'Surface Temperature (kelvin)': 313.0,
#     'Datetime': '2017-04-05T13:03:00',
#     'Power': 22.0,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -38.3483,
#     'Longitude': 147.0446,
#     'Surface Temperature (kelvin)': 310.3,
#     'Datetime': '2017-04-05T13:02:50',
#     'Power': 20.4,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 37},
#    {'Latitude': -37.4015,
#     'Longitude': 145.5947,
#     'Surface Temperature (kelvin)': 315.5,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 24.2,
#     'Confidence': 88,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -38.2169,
#     'Longitude': 146.8535,
#     'Surface Temperature (kelvin)': 312.9,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 21.5,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.6435,
#     'Longitude': 146.1417,
#     'Surface Temperature (kelvin)': 309.5,
#     'Datetime': '2017-04-05T13:02:40',
#     'Power': 19.7,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 36},
#    {'Latitude': -37.6387,
#     'Longitude': 142.9032,
#     'Surface Temperature (kelvin)': 361.8,
#     'Datetime': '2017-04-05T05:16:50',
#     'Power': 99.8,
#     'Confidence': 87,
#     'Surface Temperature (Celcius)': 88},
#    {'Latitude': -38.0045,
#     'Longitude': 143.9075,
#     'Surface Temperature (kelvin)': 337.4,
#     'Datetime': '2017-04-05T05:15:50',
#     'Power': 43.5,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.7522,
#     'Longitude': 142.3183,
#     'Surface Temperature (kelvin)': 323.3,
#     'Datetime': '2017-04-05T05:15:40',
#     'Power': 22.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.9396,
#     'Longitude': 141.9303,
#     'Surface Temperature (kelvin)': 318.7,
#     'Datetime': '2017-04-05T05:15:30',
#     'Power': 16.8,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.6439,
#     'Longitude': 142.91299999999998,
#     'Surface Temperature (kelvin)': 356.7,
#     'Datetime': '2017-04-05T05:15:30',
#     'Power': 85.5,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 83},
#    {'Latitude': -37.78,
#     'Longitude': 141.8091,
#     'Surface Temperature (kelvin)': 315.9,
#     'Datetime': '2017-04-05T03:45:10',
#     'Power': 13.5,
#     'Confidence': 65,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -37.7767,
#     'Longitude': 141.8127,
#     'Surface Temperature (kelvin)': 317.8,
#     'Datetime': '2017-04-05T03:44:40',
#     'Power': 15.1,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -38.1756,
#     'Longitude': 143.9829,
#     'Surface Temperature (kelvin)': 326.2,
#     'Datetime': '2017-04-05T03:44:30',
#     'Power': 25.1,
#     'Confidence': 65,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.7795,
#     'Longitude': 148.4084,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-05T03:41:40',
#     'Power': 29.7,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.3165,
#     'Longitude': 147.4932,
#     'Surface Temperature (kelvin)': 346.0,
#     'Datetime': '2017-04-05T03:40:50',
#     'Power': 69.2,
#     'Confidence': 93,
#     'Surface Temperature (Celcius)': 72},
#    {'Latitude': -36.9373,
#     'Longitude': 142.5327,
#     'Surface Temperature (kelvin)': 319.0,
#     'Datetime': '2017-04-05T03:40:40',
#     'Power': 15.7,
#     'Confidence': 70,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -38.3553,
#     'Longitude': 147.0231,
#     'Surface Temperature (kelvin)': 311.7,
#     'Datetime': '2017-04-05T03:40:30',
#     'Power': 12.2,
#     'Confidence': 50,
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.934,
#     'Longitude': 142.5759,
#     'Surface Temperature (kelvin)': 320.5,
#     'Datetime': '2017-04-05T03:40:30',
#     'Power': 15.4,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.3158,
#     'Longitude': 147.4986,
#     'Surface Temperature (kelvin)': 349.3,
#     'Datetime': '2017-04-05T03:40:30',
#     'Power': 76.0,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -37.7916,
#     'Longitude': 148.4098,
#     'Surface Temperature (kelvin)': 327.7,
#     'Datetime': '2017-04-05T03:40:20',
#     'Power': 32.2,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.4471,
#     'Longitude': 147.6331,
#     'Surface Temperature (kelvin)': 339.0,
#     'Datetime': '2017-04-05T03:39:30',
#     'Power': 53.3,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -37.4024,
#     'Longitude': 145.5918,
#     'Surface Temperature (kelvin)': 325.9,
#     'Datetime': '2017-04-05T03:39:30',
#     'Power': 31.9,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -37.79,
#     'Longitude': 143.3801,
#     'Surface Temperature (kelvin)': 335.8,
#     'Datetime': '2017-04-05T03:39:30',
#     'Power': 39.3,
#     'Confidence': 82,
#     'Surface Temperature (Celcius)': 62},
#    {'Latitude': -37.7835,
#     'Longitude': 148.4138,
#     'Surface Temperature (kelvin)': 339.9,
#     'Datetime': '2017-04-05T03:39:20',
#     'Power': 52.2,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.5465,
#     'Longitude': 142.0912,
#     'Surface Temperature (kelvin)': 329.9,
#     'Datetime': '2017-04-05T03:39:20',
#     'Power': 27.7,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 56},
#    {'Latitude': -38.0383,
#     'Longitude': 144.4307,
#     'Surface Temperature (kelvin)': 313.8,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 11.2,
#     'Confidence': 59,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -37.4449,
#     'Longitude': 147.6594,
#     'Surface Temperature (kelvin)': 338.4,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 52.5,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 65},
#    {'Latitude': -37.7851,
#     'Longitude': 143.3753,
#     'Surface Temperature (kelvin)': 337.4,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 41.4,
#     'Confidence': 83,
#     'Surface Temperature (Celcius)': 64},
#    {'Latitude': -37.4323,
#     'Longitude': 147.6583,
#     'Surface Temperature (kelvin)': 349.4,
#     'Datetime': '2017-04-05T03:39:10',
#     'Power': 74.4,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -37.4343,
#     'Longitude': 147.6327,
#     'Surface Temperature (kelvin)': 365.2,
# ...
#     'Surface Temperature (Celcius)': 61},
#    {'Latitude': -37.7496,
#     'Longitude': 148.3898,
#     'Surface Temperature (kelvin)': 319.4,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 18.4,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.7697,
#     'Longitude': 148.336,
#     'Surface Temperature (kelvin)': 330.7,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 32.6,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 57},
#    {'Latitude': -36.4324,
#     'Longitude': 141.5582,
#     'Surface Temperature (kelvin)': 325.5,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 17.7,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -38.0052,
#     'Longitude': 142.6179,
#     'Surface Temperature (kelvin)': 362.5,
#     'Datetime': '2017-04-06T04:20:40',
#     'Power': 95.2,
#     'Confidence': 94,
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -38.3557,
#     'Longitude': 147.0372,
#     'Surface Temperature (kelvin)': 325.3,
#     'Datetime': '2017-04-06T00:06:10',
#     'Power': 28.6,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.4509,
#     'Longitude': 143.1522,
#     'Surface Temperature (kelvin)': 320.7,
#     'Datetime': '2017-04-06T00:06:10',
#     'Power': 15.1,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -38.0962,
#     'Longitude': 146.9724,
#     'Surface Temperature (kelvin)': 320.4,
#     'Datetime': '2017-04-06T00:06:10',
#     'Power': 19.2,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -35.4625,
#     'Longitude': 143.1486,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-06T00:03:50',
#     'Power': 11.3,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -38.0942,
#     'Longitude': 146.9603,
#     'Surface Temperature (kelvin)': 313.1,
#     'Datetime': '2017-04-06T00:01:40',
#     'Power': 11.3,
#     'Confidence': 52,
#     'Surface Temperature (Celcius)': 39}]},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc5'),
#   'Station': 948701,
#   'Date': '2017-04-07',
#   'AirTemperature(Celcius)': 21,
#   'RelativeHumidity': 47.0,
#   'WindSpeed(knots)': 13.2,
#   'MaxWindSpeed': 20.0,
#   'MAX': '78.3*',
#   'MIN': '56.7',
#   'Precipitation': '0.00I',
#   'fire': [{'Latitude': -36.7394,
#     'Longitude': 147.1366,
#     'Surface Temperature (kelvin)': 317.6,
#     'Datetime': '2017-04-07T12:58:30',
#     'Power': 25.1,
#     'Confidence': 78,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.3257,
#     'Longitude': 149.1209,
#     'Surface Temperature (kelvin)': 314.5,
#     'Datetime': '2017-04-07T12:56:50',
#     'Power': 22.4,
#     'Confidence': 85,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3176,
#     'Longitude': 149.3776,
#     'Surface Temperature (kelvin)': 316.6,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 22.4,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.7507,
#     'Longitude': 147.1308,
#     'Surface Temperature (kelvin)': 312.7,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 19.0,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -37.3268,
#     'Longitude': 149.3795,
#     'Surface Temperature (kelvin)': 322.3,
#     'Datetime': '2017-04-07T12:56:30',
#     'Power': 27.0,
#     'Confidence': 94,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.7606,
#     'Longitude': 147.1326,
#     'Surface Temperature (kelvin)': 314.5,
#     'Datetime': '2017-04-07T12:54:00',
#     'Power': 20.5,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -35.6961,
#     'Longitude': 143.1935,
#     'Surface Temperature (kelvin)': 308.5,
#     'Datetime': '2017-04-07T12:53:40',
#     'Power': 16.6,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -37.3252,
#     'Longitude': 149.3911,
#     'Surface Temperature (kelvin)': 314.6,
#     'Datetime': '2017-04-07T12:53:40',
#     'Power': 20.0,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3314,
#     'Longitude': 149.1283,
#     'Surface Temperature (kelvin)': 309.1,
#     'Datetime': '2017-04-07T12:52:10',
#     'Power': 15.8,
#     'Confidence': 65,
#     'Surface Temperature (Celcius)': 35},
#    {'Latitude': -36.3477,
#     'Longitude': 144.533,
#     'Surface Temperature (kelvin)': 314.8,
#     'Datetime': '2017-04-07T12:52:10',
#     'Power': 24.4,
#     'Confidence': 86,
#     'Surface Temperature (Celcius)': 41},
#    {'Latitude': -37.3191,
#     'Longitude': 149.366,
#     'Surface Temperature (kelvin)': 318.8,
#     'Datetime': '2017-04-07T12:51:20',
#     'Power': 25.7,
#     'Confidence': 97,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -37.3359,
#     'Longitude': 149.3816,
#     'Surface Temperature (kelvin)': 321.3,
#     'Datetime': '2017-04-07T12:51:20',
#     'Power': 24.0,
#     'Confidence': 51,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -37.3526,
#     'Longitude': 149.3972,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T12:51:00',
#     'Power': 20.6,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.7408,
#     'Longitude': 147.1243,
#     'Surface Temperature (kelvin)': 322.6,
#     'Datetime': '2017-04-07T12:51:00',
#     'Power': 30.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 49},
#    {'Latitude': -36.762,
#     'Longitude': 147.12,
#     'Surface Temperature (kelvin)': 316.9,
#     'Datetime': '2017-04-07T12:50:50',
#     'Power': 23.1,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3344,
#     'Longitude': 149.3933,
#     'Surface Temperature (kelvin)': 320.9,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 24.7,
#     'Confidence': 68,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.3283,
#     'Longitude': 149.368,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 21.5,
#     'Confidence': 74,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -37.3511,
#     'Longitude': 149.4088,
#     'Surface Temperature (kelvin)': 319.5,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 24.2,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -37.3085,
#     'Longitude': 149.3756,
#     'Surface Temperature (kelvin)': 311.8,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 18.7,
#     'Confidence': 76,
#     'Surface Temperature (Celcius)': 38},
#    {'Latitude': -36.7508,
#     'Longitude': 147.1254,
#     'Surface Temperature (kelvin)': 312.4,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 19.2,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 39},
#    {'Latitude': -36.7309,
#     'Longitude': 147.1227,
#     'Surface Temperature (kelvin)': 315.8,
#     'Datetime': '2017-04-07T12:50:40',
#     'Power': 23.3,
#     'Confidence': 89,
#     'Surface Temperature (Celcius)': 42},
#    {'Latitude': -37.8361,
#     'Longitude': 142.7482,
#     'Surface Temperature (kelvin)': 327.3,
#     'Datetime': '2017-04-07T05:09:50',
#     'Power': 25.3,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.8277,
#     'Longitude': 142.7498,
#     'Surface Temperature (kelvin)': 319.7,
#     'Datetime': '2017-04-07T05:04:00',
#     'Power': 15.1,
#     'Confidence': 72,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.1031,
#     'Longitude': 143.0782,
#     'Surface Temperature (kelvin)': 318.4,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 12.6,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 45},
#    {'Latitude': -36.1025,
#     'Longitude': 143.0825,
#     'Surface Temperature (kelvin)': 316.4,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 11.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 43},
#    {'Latitude': -36.701,
#     'Longitude': 141.6351,
#     'Surface Temperature (kelvin)': 326.5,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 19.7,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.7034,
#     'Longitude': 141.6168,
#     'Surface Temperature (kelvin)': 319.3,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 11.0,
#     'Confidence': 71,
#     'Surface Temperature (Celcius)': 46},
#    {'Latitude': -36.698,
#     'Longitude': 141.6416,
#     'Surface Temperature (kelvin)': 328.1,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 22.4,
#     'Confidence': 81,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -36.7054,
#     'Longitude': 141.6708,
#     'Surface Temperature (kelvin)': 322.0,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 15.0,
#     'Confidence': 75,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.6999,
#     'Longitude': 141.6955,
#     'Surface Temperature (kelvin)': 325.6,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 20.3,
#     'Confidence': 79,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -36.7314,
#     'Longitude': 141.8698,
#     'Surface Temperature (kelvin)': 317.2,
#     'Datetime': '2017-04-07T05:03:10',
#     'Power': 10.5,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 44},
#    {'Latitude': -37.7931,
#     'Longitude': 148.385,
#     'Surface Temperature (kelvin)': 331.6,
#     'Datetime': '2017-04-07T03:31:40',
#     'Power': 33.8,
#     'Confidence': 64,
#     'Surface Temperature (Celcius)': 58},
#    {'Latitude': -37.2168,
#     'Longitude': 147.4748,
#     'Surface Temperature (kelvin)': 362.7,
#     'Datetime': '2017-04-07T03:31:40',
#     'Power': 106.5,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 89},
#    {'Latitude': -37.222,
#     'Longitude': 147.4689,
#     'Surface Temperature (kelvin)': 352.0,
#     'Datetime': '2017-04-07T03:28:20',
#     'Power': 79.2,
#     'Confidence': 96,
#     'Surface Temperature (Celcius)': 78},
#    {'Latitude': -37.7974,
#     'Longitude': 148.5498,
#     'Surface Temperature (kelvin)': 326.4,
#     'Datetime': '2017-04-07T03:27:50',
#     'Power': 28.8,
#     'Confidence': 60,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -37.2063,
#     'Longitude': 147.4713,
#     'Surface Temperature (kelvin)': 343.6,
#     'Datetime': '2017-04-07T03:27:30',
#     'Power': 61.1,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 70},
#    {'Latitude': -37.2082,
#     'Longitude': 147.4368,
#     'Surface Temperature (kelvin)': 343.9,
#     'Datetime': '2017-04-07T03:27:20',
#     'Power': 62.6,
#     'Confidence': 92,
#     'Surface Temperature (Celcius)': 70},
#    {'Latitude': -37.224000000000004,
#     'Longitude': 147.4347,
#     'Surface Temperature (kelvin)': 349.5,
#     'Datetime': '2017-04-07T03:27:20',
#     'Power': 74.4,
#     'Confidence': 95,
#     'Surface Temperature (Celcius)': 76},
#    {'Latitude': -37.2185,
#     'Longitude': 147.4402,
#     'Surface Temperature (kelvin)': 379.4,
#     'Datetime': '2017-04-07T03:27:10',
#     'Power': 163.7,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 106}]},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc6'),
#   'Station': 948701,
#   'Date': '2017-04-08',
#   'AirTemperature(Celcius)': 19,
#   'RelativeHumidity': 52.8,
#   'WindSpeed(knots)': 12.5,
#   'MaxWindSpeed': 21.0,
#   'MAX': '81.9*',
#   'MIN': '54.3*',
#   'Precipitation': '0.47G',
#   'fire': [{'Latitude': -37.34,
#     'Longitude': 149.3668,
#     'Surface Temperature (kelvin)': 347.6,
#     'Datetime': '2017-04-08T04:15:20',
#     'Power': 61.2,
#     'Confidence': 67,
#     'Surface Temperature (Celcius)': 74},
#    {'Latitude': -37.8567,
#     'Longitude': 147.1576,
#     'Surface Temperature (kelvin)': 321.4,
#     'Datetime': '2017-04-08T04:14:40',
#     'Power': 19.9,
#     'Confidence': 62,
#     'Surface Temperature (Celcius)': 48},
#    {'Latitude': -36.7287,
#     'Longitude': 142.6017,
#     'Surface Temperature (kelvin)': 359.1,
#     'Datetime': '2017-04-08T04:14:00',
#     'Power': 82.1,
#     'Confidence': 99,
#     'Surface Temperature (Celcius)': 85},
#    {'Latitude': -35.2363,
#     'Longitude': 143.0004,
#     'Surface Temperature (kelvin)': 342.5,
#     'Datetime': '2017-04-08T04:12:50',
#     'Power': 43.9,
#     'Confidence': 91,
#     'Surface Temperature (Celcius)': 69},
#    {'Latitude': -37.4368,
#     'Longitude': 149.1191,
#     'Surface Temperature (kelvin)': 326.1,
#     'Datetime': '2017-04-08T04:12:20',
#     'Power': 28.0,
#     'Confidence': 56,
#     'Surface Temperature (Celcius)': 52},
#    {'Latitude': -35.2378,
#     'Longitude': 142.9864,
#     'Surface Temperature (kelvin)': 367.5,
#     'Datetime': '2017-04-08T04:12:20',
#     'Power': 106.2,
#     'Confidence': 100,
#     'Surface Temperature (Celcius)': 94},
#    {'Latitude': -35.2397,
#     'Longitude': 142.98,
#     'Surface Temperature (kelvin)': 332.4,
#     'Datetime': '2017-04-08T04:12:00',
#     'Power': 25.4,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 59},
#    {'Latitude': -36.2115,
#     'Longitude': 141.6878,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-08T04:11:50',
#     'Power': 15.3,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -37.9408,
#     'Longitude': 146.0611,
#     'Surface Temperature (kelvin)': 320.7,
#     'Datetime': '2017-04-08T04:11:40',
#     'Power': 19.7,
#     'Confidence': 58,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -37.6994,
#     'Longitude': 146.2162,
#     'Surface Temperature (kelvin)': 314.0,
#     'Datetime': '2017-04-08T04:09:20',
#     'Power': 16.3,
#     'Confidence': 59,
#     'Surface Temperature (Celcius)': 40},
#    {'Latitude': -36.2726,
#     'Longitude': 145.506,
#     'Surface Temperature (kelvin)': 323.8,
#     'Datetime': '2017-04-08T04:09:00',
#     'Power': 21.6,
#     'Confidence': 77,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -35.2381,
#     'Longitude': 142.994,
#     'Surface Temperature (kelvin)': 357.1,
#     'Datetime': '2017-04-08T04:08:50',
#     'Power': 75.9,
#     'Confidence': 98,
#     'Surface Temperature (Celcius)': 83},
#    {'Latitude': -36.7199,
#     'Longitude': 142.5844,
#     'Surface Temperature (kelvin)': 329.9,
#     'Datetime': '2017-04-08T04:08:50',
#     'Power': 23.1,
#     'Confidence': 63,
#     'Surface Temperature (Celcius)': 56},
#    {'Latitude': -37.3493,
#     'Longitude': 149.3691,
#     'Surface Temperature (kelvin)': 353.4,
#     'Datetime': '2017-04-08T04:08:40',
#     'Power': 73.1,
#     'Confidence': 66,
#     'Surface Temperature (Celcius)': 80},
#    {'Latitude': -37.6447,
#     'Longitude': 148.6039,
#     'Surface Temperature (kelvin)': 323.7,
#     'Datetime': '2017-04-08T04:08:40',
#     'Power': 27.5,
#     'Confidence': 61,
#     'Surface Temperature (Celcius)': 50},
#    {'Latitude': -36.7165,
#     'Longitude': 142.6155,
#     'Surface Temperature (kelvin)': 340.1,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 39.6,
#     'Confidence': 90,
#     'Surface Temperature (Celcius)': 66},
#    {'Latitude': -36.7076,
#     'Longitude': 142.5982,
#     'Surface Temperature (kelvin)': 320.6,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 11.6,
#     'Confidence': 73,
#     'Surface Temperature (Celcius)': 47},
#    {'Latitude': -36.5652,
#     'Longitude': 145.5105,
#     'Surface Temperature (kelvin)': 327.2,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 23.3,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 54},
#    {'Latitude': -37.7009,
#     'Longitude': 146.2046,
#     'Surface Temperature (kelvin)': 326.6,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 31.7,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 53},
#    {'Latitude': -36.4023,
#     'Longitude': 145.7705,
#     'Surface Temperature (kelvin)': 332.0,
#     'Datetime': '2017-04-08T04:08:30',
#     'Power': 29.0,
#     'Confidence': 80,
#     'Surface Temperature (Celcius)': 58}]},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc7'),
#   'Station': 948701,
#   'Date': '2017-04-09',
#   'AirTemperature(Celcius)': 11,
#   'RelativeHumidity': 48.2,
#   'WindSpeed(knots)': 10.8,
#   'MaxWindSpeed': 22.9,
#   'MAX': '59.7*',
#   'MIN': '46.8*',
#   'Precipitation': '0.59G',
#   'fire': []},
#  {'_id': ObjectId('5b019c55b3dbfe3de262dcc8'),
#   'Station': 948701,
#   'Date': '2017-04-10',
#   'AirTemperature(Celcius)': 14,
#   'RelativeHumidity': 50.4,
#   'WindSpeed(knots)': 12.8,
#   'MaxWindSpeed': 20.0,
#   'MAX': '62.4*',
#   'MIN': '46.8',
#   'Precipitation': '0.01G',
#   'fire': []}]

# %% [markdown]
# **A7. Find the number of fire in each day. You are required to only display total number of fire and the date in the output.**

# %%
#perform round-robin partitioning
def rr_partition(data, n): 
    result = []
    
    # divide data in to n partitions
    for i in range(n): 
        result.append([])
    # calculate the number of the elements to be allocated to each bin
    n_bin = len(data)/n
    
    # for each bin, perform the following
    for index, element in enumerate(data): 
        # calculate the index of the bin that the current data point will be assigned
        index_bin = (int) (index % n)
        result[index_bin].append(element)
    return result

# %%
#Local caculation for each partitioning
def calculate(dataset):
    
    result = {}
    
    for r in dataset:
        key =  r['Date']
        val = len(r['fire'])
        if val != 0:
            if key not in result:
                result[key] = 0
            result[key] += val
    
    return result

# %%
def parallel_merge_all_groupby(dataset, n_processor):
    
    result = []
    
    subsets = rr_partition(dataset, n_processor)
    
    pool = mp.Pool(processes = n_processor)

    for s in subsets:
        result.append(pool.apply(calculate,[s]))
        
    return result

# %%
parallel_merge_all_groupby(result, 3)
# Out:
# [{'2017-03-08': 2,
#   '2017-03-14': 10,
#   '2017-03-17': 6,
#   '2017-03-26': 17,
#   '2017-03-29': 1,
#   '2017-04-01': 7,
#   '2017-04-04': 89,
#   '2017-04-07': 39,
#   '2017-04-13': 357,
#   '2017-04-16': 18,
#   '2017-04-19': 50,
#   '2017-04-22': 2,
#   '2017-04-25': 3,
#   '2017-05-01': 20,
#   '2017-05-04': 135,
#   '2017-05-07': 3,
#   '2017-05-10': 114,
#   '2017-05-13': 54,
#   '2017-05-16': 3,
#   '2017-05-22': 33,
#   '2017-06-03': 2,
#   '2017-06-09': 3,
#   '2017-06-18': 2,
#   '2017-06-30': 6,
#   '2017-07-06': 3,
#   '2017-08-02': 2,
#   '2017-08-05': 1,
#   '2017-08-14': 5,
#   '2017-09-10': 4,
#   '2017-09-22': 1,
#   '2017-10-01': 8,
#   '2017-10-04': 5,
#   '2017-10-07': 1,
#   '2017-10-10': 3,
#   '2017-10-16': 1,
#   '2017-10-28': 1,
#   '2017-11-09': 10,
#   '2017-11-12': 5,
#   '2017-11-21': 1,
#   '2017-11-30': 31,
#   '2017-12-09': 4,
#   '2017-12-12': 1,
#   '2017-12-15': 4,
#   '2017-12-21': 1,
#   '2017-12-24': 1,
#   '2017-12-27': 4},
#  {'2017-03-06': 2,
#   '2017-03-09': 3,
#   '2017-03-12': 5,
#   '2017-03-15': 7,
#   '2017-03-18': 3,
#   '2017-03-24': 2,
#   '2017-04-02': 5,
#   '2017-04-05': 49,
#   '2017-04-08': 20,
#   '2017-04-11': 24,
#   '2017-04-14': 18,
#   '2017-04-17': 38,
#   '2017-04-20': 31,
#   '2017-04-23': 19,
#   '2017-04-26': 1,
#   '2017-04-29': 3,
#   '2017-05-02': 10,
#   '2017-05-05': 31,
#   '2017-05-08': 24,
#   '2017-05-11': 19,
#   '2017-05-14': 1,
#   '2017-05-17': 1,
#   '2017-05-23': 5,
#   '2017-05-26': 4,
#   '2017-06-01': 2,
#   '2017-06-04': 9,
#   '2017-06-07': 14,
#   '2017-06-13': 1,
#   '2017-06-16': 2,
#   '2017-06-22': 1,
#   '2017-07-01': 4,
#   '2017-07-04': 1,
#   '2017-07-31': 2,
#   '2017-09-20': 5,
#   '2017-09-23': 23,
#   '2017-09-26': 1,
#   '2017-09-29': 2,
#   '2017-10-02': 7,
#   '2017-10-08': 1,
#   '2017-10-17': 5,
#   '2017-10-20': 3,
#   '2017-10-23': 1,
#   '2017-10-26': 5,
#   '2017-11-13': 5,
#   '2017-11-22': 2,
#   '2017-11-28': 1,
#   '2017-12-10': 2,
#   '2017-12-13': 1,
#   '2017-12-16': 15,
#   '2017-12-25': 1},
#  {'2017-03-07': 1,
#   '2017-03-10': 8,
#   '2017-03-13': 2,
#   '2017-03-19': 21,
#   '2017-03-25': 13,
#   '2017-03-28': 54,
#   '2017-03-31': 22,
#   '2017-04-03': 72,
#   '2017-04-06': 118,
#   '2017-04-12': 69,
#   '2017-04-15': 69,
#   '2017-04-18': 325,
#   '2017-04-24': 8,
#   '2017-05-03': 64,
#   '2017-05-06': 17,
#   '2017-05-09': 13,
#   '2017-05-12': 10,
#   '2017-05-15': 102,
#   '2017-05-18': 7,
#   '2017-05-24': 3,
#   '2017-06-02': 11,
#   '2017-06-11': 2,
#   '2017-06-14': 4,
#   '2017-06-20': 6,
#   '2017-07-02': 8,
#   '2017-07-05': 1,
#   '2017-07-14': 2,
#   '2017-07-29': 2,
#   '2017-08-01': 2,
#   '2017-08-10': 1,
#   '2017-08-13': 9,
#   '2017-09-21': 2,
#   '2017-09-24': 28,
#   '2017-09-27': 7,
#   '2017-10-03': 18,
#   '2017-10-06': 2,
#   '2017-10-09': 1,
#   '2017-10-15': 3,
#   '2017-10-18': 6,
#   '2017-10-21': 4,
#   '2017-10-27': 5,
#   '2017-11-05': 4,
#   '2017-11-08': 2,
#   '2017-11-11': 4,
#   '2017-11-14': 3,
#   '2017-11-23': 5,
#   '2017-11-29': 8,
#   '2017-12-08': 5,
#   '2017-12-14': 1}]

# %%
#Drop collection we created.
db.Combine.drop()
